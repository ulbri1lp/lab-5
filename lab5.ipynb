# %%
#import modules
import requests
import json

# %% [markdown]
# Question 1:

# %%
#base url
url = 'https://www.loc.gov'

#combining base url and list of resources
uri1 = url + '/resource/cph.3f05183/'  # item 1
uri2 = url + '/resource/fsa.8d24709/'  # item 2
uri3 = url + '/resource/highsm.64003/' # item 3

#print answer
print(uri1, uri2, uri3)
# Out:
# https://www.loc.gov/resource/cph.3f05183/ https://www.loc.gov/resource/fsa.8d24709/ https://www.loc.gov/resource/highsm.64003/

# %% [markdown]
# Question 2

# %%
#define parameters
parameters = {'fo': 'json'}

#request from item 1
r1 = requests.get(uri1, params=parameters)

#display returned data
r1.json()
# Out:
# {'articles_and_essays': None,
#  'cite_this': {'apa': 'Federal Art Project, S. <cite>For Greater Knowledge on More Subjects Use Your Library More Often</cite>. Illinois Chicago, None. [Chicago: illinois wpa art project, between 1936 and 1941] [Photograph] Retrieved from the Library of Congress, https://www.loc.gov/item/98508155/.',
#   'chicago': 'Federal Art Project, Sponsor. <cite>For Greater Knowledge on More Subjects Use Your Library More Often</cite>. Illinois Chicago, None. [Chicago: illinois wpa art project, between 1936 and 1941] Photograph. https://www.loc.gov/item/98508155/.',
#   'mla': 'Federal Art Project, Sponsor. <cite>For Greater Knowledge on More Subjects Use Your Library More Often</cite>. [Chicago: illinois wpa art project, between 1936 and 1941] Photograph. Retrieved from the Library of Congress, &lt;www.loc.gov/item/98508155/&gt;.'},
#  'item': {'_version_': 1754109026683060224,
#   'access_restricted': False,
#   'aka': ['https://www.loc.gov/pictures/item/98508155/',
#    'http://www.loc.gov/item/98508155/',
#    'http://www.loc.gov/pictures/item/98508155/',
#    'https://www.loc.gov/pictures/collection/wpapos/item/98508155/',
#    'http://www.loc.gov/pictures/collection/wpapos/item/98508155/',
#    'http://www.loc.gov/resource/cph.3f05183/',
#    'http://lccn.loc.gov/98508155',
#    'https://hdl.loc.gov/loc.pnp/cph.3f05183'],
#   'call_number': 'POS - WPA - ILL .01 .F665, no. 1 (B size) [P&P]',
#   'campaigns': [],
#   'contributor_names': ['Federal Art Project, sponsor'],
#   'contributors': [{'federal art project': 'https://www.loc.gov/search/?fa=contributor:federal+art+project&fo=json'}],
#   'control_number': '',
#   'created': '2022-08-30T06:05:30Z',
#   'created_published': ['Chicago : Illinois WPA Art Project, [between 1936 and 1941]'],
#   'created_published_date': '[between 1936 and 1941]',
#   'date': '1936-01-01',
#   'dates': [{'1936': 'https://www.loc.gov/search/?dates=1936/1936&fo=json'}],
#   'description': ['1 print on board (poster) : silkscreen, color. | Poster showing a mortarboard and a pair of glasses superimposed over a globe, promoting use of libraries.'],
#   'digital_id': ['cph 3f05183 //hdl.loc.gov/loc.pnp/cph.3f05183'],
#   'digitized': True,
#   'display_offsite': True,
#   'extract_timestamp': '2022-09-03T12:25:49.213Z',
#   'extract_urls': ['http://www.loc.gov/pictures/collection/wpapos/item/98508155/#wpapos',
#    'http://lccn.loc.gov/98508155#catalog-split-09'],
#   'format': [{'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}],
#   'format_headings': ['Posters--1930-1950.',
#    'Screen prints--Color--1930-1950.'],
#   'genre': ['Posters--1930-1950', 'Screen prints--Color--1930-1950'],
#   'group': ['wpapos',
#    'catalog-split-09',
#    'catalog',
#    'wpa-posters',
#    'main-catalog-split-09',
#    'main-catalog'],
#   'hassegments': False,
#   'id': 'http://www.loc.gov/item/98508155/',
#   'image_url': ['https://tile.loc.gov/storage-services/service/pnp/cph/3f00000/3f05000/3f05100/3f05183_150px.jpg#h=150&w=103',
#    'https://tile.loc.gov/storage-services/service/pnp/cph/3f00000/3f05000/3f05100/3f05183t.gif#h=150&w=103',
#    'https://tile.loc.gov/storage-services/service/pnp/cph/3f00000/3f05000/3f05100/3f05183r.jpg#h=640&w=440',
#    'https://tile.loc.gov/storage-services/service/pnp/cph/3f00000/3f05000/3f05100/3f05183v.jpg#h=1024&w=705'],
#   'index': 1,
#   'item': {'call_number': 'POS - WPA - ILL .01 .F665, no. 1 (B size) [P&P]',
#    'contributor_names': ['Federal Art Project, sponsor '],
#    'contributors': ['Federal Art Project, sponsor'],
#    'control_number': '98508155',
#    'created': '2022-08-30T06:05:30Z',
#    'created_published': 'Chicago : Illinois WPA Art Project, [between 1936 and 1941]',
#    'created_published_date': '[between 1936 and 1941]',
#    'creators': [{'link': 'https://www.loc.gov/pictures/related/?fi=name&q=Federal%20Art%20Project&co=wpapos',
#      'role': 'sponsor',
#      'title': 'Federal Art Project'}],
#    'date': '[between 1936 and 1941]',
#    'digital_id': ['cph 3f05183 //hdl.loc.gov/loc.pnp/cph.3f05183'],
#    'display_offsite': True,
#    'format': ['still image'],
#    'formats': [{'link': 'https://www.loc.gov/pictures/related/?fi=format&q=Posters--1930-1950.&co=wpapos',
#      'title': 'Posters--1930-1950.'},
#     {'link': 'https://www.loc.gov/pictures/related/?fi=format&q=Screen%20prints--Color--1930-1950.&co=wpapos',
#      'title': 'Screen prints--Color--1930-1950.'}],
#    'genre': ['Posters--1930-1950', 'Screen prints--Color--1930-1950'],
#    'id': '98508155',
#    'link': 'https://www.loc.gov/pictures/item/98508155/',
#    'location': ['Illinois--Chicago'],
#    'marc': 'https://www.loc.gov/pictures/item/98508155/marc/',
#    'medium': ['1 print on board (poster) : silkscreen, color.'],
#    'medium_brief': '1 print on board (poster) :',
#    'mediums': ['1 print on board (poster) : silkscreen, color.'],
#    'modified': '2022-08-30T06:05:31Z',
#    'notes': ['Work Projects Administration Poster Collection (Library of Congress).',
#     'Date stamped on verso: Jan 24 1941.'],
#    'number_former_id': ['https://www.loc.gov/item/98508155',
#     'https://www.loc.gov/item/11715294'],
#    'other_control_numbers': ['11715294'],
#    'place': [{'latitude': '',
#      'link': 'https://www.loc.gov/pictures/related/?fi=place&q=Illinois--Chicago&co=wpapos',
#      'longitude': '',
#      'title': 'Illinois--Chicago'}],
#    'raw_collections': ['diof', 'flickreyeglasses', 'pp', 'wpapos'],
#    'repository': 'Library of Congress Prints and Photographs Division Washington, D.C. 20540 USA',
#    'reproduction_number': 'LC-USZC2-5183 (color film copy slide)',
#    'resource_links': ['//hdl.loc.gov/loc.pnp/cph.3f05183'],
#    'rights_advisory': 'No known restrictions on publication.',
#    'rights_information': 'No known restrictions on publication.',
#    'service_low': '//tile.loc.gov/storage-services/service/pnp/cph/3f00000/3f05000/3f05100/3f05183_150px.jpg',
#    'service_medium': '//tile.loc.gov/storage-services/service/pnp/cph/3f00000/3f05000/3f05100/3f05183r.jpg',
#    'sort_date': '1936',
#    'source_created': '1998-05-20T00:00:00Z',
#    'source_modified': '2022-08-26T13:36:40Z',
#    'subject_headings': ['Libraries--Illinois--Chicago--1930-1950.',
#     'Education--Illinois--Chicago--1930-1950.',
#     'Illinois--Chicago'],
#    'subjects': ['Libraries--Illinois--Chicago--1930-1950',
#     'Education--Illinois--Chicago--1930-1950'],
#    'summary': 'Poster showing a mortarboard and a pair of glasses superimposed over a globe, promoting use of libraries.',
#    'thumb_gallery': '//tile.loc.gov/storage-services/service/pnp/cph/3f00000/3f05000/3f05100/3f05183_150px.jpg',
#    'title': 'For greater knowledge on more subjects use your library more often'},
#   'language': ['english'],
#   'languages': [{'english': 'https://www.loc.gov/search/?fa=language:english&fo=json'}],
#   'library_of_congress_control_number': '98508155',
#   'link': 'https://www.loc.gov/pictures/item/98508155/',
#   'location': ['illinois', 'chicago'],
#   'locations': [{'chicago': 'https://www.loc.gov/search/?fa=location:chicago&fo=json'},
#    {'illinois': 'https://www.loc.gov/search/?fa=location:illinois&fo=json'}],
#   'marc': 'https://www.loc.gov/pictures/item/98508155/marc/',
#   'medium': ['1 print on board (poster) : silkscreen, color.'],
#   'medium_brief': '1 print on board (poster) :',
#   'mime_type': ['image/gif', 'image/jpg', 'image/tif'],
#   'modified': '2022-08-30T06:05:31Z',
#   'notes': ['Work Projects Administration Poster Collection (Library of Congress).',
#    'Date stamped on verso: Jan 24 1941.'],
#   'number': ['2022-08-26t13:36:40',
#    '98508155',
#    'http://www.loc.gov/item/98508155',
#    'http://www.loc.gov/item/11715294'],
#   'number_former_id': ['http://www.loc.gov/item/11715294',
#    'http://www.loc.gov/item/98508155'],
#   'number_lccn': ['98508155'],
#   'number_source_modified': ['2022-08-26t13:36:40'],
#   'online_format': ['image'],
#   'original_format': ['photo, print, drawing'],
#   'other_control_numbers': ['11715294'],
#   'other_formats': [{'label': 'MARCXML Record',
#     'link': 'https://lccn.loc.gov/98508155/marcxml'},
#    {'label': 'MODS Record', 'link': 'https://lccn.loc.gov/98508155/mods'},
#    {'label': 'Dublin Core Record',
#     'link': 'https://lccn.loc.gov/98508155/dc'}],
#   'partof': [{'count': 932,
#     'title': 'by the people, for the people: posters from the wpa, 1936-1943',
#     'url': 'https://www.loc.gov/search/?fa=partof:by+the+people,+for+the+people:+posters+from+the+wpa,+1936-1943&fo=json'},
#    {'count': 947,
#     'title': 'posters: wpa posters',
#     'url': 'https://www.loc.gov/collections/works-progress-administration-posters/?fo=json'},
#    {'count': 437933,
#     'title': 'american memory',
#     'url': 'https://www.loc.gov/search/?fa=partof:american+memory&fo=json'},
#    {'count': 934445,
#     'title': 'prints & photographs online catalog (library of congress)',
#     'url': 'https://www.loc.gov/search/?fa=partof:prints+%26+photographs+online+catalog+%28library+of+congress%29&fo=json'},
#    {'count': 1105005,
#     'title': 'prints and photographs division',
#     'url': 'https://www.loc.gov/search/?fa=partof:prints+and+photographs+division&fo=json'},
#    {'count': 1672342,
#     'title': 'catalog',
#     'url': 'https://www.loc.gov/search/?fa=partof:catalog&fo=json'}],
#   'place': [{'latitude': '',
#     'link': 'https://www.loc.gov/pictures/related/?fi=place&q=Illinois--Chicago&co=wpapos',
#     'longitude': '',
#     'title': 'Illinois--Chicago'}],
#   'raw_collections': ['diof', 'flickreyeglasses', 'pp', 'wpapos'],
#   'related': {'neighbors': 'https://www.loc.gov/pictures/related/?&co=wpapos&pk=98508155&st=gallery&sb=call_number#focus'},
#   'repository': ['Library of Congress Prints and Photographs Division Washington, D.C. 20540 USA'],
#   'reproduction_number': 'LC-USZC2-5183 (color film copy slide)',
#   'reproductions': [],
#   'resource_links': ['//hdl.loc.gov/loc.pnp/cph.3f05183'],
#   'resources': [{'caption': 'color film copy slide',
#     'files': 1,
#     'image': 'https://tile.loc.gov/storage-services/service/pnp/cph/3f00000/3f05000/3f05100/3f05183_150px.jpg',
#     'url': 'https://www.loc.gov/resource/cph.3f05183/'}],
#   'rights': ['<p>The Library of Congress does not&nbsp;own rights to material  in its collections. Therefore, it does not license or charge permission fees  for use of such material and cannot grant or deny permission to publish or  otherwise distribute the material. </p>\n<p>Ultimately, it is the researcher\'s obligation to assess copyright or other use restrictions and  obtain permission from third parties when necessary before publishing or  otherwise distributing materials found in the Library\'s collections. </p>\n<p>For information about reproducing,  publishing, and citing material from this collection, as well as access to the  original items, see: <a href="https://www.loc.gov/rr/print/res/217_wpa.html">Work Projects Administration Posters - Rights and Restrictions Information</a> </p>\n\n'],
#   'rights_advisory': 'No known restrictions on publication.',
#   'rights_information': 'No known restrictions on publication.',
#   'score': 19.262096,
#   'shard': '00',
#   'shelf_id': 'POS - WPA - ILL .01 .F665, no. 1 (B size) [P&P]',
#   'site': ['pictures', 'catalog'],
#   'sort_date': '1936',
#   'source_created': '1998-05-20T00:00:00Z',
#   'source_modified': '2022-08-26T13:36:40Z',
#   'subject': ['illinois',
#    'chicago',
#    'libraries',
#    'screen prints',
#    'color',
#    'education',
#    'posters'],
#   'subject_headings': ['Libraries--Illinois--Chicago--1930-1950',
#    'Education--Illinois--Chicago--1930-1950'],
#   'subjects': [{'chicago': 'https://www.loc.gov/search/?fa=subject:chicago&fo=json'},
#    {'color': 'https://www.loc.gov/search/?fa=subject:color&fo=json'},
#    {'education': 'https://www.loc.gov/search/?fa=subject:education&fo=json'},
#    {'illinois': 'https://www.loc.gov/search/?fa=subject:illinois&fo=json'},
#    {'libraries': 'https://www.loc.gov/search/?fa=subject:libraries&fo=json'},
#    {'posters': 'https://www.loc.gov/search/?fa=subject:posters&fo=json'},
#    {'screen prints': 'https://www.loc.gov/search/?fa=subject:screen+prints&fo=json'}],
#   'summary': 'Poster showing a mortarboard and a pair of glasses superimposed over a globe, promoting use of libraries.',
#   'thumb_gallery': '//tile.loc.gov/storage-services/service/pnp/cph/3f00000/3f05000/3f05100/3f05183_150px.jpg',
#   'timestamp': '2023-01-04T16:12:06.699Z',
#   'title': 'For greater knowledge on more subjects use your library more often',
#   'type': ['photo, print, drawing'],
#   'unrestricted': True,
#   'url': 'https://www.loc.gov/item/98508155/'},
#  'more_like_this': [{'access_restricted': False,
#    'aka': ['http://www.loc.gov/pictures/collection/wpapos/item/98517823/',
#     'http://www.loc.gov/item/98517823/',
#     'http://www.loc.gov/pictures/item/98517823/',
#     'https://hdl.loc.gov/loc.pnp/cph.3f05555',
#     'http://www.loc.gov/resource/cph.3f05555/',
#     'http://lccn.loc.gov/98517823'],
#    'campaigns': [],
#    'contributor': ['federal art project'],
#    'date': '1936-01-01',
#    'description': ['1 print on board (poster) : silkscreen, color. | Poster for the Chicago Public Library promoting public library week.'],
#    'digitized': True,
#    'extract_timestamp': '2021-09-01T23:01:18.339Z',
#    'group': ['wpapos',
#     'catalog-split-11',
#     'catalog',
#     'wpa-posters',
#     'main-catalog-split-11',
#     'main-catalog'],
#    'hassegments': False,
#    'id': 'http://www.loc.gov/item/98517823/',
#    'image_url': ['https://tile.loc.gov/storage-services/service/pnp/cph/3f00000/3f05000/3f05500/3f05555_150px.jpg#h=150&w=101',
#     'https://tile.loc.gov/storage-services/service/pnp/cph/3f00000/3f05000/3f05500/3f05555t.gif#h=150&w=101',
#     'https://tile.loc.gov/storage-services/service/pnp/cph/3f00000/3f05000/3f05500/3f05555r.jpg#h=640&w=432',
#     'https://tile.loc.gov/storage-services/service/pnp/cph/3f00000/3f05000/3f05500/3f05555v.jpg#h=1024&w=692'],
#    'index': 1,
#    'language': ['english'],
#    'latlong': [41.775, -87.6963888889],
#    'location': ['illinois', 'chicago'],
#    'location_str': '',
#    'lonlat': [-87.6963888889, 41.775],
#    'mime_type': ['image/gif', 'image/jpg', 'image/tif'],
#    'number': ['98517823',
#     'http://www.loc.gov/item/98517823',
#     'http://www.loc.gov/item/11724101',
#     '2007-11-14t10:52:48'],
#    'online_format': ['image'],
#    'original_format': ['photo, print, drawing'],
#    'partof': ['by the people, for the people: posters from the wpa, 1936-1943',
#     'catalog',
#     'posters: wpa posters',
#     'prints and photographs division',
#     'prints & photographs online catalog (library of congress)',
#     'american memory'],
#    'score': 59.341038,
#    'shelf_id': 'POS - WPA - ILL .P83, no. 1 (C size) [P&P]',
#    'site': ['pictures', 'catalog'],
#    'subject': ['illinois',
#     'chicago',
#     'chicago public library',
#     'libraries',
#     'screen prints',
#     'color',
#     'celebrations',
#     'public relations',
#     'posters'],
#    'timestamp': '2023-01-04T16:12:53.157Z',
#    'title': 'Public library week--November 12 - 18 Your public library invites you to make its acquaintance : Open house all week : Always at your service.',
#    'type': ['still image'],
#    'url': 'https://www.loc.gov/item/98517823/'},
#   {'access_restricted': False,
#    'aka': ['http://www.loc.gov/pictures/collection/wpapos/item/98508385/',
#     'http://www.loc.gov/item/98508385/',
#     'http://www.loc.gov/pictures/item/98508385/',
#     'https://hdl.loc.gov/loc.pnp/cph.3f05168',
#     'http://www.loc.gov/resource/cph.3f05168/',
#     'http://lccn.loc.gov/98508385'],
#    'campaigns': [],
#    'contributor': ['federal art project'],
#    'date': '1936-01-01',
#    'description': ['1 print on board (poster) : silkscreen, color. | Poster for bookmobile service of the Chicago Public Library, showing a traffic light.'],
#    'digitized': True,
#    'extract_timestamp': '2021-09-01T23:01:15.957Z',
#    'group': ['wpapos',
#     'catalog-split-14',
#     'catalog',
#     'wpa-posters',
#     'main-catalog-split-14',
#     'main-catalog'],
#    'hassegments': False,
#    'id': 'http://www.loc.gov/item/98508385/',
#    'image_url': ['https://tile.loc.gov/storage-services/service/pnp/cph/3f00000/3f05000/3f05100/3f05168_150px.jpg#h=150&w=104',
#     'https://tile.loc.gov/storage-services/service/pnp/cph/3f00000/3f05000/3f05100/3f05168t.gif#h=150&w=104',
#     'https://tile.loc.gov/storage-services/service/pnp/cph/3f00000/3f05000/3f05100/3f05168r.jpg#h=640&w=443',
#     'https://tile.loc.gov/storage-services/service/pnp/cph/3f00000/3f05000/3f05100/3f05168v.jpg#h=1024&w=708'],
#    'index': 2,
#    'language': ['english'],
#    'latlong': [41.775, -87.6963888889],
#    'location': ['illinois', 'chicago'],
#    'location_str': '',
#    'lonlat': [-87.6963888889, 41.775],
#    'mime_type': ['image/gif', 'image/jpg', 'image/tif'],
#    'number': ['http://www.loc.gov/item/98508385',
#     '98508385',
#     'http://www.loc.gov/item/11715504',
#     '2007-10-05t16:14:29'],
#    'online_format': ['image'],
#    'original_format': ['photo, print, drawing'],
#    'partof': ['by the people, for the people: posters from the wpa, 1936-1943',
#     'catalog',
#     'posters: wpa posters',
#     'prints and photographs division',
#     'prints & photographs online catalog (library of congress)',
#     'american memory'],
#    'score': 59.341038,
#    'shelf_id': 'POS - WPA - ILL .01 .C75, no. 1 (B size) [P&P]',
#    'site': ['pictures', 'catalog'],
#    'subject': ['illinois',
#     'chicago',
#     'chicago public library',
#     'libraries',
#     'screen prints',
#     'color',
#     'public relations',
#     'bookmobiles',
#     'posters'],
#    'timestamp': '2023-01-04T16:12:06.699Z',
#    'title': 'Curb service 10,000 current books - convenient, free, time saving : Chicago Public Library, Randolph St. corridor.',
#    'type': ['still image'],
#    'url': 'https://www.loc.gov/item/98508385/'},
#   {'access_restricted': False,
#    'aka': ['http://www.loc.gov/pictures/collection/wpapos/item/98513471/',
#     'http://www.loc.gov/item/98513471/',
#     'http://www.loc.gov/pictures/item/98513471/',
#     'https://hdl.loc.gov/loc.pnp/cph.3f05238',
#     'http://www.loc.gov/resource/cph.3f05238/',
#     'http://lccn.loc.gov/98513471'],
#    'campaigns': [],
#    'contributor': ['federal art project'],
#    'date': '1936-01-01',
#    'description': ['1 print on board (poster) : silkscreen, color. | Poster showing a globe with a book on North America.'],
#    'digitized': True,
#    'extract_timestamp': '2021-09-01T23:01:16.882Z',
#    'group': ['wpapos',
#     'catalog-split-06',
#     'catalog',
#     'wpa-posters',
#     'main-catalog-split-06',
#     'main-catalog'],
#    'hassegments': False,
#    'id': 'http://www.loc.gov/item/98513471/',
#    'image_url': ['https://tile.loc.gov/storage-services/service/pnp/cph/3f00000/3f05000/3f05200/3f05238_150px.jpg#h=150&w=104',
#     'https://tile.loc.gov/storage-services/service/pnp/cph/3f00000/3f05000/3f05200/3f05238t.gif#h=150&w=104',
#     'https://tile.loc.gov/storage-services/service/pnp/cph/3f00000/3f05000/3f05200/3f05238r.jpg#h=640&w=445',
#     'https://tile.loc.gov/storage-services/service/pnp/cph/3f00000/3f05000/3f05200/3f05238v.jpg#h=1024&w=712'],
#    'index': 3,
#    'language': ['english'],
#    'latlong': [41.775, -87.6963888889],
#    'location': ['illinois', 'chicago'],
#    'location_str': '',
#    'lonlat': [-87.6963888889, 41.775],
#    'mime_type': ['image/gif', 'image/jpg', 'image/tif'],
#    'number': ['http://www.loc.gov/item/11720139',
#     '98513471',
#     'http://www.loc.gov/item/98513471',
#     '2007-10-05t15:50:35'],
#    'online_format': ['image'],
#    'original_format': ['photo, print, drawing'],
#    'partof': ['by the people, for the people: posters from the wpa, 1936-1943',
#     'catalog',
#     'posters: wpa posters',
#     'prints and photographs division',
#     'prints & photographs online catalog (library of congress)',
#     'american memory'],
#    'score': 59.341038,
#    'shelf_id': 'POS - WPA - ILL .S072, no. 1 (B size) [P&P]',
#    'site': ['pictures', 'catalog'],
#    'subject': ['illinois',
#     'chicago',
#     'chicago public library',
#     'libraries',
#     'screen prints',
#     'color',
#     'celebrations',
#     'public relations',
#     'posters'],
#    'timestamp': '2023-01-04T16:12:25.167Z',
#    'title': 'Chicago public library week--March 30 - April 5 The public library--an American institution /',
#    'type': ['still image'],
#    'url': 'https://www.loc.gov/item/98513471/'},
#   {'access_restricted': False,
#    'aka': ['http://www.loc.gov/pictures/collection/wpapos/item/98513545/',
#     'http://www.loc.gov/item/98513545/',
#     'http://www.loc.gov/pictures/item/98513545/',
#     'https://hdl.loc.gov/loc.pnp/cph.3f05229',
#     'http://www.loc.gov/resource/cph.3f05229/',
#     'http://lccn.loc.gov/98513545'],
#    'campaigns': [],
#    'contributor': ['weisberg, shari', 'federal art project'],
#    'date': '1936-01-01',
#    'description': ['1 print on board (poster) : silkscreen, color. | Poster for the WPA statewide library project, showing two children on a large book, looking down at mountains and trees.'],
#    'digitized': True,
#    'extract_timestamp': '2021-09-01T23:01:16.882Z',
#    'group': ['wpapos',
#     'catalog-split-08',
#     'catalog',
#     'wpa-posters',
#     'main-catalog-split-08',
#     'main-catalog'],
#    'hassegments': False,
#    'id': 'http://www.loc.gov/item/98513545/',
#    'image_url': ['https://tile.loc.gov/storage-services/service/pnp/cph/3f00000/3f05000/3f05200/3f05229_150px.jpg#h=150&w=104',
#     'https://tile.loc.gov/storage-services/service/pnp/cph/3f00000/3f05000/3f05200/3f05229t.gif#h=150&w=104',
#     'https://tile.loc.gov/storage-services/service/pnp/cph/3f00000/3f05000/3f05200/3f05229r.jpg#h=640&w=442',
#     'https://tile.loc.gov/storage-services/service/pnp/cph/3f00000/3f05000/3f05200/3f05229v.jpg#h=1024&w=707'],
#    'index': 4,
#    'language': ['english'],
#    'latlong': [41.775, -87.6963888889],
#    'location': ['illinois', 'chicago'],
#    'location_str': '',
#    'lonlat': [-87.6963888889, 41.775],
#    'mime_type': ['image/gif', 'image/jpg', 'image/tif'],
#    'number': ['http://www.loc.gov/item/11720208',
#     'http://www.loc.gov/item/98513545',
#     '2007-11-27t16:28:25',
#     '98513545'],
#    'online_format': ['image'],
#    'original_format': ['photo, print, drawing'],
#    'partof': ['by the people, for the people: posters from the wpa, 1936-1943',
#     'catalog',
#     'posters: wpa posters',
#     'prints and photographs division',
#     'prints & photographs online catalog (library of congress)',
#     'american memory'],
#    'score': 59.341038,
#    'shelf_id': 'POS - WPA - ILL .W43, no. 5 (B size) [P&P]',
#    'site': ['pictures', 'catalog'],
#    'subject': ['illinois',
#     'chicago',
#     'reading',
#     'libraries',
#     'screen prints',
#     'color',
#     'children',
#     'posters'],
#    'timestamp': '2023-01-04T16:12:25.167Z',
#    'title': 'A trip around the world at story hour time Story hour club--W.P.A library center /',
#    'type': ['still image'],
#    'url': 'https://www.loc.gov/item/98513545/'},
#   {'access_restricted': False,
#    'aka': ['http://www.loc.gov/pictures/collection/wpapos/item/92500870/',
#     'http://www.loc.gov/item/92500870/',
#     'http://www.loc.gov/pictures/item/92500870/',
#     'https://hdl.loc.gov/loc.pnp/cph.3f03741',
#     'http://www.loc.gov/resource/cph.3f03741/',
#     'http://lccn.loc.gov/92500870'],
#    'campaigns': [],
#    'contributor': ['federal art project'],
#    'date': '1940-01-01',
#    'description': ['1 print on board (poster) : silkscreen, color. | Poster for book talks at the Chicago Public Library, showing the sun.'],
#    'digitized': True,
#    'extract_timestamp': '2021-09-01T23:01:15.427Z',
#    'group': ['wpapos',
#     'catalog-split-15',
#     'catalog',
#     'wpa-posters',
#     'main-catalog-split-15',
#     'main-catalog'],
#    'hassegments': False,
#    'id': 'http://www.loc.gov/item/92500870/',
#    'image_url': ['https://tile.loc.gov/storage-services/service/pnp/cph/3f00000/3f03000/3f03700/3f03741_150px.jpg#h=150&w=102',
#     'https://tile.loc.gov/storage-services/service/pnp/cph/3f00000/3f03000/3f03700/3f03741t.gif#h=150&w=102',
#     'https://tile.loc.gov/storage-services/service/pnp/cph/3f00000/3f03000/3f03700/3f03741r.jpg#h=640&w=434',
#     'https://tile.loc.gov/storage-services/service/pnp/cph/3f00000/3f03000/3f03700/3f03741v.jpg#h=1024&w=695'],
#    'index': 5,
#    'language': ['english'],
#    'latlong': [41.775, -87.6963888889],
#    'location': ['illinois', 'chicago'],
#    'location_str': '',
#    'lonlat': [-87.6963888889, 41.775],
#    'mime_type': ['image/gif', 'image/jpg', 'image/tif'],
#    'number': ['92500870',
#     'http://www.loc.gov/item/92500870',
#     '2007-10-04t16:38:51',
#     'http://www.loc.gov/item/11592714'],
#    'online_format': ['image'],
#    'original_format': ['photo, print, drawing'],
#    'partof': ['by the people, for the people: posters from the wpa, 1936-1943',
#     'catalog',
#     'posters: wpa posters',
#     'prints and photographs division',
#     'prints & photographs online catalog (library of congress)',
#     'american memory'],
#    'score': 54.399727,
#    'shelf_id': 'POS - WPA - ILL .01 .B563, no. 1 (B size) [P&P]',
#    'site': ['pictures', 'catalog'],
#    'subject': ['illinois',
#     'meetings',
#     'chicago',
#     'chicago public library',
#     'screen prints',
#     'color',
#     'sun',
#     'book talks',
#     'posters'],
#    'timestamp': '2023-01-04T16:11:56.156Z',
#    'title': 'Book talks, 12:15 to 12:45 noon hour, every Thursday Nov. thru Apr.',
#    'type': ['still image'],
#    'url': 'https://www.loc.gov/item/92500870/'},
#   {'access_restricted': False,
#    'aka': ['http://www.loc.gov/pictures/collection/wpapos/item/95514298/',
#     'https://hdl.loc.gov/loc.pnp/cph.3f05222',
#     'http://www.loc.gov/item/95514298/',
#     'http://www.loc.gov/pictures/item/95514298/',
#     'https://hdl.loc.gov/loc.pnp/cph.3g03395',
#     'http://www.loc.gov/resource/cph.3g03395/',
#     'http://www.loc.gov/resource/cph.3f05222/',
#     'http://lccn.loc.gov/95514298'],
#    'campaigns': [],
#    'contributor': ['federal art project'],
#    'date': '1937-01-01',
#    'description': ['1 print on board (poster) : silkscreen, color. | Text with leopard.'],
#    'digitized': True,
#    'extract_timestamp': '2021-09-01T23:01:15.427Z',
#    'group': ['wpapos',
#     'catalog-split-11',
#     'catalog',
#     'wpa-posters',
#     'main-catalog-split-11',
#     'main-catalog'],
#    'hassegments': False,
#    'id': 'http://www.loc.gov/item/95514298/',
#    'image_url': ['https://tile.loc.gov/storage-services/service/pnp/cph/3g00000/3g03000/3g03300/3g03395_150px.jpg#h=121&w=150',
#     'https://tile.loc.gov/storage-services/service/pnp/cph/3g00000/3g03000/3g03300/3g03395t.gif#h=121&w=150',
#     'https://tile.loc.gov/storage-services/service/pnp/cph/3g00000/3g03000/3g03300/3g03395r.jpg#h=518&w=640',
#     'https://tile.loc.gov/storage-services/service/pnp/cph/3g00000/3g03000/3g03300/3g03395v.jpg#h=828&w=1024'],
#    'index': 6,
#    'language': ['english'],
#    'latlong': [41.775, -87.6963888889],
#    'location': ['illinois', 'chicago'],
#    'location_str': '',
#    'lonlat': [-87.6963888889, 41.775],
#    'mime_type': ['image/gif', 'image/jpg', 'image/tif'],
#    'number': ['2007-11-15t10:49:52',
#     'http://www.loc.gov/item/11655370',
#     'http://www.loc.gov/item/95514298',
#     '95514298'],
#    'online_format': ['image'],
#    'original_format': ['photo, print, drawing'],
#    'partof': ['by the people, for the people: posters from the wpa, 1936-1943',
#     'catalog',
#     'posters: wpa posters',
#     'prints and photographs division',
#     'prints & photographs online catalog (library of congress)',
#     'american memory'],
#    'score': 54.399727,
#    'shelf_id': 'POS - WPA - ILL .C37, no. 8 (B size) [P&P]',
#    'site': ['pictures', 'catalog'],
#    'subject': ['illinois',
#     'zoos',
#     'chicago',
#     'screen prints',
#     'color',
#     'panthers',
#     'posters'],
#    'timestamp': '2023-01-04T16:11:56.156Z',
#    'title': 'Visit Brookside Zoo free',
#    'type': ['still image'],
#    'url': 'https://www.loc.gov/item/95514298/'}],
#  'notice': {'warning': 'Due to the temporary shutdown of the federal government beginning October 1, 2025, all Library of Congress buildings are closed and all public events are canceled until further notice. <a href="/item/prn-25-a05/">More</a>.\n'},
#  'options': {'access_group': [''],
#   'access_group_raw': '',
#   'all': None,
#   'api_version': '1',
#   'app_context': None,
#   'application_version': '$Revision$',
#   'attribute': None,
#   'attribute!': None,
#   'attribute_map': None,
#   'cache_tags': ['wpapos',
#    'catalog-split-09',
#    'catalog',
#    'wpa-posters',
#    'main-catalog-split-09',
#    'main-catalog',
#    'catalog-split-11',
#    'main-catalog-split-11',
#    'catalog-split-14',
#    'main-catalog-split-14',
#    'catalog-split-06',
#    'main-catalog-split-06',
#    'catalog-split-08',
#    'main-catalog-split-08',
#    'catalog-split-15',
#    'main-catalog-split-15',
#    'ndnp/dlc-2020_now',
#    'library-of-congress-washington-dc-awardee-8',
#    'sgpjicp/dlc',
#    'japanese-internment-camp-project'],
#   'callback': None,
#   'clip': None,
#   'clip_image_width': None,
#   'clip_rotation': None,
#   'content_filter': None,
#   'content_replacement': '',
#   'count': None,
#   'dates': None,
#   'default_count': 1,
#   'delimiter': None,
#   'digital_id': 'cph.3f05183',
#   'display_level': None,
#   'distance': None,
#   'downloadOption': None,
#   'duration': 0.9529364109039307,
#   'embed': [],
#   'embed!': [],
#   'error_response_status': None,
#   'excludeTerms': None,
#   'facetLimits': '',
#   'facetPrefix': None,
#   'facet_count': None,
#   'facet_style': None,
#   'field': None,
#   'format': 'json',
#   'host': 'www.loc.gov',
#   'ical': False,
#   'id': None,
#   'iiif': False,
#   'index': None,
#   'inputEncoding': 'UTF-8',
#   'item': None,
#   'items': None,
#   'keys': None,
#   'language': None,
#   'latlong': None,
#   'method': 'GET',
#   'newSearch': None,
#   'new_clip_url': False,
#   'onsite': False,
#   'operator': None,
#   'outputEncoding': 'UTF-8',
#   'page_campaigns': [],
#   'path_info': '/resource/cph.3f05183/',
#   'port': '443',
#   'proxypath': None,
#   'query_string': 'fo=json',
#   'redirect_proxy': False,
#   'redirect_to_item': None,
#   'referer': '',
#   'region': '',
#   'release_id': 123456789,
#   'request_host': 'www.loc.gov',
#   'request_params': {'fo': ['json']},
#   'request_url': 'https://www.loc.gov/resource/cph.3f05183/?fo=json',
#   'resource': '',
#   'resource_sequence': None,
#   'scheme': 'https',
#   'searchIn': None,
#   'searchTerms': '',
#   'segments': None,
#   'site_id': None,
#   'site_type': None,
#   'solrQuery': '',
#   'sortBy': None,
#   'sortOrder': None,
#   'startPage': None,
#   'style': None,
#   'suggested': None,
#   'target': None,
#   'template': 'resource/base',
#   'timestamp': 1759421470.5190594,
#   'tz_aware': None,
#   'unionFacets': '',
#   'webcast_permalink': None},
#  'page': [{'height': 150,
#    'levels': 1,
#    'mimetype': 'image/jpeg',
#    'size': 5043,
#    'url': 'https://tile.loc.gov/storage-services/service/pnp/cph/3f00000/3f05000/3f05100/3f05183_150px.jpg',
#    'width': 103},
#   {'height': 150,
#    'levels': 1,
#    'mimetype': 'image/gif',
#    'size': 12868,
#    'url': 'https://tile.loc.gov/storage-services/service/pnp/cph/3f00000/3f05000/3f05100/3f05183t.gif',
#    'width': 103},
#   {'height': 640,
#    'levels': 1,
#    'mimetype': 'image/jpeg',
#    'size': 32342,
#    'url': 'https://tile.loc.gov/storage-services/service/pnp/cph/3f00000/3f05000/3f05100/3f05183r.jpg',
#    'width': 440},
#   {'height': 1024,
#    'levels': 1,
#    'mimetype': 'image/jpeg',
#    'size': 123318,
#    'url': 'https://tile.loc.gov/storage-services/service/pnp/cph/3f00000/3f05000/3f05100/3f05183v.jpg',
#    'width': 705}],
#  'pagination': {'current': 1, 'next': None, 'previous': None, 'total': 1},
#  'related': {'group_record': None,
#   'lot_link': None,
#   'neighbors': 'https://www.loc.gov/pictures/related/?&co=wpapos&pk=98508155&st=gallery&sb=call_number#focus',
#   'survey_link': None},
#  'related_items': [{'access_restricted': False,
#    'aka': ['http://www.loc.gov/item/sn84025819/1900-01-27/ed-1/',
#     'http://www.loc.gov/resource/sn84025819/1900-01-27/ed-1/'],
#    'batch': ['dlc_bigstone_ver01'],
#    'campaigns': [],
#    'contributor': ['library of congress, washington, dc'],
#    'date': '1900-01-27',
#    'dates': ['1900-01-27'],
#    'description': ['Chicago, Ill.'],
#    'digitized': True,
#    'extract_timestamp': '2023-08-07T20:29:59.284Z',
#    'group': ['ndnp/dlc-2020_now',
#     'library-of-congress-washington-dc-awardee-8'],
#    'hassegments': True,
#    'id': 'http://www.loc.gov/item/sn84025819/1900-01-27/ed-1/',
#    'image_url': ['https://tile.loc.gov/image-services/iiif/service:ndnp:dlc:batch_dlc_bigstone_ver01:data:sn84025819:00220720457:1900012701:0001/full/pct:3.125/0/default.jpg#h=289&w=188',
#     'https://tile.loc.gov/image-services/iiif/service:ndnp:dlc:batch_dlc_bigstone_ver01:data:sn84025819:00220720457:1900012701:0001/full/pct:6.25/0/default.jpg#h=579&w=376',
#     'https://tile.loc.gov/image-services/iiif/service:ndnp:dlc:batch_dlc_bigstone_ver01:data:sn84025819:00220720457:1900012701:0001/full/pct:12.5/0/default.jpg#h=1159&w=752'],
#    'index': 1,
#    'language': ['english'],
#    'location': ['illinois', 'chicago', 'cook', 'united states', 'cook county'],
#    'mime_type': ['image/jp2', 'application/pdf', 'text/xml', 'image/jpeg'],
#    'number': ['00220720457', 'sn84025819', '1'],
#    'numeric_shelf_id': 190001271,
#    'online_format': ['image', 'pdf', 'online text'],
#    'original_format': ['newspaper'],
#    'partof': ['chronicling america',
#     'the chicago world (chicago, ill.) 1900-19??',
#     'serial and government publications division'],
#    'publication_frequency': ['weekly'],
#    'score': 27.373022,
#    'shelf_id': 'sn84025819, 1900-01-27, Edition 1',
#    'site': ['chroniclingamerica'],
#    'subject': ['illinois',
#     'chicago',
#     'cook',
#     'african american',
#     'newspapers',
#     'african american newspapers',
#     'african americans',
#     'cook county (ill.)',
#     'united states',
#     'chicago (ill.)',
#     'cook county'],
#    'timestamp': '2023-08-07T23:44:14.963Z',
#    'title': 'The Chicago world (Chicago, Ill.), January 27, 1900',
#    'type': ['issue'],
#    'url': 'https://www.loc.gov/item/sn84025819/1900-01-27/ed-1/'},
#   {'access_restricted': False,
#    'aka': ['http://www.loc.gov/item/sn84024048/1882-11-18/ed-1/',
#     'http://www.loc.gov/resource/sn84024048/1882-11-18/ed-1/'],
#    'batch': ['dlc_crater_ver01'],
#    'campaigns': [],
#    'contributor': ['library of congress, washington, dc'],
#    'date': '1882-11-18',
#    'dates': ['1882-11-18'],
#    'description': ['Chicago, Ill.'],
#    'digitized': True,
#    'extract_timestamp': '2023-08-07T20:30:34.324Z',
#    'group': ['ndnp/dlc-2020_now',
#     'library-of-congress-washington-dc-awardee-8'],
#    'hassegments': True,
#    'id': 'http://www.loc.gov/item/sn84024048/1882-11-18/ed-1/',
#    'image_url': ['https://tile.loc.gov/image-services/iiif/service:ndnp:dlc:batch_dlc_crater_ver01:data:sn84024048:00220720391:1882111801:0001/full/pct:3.125/0/default.jpg#h=275&w=203',
#     'https://tile.loc.gov/image-services/iiif/service:ndnp:dlc:batch_dlc_crater_ver01:data:sn84024048:00220720391:1882111801:0001/full/pct:6.25/0/default.jpg#h=550&w=407',
#     'https://tile.loc.gov/image-services/iiif/service:ndnp:dlc:batch_dlc_crater_ver01:data:sn84024048:00220720391:1882111801:0001/full/pct:12.5/0/default.jpg#h=1101&w=815'],
#    'index': 2,
#    'language': ['english'],
#    'location': ['united states', 'illinois', 'cook county', 'chicago'],
#    'mime_type': ['image/jp2', 'application/pdf', 'text/xml', 'image/jpeg'],
#    'number': ['sn84024048', '1', '00220720391'],
#    'numeric_shelf_id': 188211181,
#    'online_format': ['image', 'pdf', 'online text'],
#    'original_format': ['newspaper'],
#    'partof': ['chronicling america',
#     'serial and government publications division',
#     'the conservator (chicago, ill.) 18??-1???'],
#    'publication_frequency': ['weekly'],
#    'score': 27.373022,
#    'shelf_id': 'sn84024048, 1882-11-18, Edition 1',
#    'site': ['chroniclingamerica'],
#    'subject': ['illinois',
#     'chicago',
#     'african american',
#     'newspapers',
#     'united states',
#     'african americans',
#     'chicago (ill.)',
#     'cook county'],
#    'timestamp': '2023-08-08T02:12:11.475Z',
#    'title': 'The conservator (Chicago, Ill.), November 18, 1882',
#    'type': ['issue'],
#    'url': 'https://www.loc.gov/item/sn84024048/1882-11-18/ed-1/'},
#   {'access_restricted': False,
#    'aka': ['http://www.loc.gov/item/sn84024048/1882-12-23/ed-1/',
#     'http://www.loc.gov/resource/sn84024048/1882-12-23/ed-1/'],
#    'batch': ['dlc_crater_ver01'],
#    'campaigns': [],
#    'contributor': ['library of congress, washington, dc'],
#    'date': '1882-12-23',
#    'dates': ['1882-12-23'],
#    'description': ['Chicago, Ill.'],
#    'digitized': True,
#    'extract_timestamp': '2023-08-07T20:30:34.324Z',
#    'group': ['ndnp/dlc-2020_now',
#     'library-of-congress-washington-dc-awardee-8'],
#    'hassegments': True,
#    'id': 'http://www.loc.gov/item/sn84024048/1882-12-23/ed-1/',
#    'image_url': ['https://tile.loc.gov/image-services/iiif/service:ndnp:dlc:batch_dlc_crater_ver01:data:sn84024048:00220720391:1882122301:0001/full/pct:3.125/0/default.jpg#h=273&w=203',
#     'https://tile.loc.gov/image-services/iiif/service:ndnp:dlc:batch_dlc_crater_ver01:data:sn84024048:00220720391:1882122301:0001/full/pct:6.25/0/default.jpg#h=546&w=406',
#     'https://tile.loc.gov/image-services/iiif/service:ndnp:dlc:batch_dlc_crater_ver01:data:sn84024048:00220720391:1882122301:0001/full/pct:12.5/0/default.jpg#h=1092&w=812'],
#    'index': 3,
#    'language': ['english'],
#    'location': ['united states', 'illinois', 'cook county', 'chicago'],
#    'mime_type': ['image/jp2', 'application/pdf', 'text/xml', 'image/jpeg'],
#    'number': ['sn84024048', '1', '00220720391'],
#    'numeric_shelf_id': 188212231,
#    'online_format': ['image', 'pdf', 'online text'],
#    'original_format': ['newspaper'],
#    'partof': ['chronicling america',
#     'serial and government publications division',
#     'the conservator (chicago, ill.) 18??-1???'],
#    'publication_frequency': ['weekly'],
#    'score': 27.373022,
#    'shelf_id': 'sn84024048, 1882-12-23, Edition 1',
#    'site': ['chroniclingamerica'],
#    'subject': ['illinois',
#     'chicago',
#     'african american',
#     'newspapers',
#     'united states',
#     'african americans',
#     'chicago (ill.)',
#     'cook county'],
#    'timestamp': '2023-08-08T02:12:11.475Z',
#    'title': 'The conservator (Chicago, Ill.), December 23, 1882',
#    'type': ['issue'],
#    'url': 'https://www.loc.gov/item/sn84024048/1882-12-23/ed-1/'},
#   {'access_restricted': False,
#    'aka': ['http://www.loc.gov/item/sn84024048/1883-09-08/ed-1/',
#     'http://www.loc.gov/resource/sn84024048/1883-09-08/ed-1/'],
#    'batch': ['dlc_crater_ver01'],
#    'campaigns': [],
#    'contributor': ['library of congress, washington, dc'],
#    'date': '1883-09-08',
#    'dates': ['1883-09-08'],
#    'description': ['Chicago, Ill.'],
#    'digitized': True,
#    'extract_timestamp': '2023-08-07T20:30:34.324Z',
#    'group': ['ndnp/dlc-2020_now',
#     'library-of-congress-washington-dc-awardee-8'],
#    'hassegments': True,
#    'id': 'http://www.loc.gov/item/sn84024048/1883-09-08/ed-1/',
#    'image_url': ['https://tile.loc.gov/image-services/iiif/service:ndnp:dlc:batch_dlc_crater_ver01:data:sn84024048:00220720391:1883090801:0001/full/pct:3.125/0/default.jpg#h=273&w=203',
#     'https://tile.loc.gov/image-services/iiif/service:ndnp:dlc:batch_dlc_crater_ver01:data:sn84024048:00220720391:1883090801:0001/full/pct:6.25/0/default.jpg#h=547&w=406',
#     'https://tile.loc.gov/image-services/iiif/service:ndnp:dlc:batch_dlc_crater_ver01:data:sn84024048:00220720391:1883090801:0001/full/pct:12.5/0/default.jpg#h=1095&w=812'],
#    'index': 4,
#    'language': ['english'],
#    'location': ['united states', 'illinois', 'cook county', 'chicago'],
#    'mime_type': ['image/jp2', 'application/pdf', 'text/xml', 'image/jpeg'],
#    'number': ['sn84024048', '1', '00220720391'],
#    'numeric_shelf_id': 188309081,
#    'online_format': ['image', 'pdf', 'online text'],
#    'original_format': ['newspaper'],
#    'partof': ['chronicling america',
#     'serial and government publications division',
#     'the conservator (chicago, ill.) 18??-1???'],
#    'publication_frequency': ['weekly'],
#    'score': 27.373022,
#    'shelf_id': 'sn84024048, 1883-09-08, Edition 1',
#    'site': ['chroniclingamerica'],
#    'subject': ['illinois',
#     'chicago',
#     'african american',
#     'newspapers',
#     'united states',
#     'african americans',
#     'chicago (ill.)',
#     'cook county'],
#    'timestamp': '2023-08-08T02:12:11.475Z',
#    'title': 'The conservator (Chicago, Ill.), September 8, 1883',
#    'type': ['issue'],
#    'url': 'https://www.loc.gov/item/sn84024048/1883-09-08/ed-1/'},
#   {'access_restricted': False,
#    'aka': ['http://www.loc.gov/item/sn84024048/1886-12-18/ed-1/',
#     'http://www.loc.gov/resource/sn84024048/1886-12-18/ed-1/'],
#    'batch': ['dlc_crater_ver01'],
#    'campaigns': [],
#    'contributor': ['library of congress, washington, dc'],
#    'date': '1886-12-18',
#    'dates': ['1886-12-18'],
#    'description': ['Chicago, Ill.'],
#    'digitized': True,
#    'extract_timestamp': '2023-08-07T20:30:34.324Z',
#    'group': ['ndnp/dlc-2020_now',
#     'library-of-congress-washington-dc-awardee-8'],
#    'hassegments': True,
#    'id': 'http://www.loc.gov/item/sn84024048/1886-12-18/ed-1/',
#    'image_url': ['https://tile.loc.gov/image-services/iiif/service:ndnp:dlc:batch_dlc_crater_ver01:data:sn84024048:00220720391:1886121801:0001/full/pct:3.125/0/default.jpg#h=281&w=219',
#     'https://tile.loc.gov/image-services/iiif/service:ndnp:dlc:batch_dlc_crater_ver01:data:sn84024048:00220720391:1886121801:0001/full/pct:6.25/0/default.jpg#h=563&w=438',
#     'https://tile.loc.gov/image-services/iiif/service:ndnp:dlc:batch_dlc_crater_ver01:data:sn84024048:00220720391:1886121801:0001/full/pct:12.5/0/default.jpg#h=1127&w=876'],
#    'index': 5,
#    'language': ['english'],
#    'location': ['united states', 'illinois', 'cook county', 'chicago'],
#    'mime_type': ['image/jp2', 'application/pdf', 'text/xml', 'image/jpeg'],
#    'number': ['sn84024048', '1', '00220720391'],
#    'numeric_shelf_id': 188612181,
#    'online_format': ['image', 'pdf', 'online text'],
#    'original_format': ['newspaper'],
#    'partof': ['chronicling america',
#     'serial and government publications division',
#     'the conservator (chicago, ill.) 18??-1???'],
#    'publication_frequency': ['weekly'],
#    'score': 27.373022,
#    'shelf_id': 'sn84024048, 1886-12-18, Edition 1',
#    'site': ['chroniclingamerica'],
#    'subject': ['illinois',
#     'chicago',
#     'african american',
#     'newspapers',
#     'united states',
#     'african americans',
#     'chicago (ill.)',
#     'cook county'],
#    'timestamp': '2023-08-08T02:12:11.475Z',
#    'title': 'The conservator (Chicago, Ill.), December 18, 1886',
#    'type': ['issue'],
#    'url': 'https://www.loc.gov/item/sn84024048/1886-12-18/ed-1/'},
#   {'access_restricted': False,
#    'aka': ['http://www.loc.gov/item/sn83025518/1945-03-24/ed-1/',
#     'http://www.loc.gov/resource/sn83025518/1945-03-24/ed-1/'],
#    'batch': ['dlc_dupontcircle_ver01'],
#    'campaigns': [],
#    'contributor': ['library of congress, washington, dc'],
#    'date': '1945-03-24',
#    'dates': ['1945-03-24'],
#    'description': ['Denver, Colo.'],
#    'digitized': True,
#    'extract_timestamp': '2020-09-19T00:34:03.043Z',
#    'group': ['sgpjicp/dlc', 'japanese-internment-camp-project'],
#    'hassegments': True,
#    'id': 'http://www.loc.gov/item/sn83025518/1945-03-24/ed-1/',
#    'image_url': ['https://tile.loc.gov/image-services/iiif/service:sgp:sgpbatches:batch_dlc_dupontcircle_ver01:data:sn83025518:00237288701:1945032401:0047/full/pct:6.25/0/default.jpg#h=451&w=330',
#     'https://tile.loc.gov/image-services/iiif/service:sgp:sgpbatches:batch_dlc_dupontcircle_ver01:data:sn83025518:00237288701:1945032401:0047/full/pct:12.5/0/default.jpg#h=902&w=660'],
#    'index': 6,
#    'language': ['english', 'japanese'],
#    'location': ['denver',
#     'illinois',
#     'chicago',
#     'california',
#     'colorado',
#     'united states'],
#    'mime_type': ['image/jp2', 'application/pdf', 'text/xml', 'image/jpeg'],
#    'number': ['sn83025518', '00237288701', '1'],
#    'numeric_shelf_id': 194503241,
#    'online_format': ['image', 'pdf', 'online text'],
#    'original_format': ['newspaper'],
#    'other_title': ['格州時事 = Colorado times', 'Colorado times'],
#    'partof': ['chronicling america',
#     'kakushu jiji = colorado times (denver, colo.) 1918-1969',
#     'serial and government publications division',
#     'japanese-american internment camp newspapers, 1942-1946'],
#    'publication_frequency': ['triweekly'],
#    'score': 24.017845,
#    'shelf_id': 'sn83025518, 1945-03-24, Edition 1',
#    'site': ['chroniclingamerica'],
#    'subject': ['denver',
#     'illinois',
#     'chicago',
#     'california',
#     'denver (colo.)',
#     'colorado',
#     'japanese',
#     'newspapers',
#     'united states',
#     'japanese americans'],
#    'timestamp': '2022-11-17T20:43:43.240Z',
#    'title': 'Kakushu jiji = Colorado times (Denver, Colo.), March 24, 1945',
#    'type': ['issue'],
#    'url': 'https://www.loc.gov/item/sn83025518/1945-03-24/ed-1/'}],
#  'reproductions': '<p>If an image is displaying, you can download it yourself. (Some images \ndisplay only as thumbnails outside the Library of Congress because of rights \nconsiderations, but you have access to larger size images on site.)\n</p>\n\n<p>  \nAlternatively, you can purchase copies of various types through Library \nof Congress Duplication Services</a>.\n</p>\n\n<p> \n<ol>\n<p>\n<li><strong>If a digital image is displaying:</strong> The qualities of the digital image \npartially depend on whether it was made from the original or an \nintermediate such as a copy negative or transparency. If the Reproduction \nNumber field above includes a reproduction number that starts with \nLC-DIG..., then there is a digital image that was made directly \nfrom the original and is of sufficient resolution for most publication\n purposes.\n</li> \n</p>\n\n<li><strong>If there is information listed in the Reproduction Number field above:</strong> \nYou can use the reproduction number to purchase a copy from Duplication \nServices.  It will be made from the source listed in the parentheses after\n the number.  \n<p> \nIf only black-and-white (&quot;b&w&quot;) sources are listed and you \n desire a copy showing color or tint (assuming the original has any), \n you can generally purchase a quality copy of the original in color by \n citing the Call Number listed above and including the catalog record \n (&quot;About This Item&quot;) with your request.\n </p>\n</li>\n\n<li><strong>If there is no information listed in the Reproduction Number field \nabove:</strong> You can generally purchase a quality copy through \nDuplication Services. Cite the Call Number listed above and include the catalog record (&quot;About This Item&quot;) with \n your request.\n</li>\n</ol>\n</p>\n\n<p> \nPrice lists, contact information, and order forms are available on the\n <a href="//www.loc.gov/duplicationservices/">Duplication Services Web site</a>.  \n</p>\n\n\n\n',
#  'resource': {'caption': 'color film copy slide',
#   'image': 'https://tile.loc.gov/storage-services/service/pnp/cph/3f00000/3f05000/3f05100/3f05183_150px.jpg',
#   'segment_count': 1,
#   'url': 'https://www.loc.gov/resource/cph.3f05183/'},
#  'resources': [{'caption': 'color film copy slide',
#    'image': 'https://tile.loc.gov/storage-services/service/pnp/cph/3f00000/3f05000/3f05100/3f05183_150px.jpg',
#    'segment_count': 1,
#    'url': 'https://www.loc.gov/resource/cph.3f05183/'}],
#  'thesaurus_entry': None,
#  'timestamp': 1759421471472,
#  'type': 'legacyzoom',
#  'unrestricted': True,
#  'views': {'brief': 'https://www.loc.gov/resource/cph.3f05183/?fo=json&st=brief',
#   'current': 'single',
#   'epub': 'https://www.loc.gov/resource/cph.3f05183/?fo=json&st=pdf',
#   'gallery': 'https://www.loc.gov/resource/cph.3f05183/?fo=json&st=gallery',
#   'grid': 'https://www.loc.gov/resource/cph.3f05183/?fo=json&st=grid',
#   'image': 'https://www.loc.gov/resource/cph.3f05183/?fo=json&st=image',
#   'list': 'https://www.loc.gov/resource/cph.3f05183/?fo=json&st=list',
#   'pdf': 'https://www.loc.gov/resource/cph.3f05183/?fo=json&st=pdf',
#   'single': 'https://www.loc.gov/resource/cph.3f05183/?fo=json',
#   'slideshow': 'https://www.loc.gov/resource/cph.3f05183/?fo=json&st=slideshow',
#   'text': 'https://www.loc.gov/resource/cph.3f05183/?fo=json&st=text'}}

# %% [markdown]
# Permalink 1: https://lccn.loc.gov/98508155. Found using r.json() and then ctrl+F the output for the control number. Could also be found by just going to the LOC website but this seems more fun.

# %%
#request from item 2
r2 = requests.get(uri2, params=parameters)

#display returned data
r2.json()
# Out:
# {'articles_and_essays': None,
#  'cite_this': {'apa': 'Parks, G., photographer. (1943) <cite>Daytona Beach, Florida. Bethune-Cookman College. Students in the library reading room</cite>. United States Daytona Beach Florida Volusia County, 1943. Jan. [Photograph] Retrieved from the Library of Congress, https://www.loc.gov/item/2017843202/.',
#   'chicago': 'Parks, Gordon, photographer. <cite>Daytona Beach, Florida. Bethune-Cookman College. Students in the library reading room</cite>. United States Daytona Beach Florida Volusia County, 1943. Jan. Photograph. https://www.loc.gov/item/2017843202/.',
#   'mla': 'Parks, Gordon, photographer. <cite>Daytona Beach, Florida. Bethune-Cookman College. Students in the library reading room</cite>. Jan. Photograph. Retrieved from the Library of Congress, &lt;www.loc.gov/item/2017843202/&gt;.'},
#  'item': {'_version_': 1731151525508546560,
#   'access_restricted': False,
#   'aka': ['http://www.loc.gov/pictures/collection/fsa/item/2017843202/',
#    'http://www.loc.gov/item/2017843202/',
#    'http://www.loc.gov/pictures/item/2017843202/',
#    'https://hdl.loc.gov/loc.pnp/fsa.8d24709',
#    'http://www.loc.gov/resource/fsa.8d24709/',
#    'http://lccn.loc.gov/2017843202'],
#   'call_number': 'LC-USW3- 014835-E [P&P] LOT 682 (corresponding photographic print)',
#   'campaigns': [],
#   'contributor_names': ['Parks, Gordon, 1912-2006, photographer'],
#   'contributors': [{'parks, gordon': 'https://www.loc.gov/search/?fa=contributor:parks,+gordon&fo=json'}],
#   'control_number': '',
#   'created': '2017-09-26T03:37:57Z',
#   'created_published': ['1943 Jan.'],
#   'created_published_date': '1943 Jan.',
#   'date': '1943-01-01',
#   'dates': [{'1943': 'https://www.loc.gov/search/?dates=1943/1943&fo=json'}],
#   'description': ['1 negative : nitrate ; 2 1/4 x 2 1/4 inches or smaller.'],
#   'digital_id': ['fsa 8d24709 //hdl.loc.gov/loc.pnp/fsa.8d24709'],
#   'digitized': True,
#   'display_offsite': True,
#   'extract_timestamp': '2021-09-01T20:20:28.197Z',
#   'extract_urls': ['http://www.loc.gov/pictures/collection/fsa/item/2017843202/#fsa',
#    'http://lccn.loc.gov/2017843202#catalog-split-13'],
#   'format': [{'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}],
#   'format_headings': ['Nitrate negatives.'],
#   'genre': ['Nitrate negatives'],
#   'group': ['fsa',
#    'catalog-split-13',
#    'catalog',
#    'fsa-owi-black-and-white-negatives',
#    'main-catalog-split-13',
#    'main-catalog'],
#   'hassegments': False,
#   'id': 'http://www.loc.gov/item/2017843202/',
#   'image_url': ['https://tile.loc.gov/storage-services/service/pnp/fsa/8d24000/8d24700/8d24709_150px.jpg#h=150&w=143',
#    'https://tile.loc.gov/storage-services/service/pnp/fsa/8d24000/8d24700/8d24709t.gif#h=150&w=149',
#    'https://tile.loc.gov/storage-services/service/pnp/fsa/8d24000/8d24700/8d24709r.jpg#h=640&w=610',
#    'https://tile.loc.gov/storage-services/service/pnp/fsa/8d24000/8d24700/8d24709v.jpg#h=1024&w=976'],
#   'index': 1,
#   'item': {'call_number': 'LC-USW3- 014835-E [P&P] LOT 682 (corresponding photographic print)',
#    'contributors': ['Parks, Gordon, 1912-2006, photographer.'],
#    'control_number': '2017843202',
#    'created': '2017-09-26T03:37:57Z',
#    'created_published': '1943 Jan.',
#    'created_published_date': '1943 Jan.',
#    'creators': [{'link': '//www.loc.gov/pictures/related/?fi=name&q=Parks%2C%20Gordon%2C%201912-2006&co=fsa',
#      'role': 'photographer',
#      'title': 'Parks, Gordon, 1912-2006'}],
#    'date': '1943 Jan.',
#    'digital_id': ['fsa 8d24709 //hdl.loc.gov/loc.pnp/fsa.8d24709'],
#    'display_offsite': True,
#    'format': ['still image'],
#    'formats': [{'link': '//www.loc.gov/pictures/related/?fi=format&q=Nitrate%20negatives.&co=fsa',
#      'title': 'Nitrate negatives.'}],
#    'genre': ['Nitrate negatives'],
#    'id': '2017843202',
#    'language': ['eng'],
#    'link': '//www.loc.gov/pictures/item/2017843202/',
#    'marc': '//www.loc.gov/pictures/item/2017843202/marc/',
#    'medium': ['1 negative : nitrate ; 2 1/4 x 2 1/4 inches or smaller.'],
#    'medium_brief': '1 negative :',
#    'mediums': ['1 negative : nitrate ; 2 1/4 x 2 1/4 inches or smaller.'],
#    'modified': '2017-09-26T03:37:57Z',
#    'notes': ['Title and other information from caption card.',
#     'Transfer; United States. Office of War Information. Overseas Picture Division. Washington Division; 1944.',
#     'More information about the FSA/OWI Collection is available at http://hdl.loc.gov/loc.pnp/pp.fsaowi',
#     'Temp. note: owibatch3',
#     'Film copy on SIS roll 12, frame 598.'],
#    'number_former_id': ['https://www.loc.gov/item/2017843202',
#     'https://www.loc.gov/item/owi2001016932/PP'],
#    'other_control_numbers': ['20018380', 'owi2001016932/PP'],
#    'other_number': 'E 872',
#    'part_of': 'Farm Security Administration - Office of War Information photograph collection (Library of Congress)',
#    'place': [{'latitude': '',
#      'link': '//www.loc.gov/pictures/related/?fi=place&q=Florida--Volusia%20County--Daytona%20Beach&co=fsa',
#      'longitude': '',
#      'title': 'Florida--Volusia County--Daytona Beach'}],
#    'repository': 'Library of Congress Prints and Photographs Division Washington, D.C. 20540 USA http://hdl.loc.gov/loc.pnp/pp.print',
#    'reproduction_number': 'LC-DIG-fsa-8d24709 (digital file from original neg.)\nLC-USW3-014835-E (b&w film nitrate neg.)',
#    'resource_links': ['//hdl.loc.gov/loc.pnp/fsa.8d24709'],
#    'rights_advisory': 'No known restrictions. For information, see U.S. Farm Security Administration/Office of War Information Black & White Photographs https://www.loc.gov/rr/print/res/071_fsab.html',
#    'rights_information': 'No known restrictions. For information, see U.S. Farm Security Administration/Office of War Information Black & White Photographs https://www.loc.gov/rr/print/res/071_fsab.html',
#    'service_low': 'https://tile.loc.gov/storage-services/service/pnp/fsa/8d24000/8d24700/8d24709_150px.jpg',
#    'service_medium': 'https://tile.loc.gov/storage-services/service/pnp/fsa/8d24000/8d24700/8d24709r.jpg',
#    'sort_date': '1943',
#    'source_collection': ['Farm Security Administration - Office of War Information photograph collection (Library of Congress)'],
#    'source_created': '2001-08-03T00:00:00Z',
#    'source_modified': '2017-09-21T12:07:44Z',
#    'subject_headings': ['United States--Florida--Volusia County--Daytona Beach.',
#     'Florida--Volusia County--Daytona Beach'],
#    'subjects': ['United States--Florida--Volusia County--Daytona Beach'],
#    'thumb_gallery': 'https://tile.loc.gov/storage-services/service/pnp/fsa/8d24000/8d24700/8d24709_150px.jpg',
#    'title': 'Daytona Beach, Florida. Bethune-Cookman College. Students in the library reading room'},
#   'language': ['english'],
#   'languages': [{'english': 'https://www.loc.gov/search/?fa=language:english&fo=json'}],
#   'library_of_congress_control_number': '2017843202',
#   'link': '//www.loc.gov/pictures/item/2017843202/',
#   'location': ['united states', 'daytona beach', 'florida', 'volusia county'],
#   'location_city': ['daytona beach'],
#   'location_country': ['united states'],
#   'location_county': ['volusia county'],
#   'location_state': ['florida'],
#   'locations': [{'daytona beach': 'https://www.loc.gov/search/?fa=location:daytona+beach&fo=json'},
#    {'florida': 'https://www.loc.gov/search/?fa=location:florida&fo=json'},
#    {'united states': 'https://www.loc.gov/search/?fa=location:united+states&fo=json'},
#    {'volusia county': 'https://www.loc.gov/search/?fa=location:volusia+county&fo=json'}],
#   'locations_city': [{'daytona beach': 'https://www.loc.gov/search/?fa=location_city:daytona+beach&fo=json'}],
#   'locations_country': [{'united states': 'https://www.loc.gov/search/?fa=location_country:united+states&fo=json'}],
#   'locations_county': [{'volusia county': 'https://www.loc.gov/search/?fa=location_county:volusia+county&fo=json'}],
#   'locations_state': [{'florida': 'https://www.loc.gov/search/?fa=location_state:florida&fo=json'}],
#   'marc': '//www.loc.gov/pictures/item/2017843202/marc/',
#   'medium': ['1 negative : nitrate ; 2 1/4 x 2 1/4 inches or smaller.'],
#   'medium_brief': '1 negative :',
#   'mime_type': ['image/gif', 'image/jpg', 'image/tif'],
#   'modified': '2017-09-26T03:37:57Z',
#   'notes': ['Title and other information from caption card.',
#    'Transfer; United States. Office of War Information. Overseas Picture Division. Washington Division; 1944.',
#    'More information about the FSA/OWI Collection is available at http://hdl.loc.gov/loc.pnp/pp.fsaowi',
#    'Temp. note: owibatch3',
#    'Film copy on SIS roll 12, frame 598.'],
#   'number': ['2017-09-21t12:07:44',
#    'http://www.loc.gov/item/20018380',
#    '2017843202',
#    'http://www.loc.gov/item/owi2001016932/pp',
#    'http://www.loc.gov/item/2017843202'],
#   'number_former_id': ['http://www.loc.gov/item/20018380',
#    'http://www.loc.gov/item/owi2001016932/pp',
#    'http://www.loc.gov/item/2017843202'],
#   'number_lccn': ['2017843202'],
#   'number_source_modified': ['2017-09-21t12:07:44'],
#   'online_format': ['image'],
#   'original_format': ['photo, print, drawing'],
#   'other_control_numbers': ['20018380', 'owi2001016932/PP'],
#   'other_formats': [{'label': 'MARCXML Record',
#     'link': 'https://lccn.loc.gov/2017843202/marcxml'},
#    {'label': 'MODS Record', 'link': 'https://lccn.loc.gov/2017843202/mods'},
#    {'label': 'Dublin Core Record',
#     'link': 'https://lccn.loc.gov/2017843202/dc'}],
#   'other_number': 'E 872',
#   'partof': [{'count': 154,
#     'title': 'lot 682',
#     'url': 'https://www.loc.gov/search/?fa=partof:lot+682&fo=json'},
#    {'count': 171048,
#     'title': 'farm security administration/office of war information black-and-white negatives',
#     'url': 'https://www.loc.gov/collections/fsa-owi-black-and-white-negatives/?fo=json'},
#    {'count': 437933,
#     'title': 'american memory',
#     'url': 'https://www.loc.gov/search/?fa=partof:american+memory&fo=json'},
#    {'count': 934445,
#     'title': 'prints & photographs online catalog (library of congress)',
#     'url': 'https://www.loc.gov/search/?fa=partof:prints+%26+photographs+online+catalog+%28library+of+congress%29&fo=json'},
#    {'count': 1105005,
#     'title': 'prints and photographs division',
#     'url': 'https://www.loc.gov/search/?fa=partof:prints+and+photographs+division&fo=json'},
#    {'count': 1672342,
#     'title': 'catalog',
#     'url': 'https://www.loc.gov/search/?fa=partof:catalog&fo=json'}],
#   'place': [{'latitude': '',
#     'link': '//www.loc.gov/pictures/related/?fi=place&q=Florida--Volusia%20County--Daytona%20Beach&co=fsa',
#     'longitude': '',
#     'title': 'Florida--Volusia County--Daytona Beach'}],
#   'related': {'group_record': '//www.loc.gov/pictures/search/?q=LOT 682&fi=number&op=PHRASE&va=exact&co=coll&sg=true',
#    'neighbors': '//www.loc.gov/pictures/related/?&co=fsa&pk=2017843202&st=gallery&sb=call_number#focus'},
#   'repository': ['Library of Congress Prints and Photographs Division Washington, D.C. 20540 USA http://hdl.loc.gov/loc.pnp/pp.print'],
#   'reproduction_number': 'LC-DIG-fsa-8d24709 (digital file from original neg.)\nLC-USW3-014835-E (b&w film nitrate neg.)',
#   'reproductions': ['<p> If an image is displaying, you can download it yourself. (Some images display only as thumbnails outside the Library of Congress because of rights considerations, but you have access to larger size images on site.) </p>\n<p> Alternatively, you can purchase copies of various types through Library  of Congress Duplication Services. </p>\n<ol class="margin-bottom-single-li">\n\t<li> <strong>If a digital image is displaying:</strong> The qualities of the digital image partially depend on whether it was made from the original or an intermediate such as a copy negative or transparency. If the Reproduction Number field above includes a reproduction number that starts with LC-DIG..., then there is a digital image that was made directly from the original and is of sufficient resolution for most publication    purposes. </li>\n\t<li> <strong>If there is information listed in the Reproduction Number field above:</strong> You can use the reproduction number to purchase a copy from Duplication Services.  It will be made from the source listed in the parentheses after  the number.\n\t\t If only black-and-white ("b&amp;w") sources are listed and you desire a copy showing color or tint (assuming the original has any), you can generally purchase a quality copy of the original in color by citing the Call Number listed above and including the catalog record ("About This Item") with your request.\n\t</li>\n\t<li> <strong>If there is no information listed in the Reproduction Number field above:</strong> You can generally purchase a quality copy through Duplication Services. Cite the Call Number listed above and include the catalog record ("About This Item") with your request. </li>\n</ol>\n<p> Price lists, contact information, and order forms are available on the <a href="https://lcweb.loc.gov/preserv/pds/">Duplication Services Web site</a>. </p>\n<h4>Expect Delays in Service of Nitrate Negatives </h4>\n<p>Reproductions of all types are available, but Duplication Services anticipates an  8-10 week turnaround in completing orders, as all negatives must be reproduced at  their off-site, cold storage facility. </p>\n<p> Clues that an FSA/OWI/OEM image may be affected are:<br />\n\t<strong>Medium</strong> field says "1 negative : nitrate" OR <br />\n\t<strong>Reproduction Number</strong> field begins with: LC-USF33- </p>\n<p> If either is the case, you may wish to consult with Prints and Photographs Division reference staff (202-707-6394). In certain instances, duplicate negatives are available for copying. </p>\n'],
#   'resource_links': ['//hdl.loc.gov/loc.pnp/fsa.8d24709'],
#   'resources': [{'caption': 'digital file from original neg.',
#     'files': 1,
#     'image': 'https://tile.loc.gov/storage-services/service/pnp/fsa/8d24000/8d24700/8d24709_150px.jpg',
#     'url': 'https://www.loc.gov/resource/fsa.8d24709/'}],
#   'rights': ['<p>The contents of the Library of Congress Farm Security Administration/Office of War Information Black-and-White Negatives are in the public domain and are free to use and reuse.</p>\r\n<p> Credit Line: Library of Congress, Prints &amp; Photographs Division, Farm Security Administration/Office of War Information Black-and-White Negatives.</p>\r\n<p>For information about reproducing, publishing, and citing material from this collection, as well as access to the original items, see: <a href="https://www.loc.gov/rr/print/res/071_fsab.html">U.S. Farm Security Administration/Office of War Information Black &amp; White Photographs - Rights and Restrictions Information</a>\r\n</p>\r\n<p>More about <a href="/legal/">Copyright and other Restrictions</a> </p>\r\n<p>For guidance about compiling full citations consult <a href="https://www.loc.gov/teachers/usingprimarysources/citing.html">Citing Primary Sources</a>.</p>'],
#   'rights_advisory': 'No known restrictions. For information, see U.S. Farm Security Administration/Office of War Information Black & White Photographs https://www.loc.gov/rr/print/res/071_fsab.html',
#   'rights_information': 'No known restrictions. For information, see U.S. Farm Security Administration/Office of War Information Black & White Photographs https://www.loc.gov/rr/print/res/071_fsab.html',
#   'score': 19.262096,
#   'shard': '00',
#   'shelf_id': 'LC-USW3- 014835-E [P&P] LOT 682 (corresponding photographic print)',
#   'site': ['pictures', 'catalog'],
#   'sort_date': '1943',
#   'source_collection': 'Farm Security Administration - Office of War Information photograph collection (Library of Congress)',
#   'source_created': '2001-08-03T00:00:00Z',
#   'source_modified': '2017-09-21T12:07:44Z',
#   'subject': ['florida',
#    'united states',
#    'nitrate negatives',
#    'daytona beach',
#    'volusia county'],
#   'subject_headings': ['United States--Florida--Volusia County--Daytona Beach'],
#   'subjects': [{'daytona beach': 'https://www.loc.gov/search/?fa=subject:daytona+beach&fo=json'},
#    {'florida': 'https://www.loc.gov/search/?fa=subject:florida&fo=json'},
#    {'nitrate negatives': 'https://www.loc.gov/search/?fa=subject:nitrate+negatives&fo=json'},
#    {'united states': 'https://www.loc.gov/search/?fa=subject:united+states&fo=json'},
#    {'volusia county': 'https://www.loc.gov/search/?fa=subject:volusia+county&fo=json'}],
#   'thumb_gallery': 'https://tile.loc.gov/storage-services/service/pnp/fsa/8d24000/8d24700/8d24709_150px.jpg',
#   'timestamp': '2022-04-26T06:32:27.435Z',
#   'title': 'Daytona Beach, Florida. Bethune-Cookman College. Students in the library reading room',
#   'type': ['photo, print, drawing'],
#   'unrestricted': True,
#   'url': 'https://www.loc.gov/item/2017843202/'},
#  'more_like_this': [{'access_restricted': False,
#    'aka': ['http://www.loc.gov/pictures/collection/fsa/item/2017845200/',
#     'http://www.loc.gov/item/2017845200/',
#     'http://www.loc.gov/pictures/item/2017845200/',
#     'https://hdl.loc.gov/loc.pnp/fsa.8d25499',
#     'http://www.loc.gov/resource/fsa.8d25499/',
#     'http://lccn.loc.gov/2017845200'],
#    'campaigns': [],
#    'contributor': ['parks, gordon'],
#    'date': '1943-01-01',
#    'dates': ['1943'],
#    'description': ['1 negative : nitrate ; 2 1/4 x 2 1/4 inches or smaller.'],
#    'digitized': True,
#    'extract_timestamp': '2021-09-01T20:20:34.392Z',
#    'group': ['fsa',
#     'catalog-split-13',
#     'catalog',
#     'fsa-owi-black-and-white-negatives',
#     'main-catalog-split-13',
#     'main-catalog'],
#    'hassegments': False,
#    'id': 'http://www.loc.gov/item/2017845200/',
#    'image_url': ['https://tile.loc.gov/storage-services/service/pnp/fsa/8d25000/8d25400/8d25499_150px.jpg#h=150&w=146',
#     'https://tile.loc.gov/storage-services/service/pnp/fsa/8d25000/8d25400/8d25499t.gif#h=146&w=150',
#     'https://tile.loc.gov/storage-services/service/pnp/fsa/8d25000/8d25400/8d25499r.jpg#h=640&w=621',
#     'https://tile.loc.gov/storage-services/service/pnp/fsa/8d25000/8d25400/8d25499v.jpg#h=1024&w=994'],
#    'index': 1,
#    'language': ['english'],
#    'location': ['united states', 'daytona beach', 'florida', 'volusia county'],
#    'mime_type': ['image/gif', 'image/jpg', 'image/tif'],
#    'number': ['http://www.loc.gov/item/owi2001018930/pp',
#     '2017-09-21t12:27:52',
#     'http://www.loc.gov/item/20020445',
#     'http://www.loc.gov/item/2017845200',
#     '2017845200'],
#    'online_format': ['image'],
#    'original_format': ['photo, print, drawing'],
#    'partof': ['prints & photographs online catalog (library of congress)',
#     'catalog',
#     'lot 682',
#     'farm security administration/office of war information black-and-white negatives',
#     'american memory',
#     'prints and photographs division'],
#    'score': 58.66326,
#    'shelf_id': 'LC-USW3- 017051-E [P&P] LOT 682 (Location of corresponding print.) (corresponding photographic print)',
#    'site': ['pictures', 'catalog'],
#    'subject': ['florida',
#     'united states',
#     'nitrate negatives',
#     'daytona beach',
#     'volusia county'],
#    'timestamp': '2022-04-26T06:54:24.506Z',
#    'title': 'Daytona Beach, Florida. Bethune-Cookman College. Student choir singing on the campus',
#    'url': 'https://www.loc.gov/item/2017845200/'},
#   {'access_restricted': False,
#    'aka': ['http://www.loc.gov/pictures/collection/fsa/item/2017845202/',
#     'http://www.loc.gov/item/2017845202/',
#     'http://www.loc.gov/pictures/item/2017845202/',
#     'https://hdl.loc.gov/loc.pnp/fsa.8d25502',
#     'http://www.loc.gov/resource/fsa.8d25502/',
#     'http://lccn.loc.gov/2017845202'],
#    'campaigns': [],
#    'contributor': ['parks, gordon'],
#    'date': '1943-01-01',
#    'dates': ['1943'],
#    'description': ['1 negative : nitrate ; 2 1/4 x 2 1/4 inches or smaller.'],
#    'digitized': True,
#    'extract_timestamp': '2021-09-01T20:20:34.392Z',
#    'group': ['fsa',
#     'catalog-split-15',
#     'catalog',
#     'fsa-owi-black-and-white-negatives',
#     'main-catalog-split-15',
#     'main-catalog'],
#    'hassegments': False,
#    'id': 'http://www.loc.gov/item/2017845202/',
#    'image_url': ['https://tile.loc.gov/storage-services/service/pnp/fsa/8d25000/8d25500/8d25502_150px.jpg#h=150&w=137',
#     'https://tile.loc.gov/storage-services/service/pnp/fsa/8d25000/8d25500/8d25502t.gif#h=146&w=150',
#     'https://tile.loc.gov/storage-services/service/pnp/fsa/8d25000/8d25500/8d25502r.jpg#h=640&w=584',
#     'https://tile.loc.gov/storage-services/service/pnp/fsa/8d25000/8d25500/8d25502v.jpg#h=1024&w=934'],
#    'index': 2,
#    'language': ['english'],
#    'location': ['united states', 'daytona beach', 'florida', 'volusia county'],
#    'mime_type': ['image/gif', 'image/jpg', 'image/tif'],
#    'number': ['2017845202',
#     'http://www.loc.gov/item/20020447',
#     'http://www.loc.gov/item/2017845202',
#     '2017-09-21t12:27:54',
#     'http://www.loc.gov/item/owi2001018932/pp'],
#    'online_format': ['image'],
#    'original_format': ['photo, print, drawing'],
#    'partof': ['prints & photographs online catalog (library of congress)',
#     'catalog',
#     'lot 682',
#     'farm security administration/office of war information black-and-white negatives',
#     'american memory',
#     'prints and photographs division'],
#    'score': 58.66326,
#    'shelf_id': 'LC-USW3- 017053-E [P&P] LOT 682 (Location of corresponding print.) (corresponding photographic print)',
#    'site': ['pictures', 'catalog'],
#    'subject': ['florida',
#     'united states',
#     'nitrate negatives',
#     'daytona beach',
#     'volusia county'],
#    'timestamp': '2022-04-26T06:54:24.506Z',
#    'title': 'Daytona Beach, Florida. Bethune-Cookman College. Student chior singing on the campus',
#    'url': 'https://www.loc.gov/item/2017845202/'},
#   {'access_restricted': False,
#    'aka': ['http://www.loc.gov/pictures/collection/fsa/item/2017845203/',
#     'http://www.loc.gov/item/2017845203/',
#     'http://www.loc.gov/pictures/item/2017845203/',
#     'https://hdl.loc.gov/loc.pnp/fsa.8d25503',
#     'http://www.loc.gov/resource/fsa.8d25503/',
#     'http://lccn.loc.gov/2017845203'],
#    'campaigns': [],
#    'contributor': ['parks, gordon'],
#    'date': '1943-01-01',
#    'dates': ['1943'],
#    'description': ['1 negative : nitrate ; 2 1/4 x 2 1/4 inches or smaller.'],
#    'digitized': True,
#    'extract_timestamp': '2021-09-01T20:20:34.392Z',
#    'group': ['fsa',
#     'catalog-split-00',
#     'catalog',
#     'fsa-owi-black-and-white-negatives',
#     'main-catalog-split-00',
#     'main-catalog'],
#    'hassegments': False,
#    'id': 'http://www.loc.gov/item/2017845203/',
#    'image_url': ['https://tile.loc.gov/storage-services/service/pnp/fsa/8d25000/8d25500/8d25503_150px.jpg#h=145&w=150',
#     'https://tile.loc.gov/storage-services/service/pnp/fsa/8d25000/8d25500/8d25503t.gif#h=146&w=150',
#     'https://tile.loc.gov/storage-services/service/pnp/fsa/8d25000/8d25500/8d25503r.jpg#h=617&w=640',
#     'https://tile.loc.gov/storage-services/service/pnp/fsa/8d25000/8d25500/8d25503v.jpg#h=987&w=1024'],
#    'index': 3,
#    'language': ['english'],
#    'location': ['united states', 'daytona beach', 'florida', 'volusia county'],
#    'mime_type': ['image/gif', 'image/jpg', 'image/tif'],
#    'number': ['2017845203',
#     'http://www.loc.gov/item/2017845203',
#     '2017-09-21t12:27:55',
#     'http://www.loc.gov/item/owi2001018933/pp',
#     'http://www.loc.gov/item/20020448'],
#    'online_format': ['image'],
#    'original_format': ['photo, print, drawing'],
#    'partof': ['prints & photographs online catalog (library of congress)',
#     'catalog',
#     'lot 682',
#     'farm security administration/office of war information black-and-white negatives',
#     'american memory',
#     'prints and photographs division'],
#    'score': 58.66326,
#    'shelf_id': 'LC-USW3- 017054-E [P&P] LOT 682 (Location of corresponding print.) (corresponding photographic print)',
#    'site': ['pictures', 'catalog'],
#    'subject': ['florida',
#     'united states',
#     'nitrate negatives',
#     'daytona beach',
#     'volusia county'],
#    'timestamp': '2022-04-26T06:54:24.506Z',
#    'title': 'Daytona Beach, Florida. Bethune-Cookman College. Student chior singing on the campus',
#    'url': 'https://www.loc.gov/item/2017845203/'},
#   {'access_restricted': False,
#    'aka': ['http://www.loc.gov/pictures/collection/fsa/item/2017845204/',
#     'http://www.loc.gov/item/2017845204/',
#     'http://www.loc.gov/pictures/item/2017845204/',
#     'https://hdl.loc.gov/loc.pnp/fsa.8d25504',
#     'http://www.loc.gov/resource/fsa.8d25504/',
#     'http://lccn.loc.gov/2017845204'],
#    'campaigns': [],
#    'contributor': ['parks, gordon'],
#    'date': '1943-01-01',
#    'dates': ['1943'],
#    'description': ['1 negative : nitrate ; 2 1/4 x 2 1/4 inches or smaller.'],
#    'digitized': True,
#    'extract_timestamp': '2021-09-01T20:20:34.392Z',
#    'group': ['fsa',
#     'catalog-split-01',
#     'catalog',
#     'fsa-owi-black-and-white-negatives',
#     'main-catalog-split-01',
#     'main-catalog'],
#    'hassegments': False,
#    'id': 'http://www.loc.gov/item/2017845204/',
#    'image_url': ['https://tile.loc.gov/storage-services/service/pnp/fsa/8d25000/8d25500/8d25504_150px.jpg#h=148&w=150',
#     'https://tile.loc.gov/storage-services/service/pnp/fsa/8d25000/8d25500/8d25504t.gif#h=146&w=150',
#     'https://tile.loc.gov/storage-services/service/pnp/fsa/8d25000/8d25500/8d25504r.jpg#h=631&w=640',
#     'https://tile.loc.gov/storage-services/service/pnp/fsa/8d25000/8d25500/8d25504v.jpg#h=1010&w=1024'],
#    'index': 4,
#    'language': ['english'],
#    'location': ['united states', 'daytona beach', 'florida', 'volusia county'],
#    'mime_type': ['image/gif', 'image/jpg', 'image/tif'],
#    'number': ['http://www.loc.gov/item/20020449',
#     'http://www.loc.gov/item/2017845204',
#     '2019-02-13t08:38:15',
#     '2017845204',
#     'http://www.loc.gov/item/owi2001018934/pp'],
#    'online_format': ['image'],
#    'original_format': ['photo, print, drawing'],
#    'partof': ['prints & photographs online catalog (library of congress)',
#     'catalog',
#     'lot 682',
#     'farm security administration/office of war information black-and-white negatives',
#     'american memory',
#     'prints and photographs division'],
#    'score': 58.66326,
#    'shelf_id': 'LC-USW3- 017055-E [P&P] LOT 682 (Location of corresponding print.) (corresponding photographic print)',
#    'site': ['pictures', 'catalog'],
#    'subject': ['florida',
#     'united states',
#     'nitrate negatives',
#     'daytona beach',
#     'volusia county'],
#    'timestamp': '2022-04-26T06:54:24.506Z',
#    'title': 'Daytona Beach, Florida. Bethune-Cookman College. Student choir singing on the campus',
#    'url': 'https://www.loc.gov/item/2017845204/'},
#   {'access_restricted': False,
#    'aka': ['http://www.loc.gov/pictures/collection/fsa/item/2017845206/',
#     'http://www.loc.gov/item/2017845206/',
#     'http://www.loc.gov/pictures/item/2017845206/',
#     'https://hdl.loc.gov/loc.pnp/fsa.8d25506',
#     'http://www.loc.gov/resource/fsa.8d25506/',
#     'http://lccn.loc.gov/2017845206'],
#    'campaigns': [],
#    'contributor': ['parks, gordon'],
#    'date': '1943-01-01',
#    'dates': ['1943'],
#    'description': ['1 negative : nitrate ; 2 1/4 x 2 1/4 inches or smaller.'],
#    'digitized': True,
#    'extract_timestamp': '2021-09-01T20:20:34.392Z',
#    'group': ['fsa',
#     'catalog-split-03',
#     'catalog',
#     'fsa-owi-black-and-white-negatives',
#     'main-catalog-split-03',
#     'main-catalog'],
#    'hassegments': False,
#    'id': 'http://www.loc.gov/item/2017845206/',
#    'image_url': ['https://tile.loc.gov/storage-services/service/pnp/fsa/8d25000/8d25500/8d25506_150px.jpg#h=149&w=150',
#     'https://tile.loc.gov/storage-services/service/pnp/fsa/8d25000/8d25500/8d25506t.gif#h=146&w=150',
#     'https://tile.loc.gov/storage-services/service/pnp/fsa/8d25000/8d25500/8d25506r.jpg#h=635&w=640',
#     'https://tile.loc.gov/storage-services/service/pnp/fsa/8d25000/8d25500/8d25506v.jpg#h=1016&w=1024'],
#    'index': 5,
#    'language': ['english'],
#    'location': ['united states', 'daytona beach', 'florida', 'volusia county'],
#    'mime_type': ['image/gif', 'image/jpg', 'image/tif'],
#    'number': ['2017-09-21t12:27:57',
#     'http://www.loc.gov/item/2017845206',
#     'http://www.loc.gov/item/20020451',
#     'http://www.loc.gov/item/owi2001018936/pp',
#     '2017845206'],
#    'online_format': ['image'],
#    'original_format': ['photo, print, drawing'],
#    'partof': ['prints & photographs online catalog (library of congress)',
#     'catalog',
#     'lot 682',
#     'farm security administration/office of war information black-and-white negatives',
#     'american memory',
#     'prints and photographs division'],
#    'score': 58.66326,
#    'shelf_id': 'LC-USW3- 017057-E [P&P] LOT 682 (Location of corresponding print.) (corresponding photographic print)',
#    'site': ['pictures', 'catalog'],
#    'subject': ['florida',
#     'united states',
#     'nitrate negatives',
#     'daytona beach',
#     'volusia county'],
#    'timestamp': '2022-04-26T06:54:24.506Z',
#    'title': 'Daytona Beach, Florida. Bethune-Cookman College. Student choir singing on the campus',
#    'url': 'https://www.loc.gov/item/2017845206/'},
#   {'access_restricted': False,
#    'aka': ['http://www.loc.gov/pictures/collection/fsa/item/2017845213/',
#     'http://www.loc.gov/item/2017845213/',
#     'http://www.loc.gov/pictures/item/2017845213/',
#     'https://hdl.loc.gov/loc.pnp/fsa.8d25513',
#     'http://www.loc.gov/resource/fsa.8d25513/',
#     'http://lccn.loc.gov/2017845213'],
#    'campaigns': [],
#    'contributor': ['parks, gordon'],
#    'date': '1943-01-01',
#    'dates': ['1943'],
#    'description': ['1 negative : nitrate ; 2 1/4 x 2 1/4 inches or smaller.'],
#    'digitized': True,
#    'extract_timestamp': '2021-09-01T20:20:34.392Z',
#    'group': ['fsa',
#     'catalog-split-01',
#     'catalog',
#     'fsa-owi-black-and-white-negatives',
#     'main-catalog-split-01',
#     'main-catalog'],
#    'hassegments': False,
#    'id': 'http://www.loc.gov/item/2017845213/',
#    'image_url': ['https://tile.loc.gov/storage-services/service/pnp/fsa/8d25000/8d25500/8d25513_150px.jpg#h=150&w=139',
#     'https://tile.loc.gov/storage-services/service/pnp/fsa/8d25000/8d25500/8d25513t.gif#h=146&w=150',
#     'https://tile.loc.gov/storage-services/service/pnp/fsa/8d25000/8d25500/8d25513r.jpg#h=640&w=595',
#     'https://tile.loc.gov/storage-services/service/pnp/fsa/8d25000/8d25500/8d25513v.jpg#h=1024&w=952'],
#    'index': 6,
#    'language': ['english'],
#    'location': ['united states', 'daytona beach', 'florida', 'volusia county'],
#    'mime_type': ['image/gif', 'image/jpg', 'image/tif'],
#    'number': ['http://www.loc.gov/item/owi2001018943/pp',
#     '2017-09-21t12:28:03',
#     'http://www.loc.gov/item/2017845213',
#     'http://www.loc.gov/item/20020458',
#     '2017845213'],
#    'online_format': ['image'],
#    'original_format': ['photo, print, drawing'],
#    'partof': ['prints & photographs online catalog (library of congress)',
#     'catalog',
#     'lot 682',
#     'farm security administration/office of war information black-and-white negatives',
#     'american memory',
#     'prints and photographs division'],
#    'score': 58.66326,
#    'shelf_id': 'LC-USW3- 017064-E [P&P] LOT 682 (Location of corresponding print.) (corresponding photographic print)',
#    'site': ['pictures', 'catalog'],
#    'subject': ['florida',
#     'united states',
#     'nitrate negatives',
#     'daytona beach',
#     'volusia county'],
#    'timestamp': '2022-04-26T06:54:24.506Z',
#    'title': 'Daytona Beach, Florida. Bethune-Cookman College. Mr. Bond, dean of the college',
#    'url': 'https://www.loc.gov/item/2017845213/'}],
#  'notice': {'warning': 'Due to the temporary shutdown of the federal government beginning October 1, 2025, all Library of Congress buildings are closed and all public events are canceled until further notice. <a href="/item/prn-25-a05/">More</a>.\n'},
#  'options': {'access_group': [''],
#   'access_group_raw': '',
#   'all': None,
#   'api_version': '1',
#   'app_context': None,
#   'application_version': '$Revision$',
#   'attribute': None,
#   'attribute!': None,
#   'attribute_map': None,
#   'cache_tags': ['fsa',
#    'catalog-split-13',
#    'catalog',
#    'fsa-owi-black-and-white-negatives',
#    'main-catalog-split-13',
#    'main-catalog',
#    'catalog-split-15',
#    'main-catalog-split-15',
#    'catalog-split-00',
#    'main-catalog-split-00',
#    'catalog-split-01',
#    'main-catalog-split-01',
#    'catalog-split-03',
#    'main-catalog-split-03',
#    'ndnp/newspapers',
#    'united-states-newspaper-directory',
#    'newspaper-titles',
#    'catalog-split-06',
#    'main-catalog-split-06',
#    'gmd.mar',
#    'catalog-split-09',
#    'general-maps',
#    'main-catalog-split-09'],
#   'callback': None,
#   'clip': None,
#   'clip_image_width': None,
#   'clip_rotation': None,
#   'content_filter': None,
#   'content_replacement': '',
#   'count': None,
#   'dates': None,
#   'default_count': 1,
#   'delimiter': None,
#   'digital_id': 'fsa.8d24709',
#   'display_level': None,
#   'distance': None,
#   'downloadOption': None,
#   'duration': 0.7237589359283447,
#   'embed': [],
#   'embed!': [],
#   'error_response_status': None,
#   'excludeTerms': None,
#   'facetLimits': '',
#   'facetPrefix': None,
#   'facet_count': None,
#   'facet_style': None,
#   'field': None,
#   'format': 'json',
#   'host': 'www.loc.gov',
#   'ical': False,
#   'id': None,
#   'iiif': False,
#   'index': None,
#   'inputEncoding': 'UTF-8',
#   'item': None,
#   'items': None,
#   'keys': None,
#   'language': None,
#   'latlong': None,
#   'method': 'GET',
#   'newSearch': None,
#   'new_clip_url': False,
#   'onsite': False,
#   'operator': None,
#   'outputEncoding': 'UTF-8',
#   'page_campaigns': [],
#   'path_info': '/resource/fsa.8d24709/',
#   'port': '443',
#   'proxypath': None,
#   'query_string': 'fo=json',
#   'redirect_proxy': False,
#   'redirect_to_item': None,
#   'referer': '',
#   'region': '',
#   'release_id': 123456789,
#   'request_host': 'www.loc.gov',
#   'request_params': {'fo': ['json']},
#   'request_url': 'https://www.loc.gov/resource/fsa.8d24709/?fo=json',
#   'resource': '',
#   'resource_sequence': None,
#   'scheme': 'https',
#   'searchIn': None,
#   'searchTerms': '',
#   'segments': None,
#   'site_id': None,
#   'site_type': None,
#   'solrQuery': '',
#   'sortBy': None,
#   'sortOrder': None,
#   'startPage': None,
#   'style': None,
#   'suggested': None,
#   'target': None,
#   'template': 'resource/base',
#   'timestamp': 1759432110.0045986,
#   'tz_aware': None,
#   'unionFacets': '',
#   'webcast_permalink': None},
#  'page': [{'height': 0,
#    'levels': 1,
#    'mimetype': 'image/tiff',
#    'size': 25052676,
#    'url': 'https://tile.loc.gov/storage-services/master/pnp/fsa/8d24000/8d24700/8d24709u.tif',
#    'width': 0},
#   {'height': 0,
#    'levels': 1,
#    'mimetype': 'image/tiff',
#    'size': 50022390,
#    'url': 'https://tile.loc.gov/storage-services/master/pnp/fsa/8d24000/8d24700/8d24709a.tif',
#    'width': 0},
#   {'height': 150,
#    'levels': 1,
#    'mimetype': 'image/jpeg',
#    'size': 5526,
#    'url': 'https://tile.loc.gov/storage-services/service/pnp/fsa/8d24000/8d24700/8d24709_150px.jpg',
#    'width': 143},
#   {'height': 150,
#    'levels': 1,
#    'mimetype': 'image/gif',
#    'size': 24267,
#    'url': 'https://tile.loc.gov/storage-services/service/pnp/fsa/8d24000/8d24700/8d24709t.gif',
#    'width': 149},
#   {'height': 640,
#    'levels': 1,
#    'mimetype': 'image/jpeg',
#    'size': 43428,
#    'url': 'https://tile.loc.gov/storage-services/service/pnp/fsa/8d24000/8d24700/8d24709r.jpg',
#    'width': 610},
#   {'height': 1024,
#    'levels': 1,
#    'mimetype': 'image/jpeg',
#    'size': 255379,
#    'url': 'https://tile.loc.gov/storage-services/service/pnp/fsa/8d24000/8d24700/8d24709v.jpg',
#    'width': 976}],
#  'pagination': {'current': 1, 'next': None, 'previous': None, 'total': 1},
#  'related': {'group_record': '//www.loc.gov/pictures/search/?q=LOT 682&fi=number&op=PHRASE&va=exact&co=coll&sg=true',
#   'lot_link': None,
#   'neighbors': '//www.loc.gov/pictures/related/?&co=fsa&pk=2017843202&st=gallery&sb=call_number#focus',
#   'survey_link': None},
#  'related_items': [{'access_restricted': False,
#    'aka': ['http://www.loc.gov/item/2022239399/'],
#    'campaigns': [],
#    'date': '1903',
#    'dates': ['[1903 TO 1925]'],
#    'description': ['Daily (except Saturday), <1924>-1925 Began Dec. 1, 1903; ceased with vol. [21], no. 161 (Aug. 4, 1925). The Daytona Daily News began publishing in 1903. In August of 1925, following the vote to merge the Florida cities of Daytona, Daytona Beach and Seabreeze into the new city of Daytona Beach, the newspaper changed its name to the Daytona Beach News [LCCN: sn96027149], despite consolidation not being official until January 1, 1926. In 1927, the newspaper merged with the Daytona Beach (FL) Journal [LCCN sn96027151] to form the Daytona Beach (FL) News-Journal [LCCN sn96027152]. In 1936, the newspaper split into the Daytona Beach (FL) Evening News [LCCN sn96027153] and the Daytona Beach (FL) Morning Journal [LCCN sn93063708]. In 1986, the two newspapers merged back together to form the News-Journal (Daytona Beach, Fla.) [sn94057790], later returning to the name Daytona Beach (FL) News-Journal [2002058143] in 2001. Published: daily (except Sunday), December through March only, Dec. 1903-<Apr. 1917> (none issued in Dec. 1904; seasons ending in 1916-<1917> extended into April); every afternoon (except Sunday) of the year and Sunday morning for December through March only, <Oct. 1920-Feb. 1922>; every afternoon and Sunday morning, <May-Aug 12. 1923>; every afternoon (except Sunday) and Sunday morning, <Aug. 13-Nov. 1923>; every afternoon (except Saturday) and Sunday morning, <Oct. 1924>-Aug. 4, 1925. 1925 printed as vol. 20, but constitutes vol. 21. Weekly edition: Daytona gazette-news, 1903-1922. Vol. 2, no. 1 (January 2, 1905); title from banner (viewed August 12, 2022). Vol. [21], no. 161 (August 4, 1925) (viewed August 12, 2022). Daytona Beach news (DLC)  2022239400 (OCoLC)1290897826'],
#    'digitized': True,
#    'extract_timestamp': '2024-12-30T15:07:19.101Z',
#    'group': ['ndnp/newspapers', 'united-states-newspaper-directory'],
#    'hassegments': False,
#    'id': 'http://www.loc.gov/item/2022239399/',
#    'image_url': [],
#    'index': 1,
#    'language': ['english'],
#    'location': ['florida',
#     'volusia county',
#     'daytona beach',
#     'daytona',
#     'united states'],
#    'number': ['2024-12-20t12:37:18.550397',
#     '2022239399',
#     'online resource',
#     '904427875',
#     '2022239403',
#     '2022239400'],
#    'original_format': ['newspaper'],
#    'other_title': ['Sunday morning issues for <Jan. 2, 1921>-Oct. 14, 1923 titled: Sunday morning daily news',
#     'Daily news'],
#    'partof': ['serial and government publications division',
#     'directory of u.s. newspapers in american libraries',
#     'the daytona daily news (daytona, fla.) 1903-1925 [online resource]'],
#    'publication_frequency': ['daily'],
#    'score': 37.946877,
#    'shelf_id': 'AN2.F6.D39 N49 Internet Access AEU',
#    'site': ['usnd'],
#    'subject': ['daytona (fla.)',
#     'newspapers',
#     'florida',
#     'united states',
#     'electronic journals',
#     'daytona beach',
#     'periodicals',
#     'volusia county (fla.)',
#     'volusia county'],
#    'timestamp': '2025-03-17T22:09:21.061Z',
#    'title': 'The Daytona daily news',
#    'type': ['title'],
#    'url': 'https://www.loc.gov/item/2022239399/'},
#   {'access_restricted': False,
#    'aka': ['http://www.loc.gov/item/sn93063916/',
#     'http://lccn.loc.gov/sn93063916'],
#    'batch': ['fu_defuniak_ver01'],
#    'campaigns': [],
#    'date': '1903',
#    'description': ['Daily (except Saturday), <1924>-1925 Began Dec. 1, 1903; ceased with vol. [21], no. 161 (Aug. 4, 1925). "Published ... during December, January, February and March at the prettiest winter resort in Florida." Published: daily (except Sunday), December through March only, Dec. 1903-<Apr. 1917> (none issued in Dec. 1904; seasons ending in 1916-<1917> extended into April); every afternoon (except Sunday) of the year and Sunday morning for December through March only, <Oct. 1920-Feb. 1922>; every afternoon and Sunday morning, <May-Aug 12. 1923>; every afternoon (except Sunday) and Sunday morning, <Aug. 13-Nov. 1923>; every afternoon (except Saturday) and Sunday morning, <Oct. 1924>-Aug. 4, 1925. The Daytona Daily News began publishing in 1903. In August of 1925, following the vote to merge the Florida cities of Daytona, Daytona Beach and Seabreeze into the new city of Daytona Beach, the newspaper changed its name to the Daytona Beach News [LCCN: sn96027149], despite consolidation not being official until January 1, 1926. In 1927, the newspaper merged with the Daytona Beach (FL) Journal [LCCN sn96027151] to form the Daytona Beach (FL) News-Journal [LCCN sn96027152]. In 1936, the newspaper split into the Daytona Beach (FL) Evening News [LCCN sn96027153] and the Daytona Beach (FL) Morning Journal [LCCN sn93063708]. In 1986, the two newspapers merged back together to form the News-Journal (Daytona Beach, Fla.) [sn94057790], later returning to the name Daytona Beach (FL) News-Journal [2002058143] in 2001. 1925 printed as vol. 20, but constitutes vol. 21. Archived issues are available in digital format as part of the Library of Congress Chronicling America online collection. Weekly edition: Daytona gazette-news, 1903-1922. Vol. 2, no. 1 (Jan. 2, 1905). Vol. [21], no. 161 (Aug. 4, 1925) (surrogate). Daytona Beach news (DLC)sn 96027149 (OCoLC)1631353'],
#    'digitized': True,
#    'extract_timestamp': '2025-09-30T14:37:11.157Z',
#    'group': ['newspaper-titles',
#     'ndnp/newspapers',
#     'catalog-split-06',
#     'catalog',
#     'united-states-newspaper-directory',
#     'main-catalog-split-06'],
#    'hassegments': False,
#    'id': 'http://www.loc.gov/item/sn93063916/',
#    'image_url': [],
#    'index': 2,
#    'language': ['english'],
#    'latlong': [29.2070854, -81.0207257],
#    'location': ['florida',
#     'volusia county',
#     'daytona beach',
#     'daytona',
#     'united states'],
#    'location_str': '',
#    'lonlat': [-81.0207257, 29.2070854],
#    'number': ['1297',
#     'http://www.loc.gov/item/sn93063916/1922-02-27/ed-1/',
#     '2024-12-20t12:37:18.550397',
#     'http://www.loc.gov/item/sn93063916/1905-01-02/ed-1/',
#     '1',
#     '2151-5352',
#     'sn93063916',
#     '2025-05-09t13:39:59.158806',
#     '1631353',
#     'online resource',
#     '2023-12-16t15:23:22',
#     'sn93059208',
#     'sn95047376',
#     'new york state - ho5',
#     'original',
#     'sn96027149'],
#    'original_format': ['newspaper'],
#    'other_title': ['Sunday morning issues for <Jan. 2, 1921>-Oct. 14, 1923 titled: Sunday morning daily news',
#     'Daily news'],
#    'partof': ['catalog',
#     'directory of u.s. newspapers in american libraries',
#     'chronicling america',
#     'serial and government publications division',
#     'the daytona daily news (daytona, fla.) 1903-1925'],
#    'publication_frequency': ['daily'],
#    'score': 37.946877,
#    'shelf_id': 'Newspaper AN2.F6.D39 N49',
#    'site': ['chroniclingamerica', 'usnd', 'catalog'],
#    'subject': ['daytona (fla.)',
#     'newspapers',
#     'florida',
#     'united states',
#     'daytona beach',
#     'volusia county (fla.)',
#     'https://id.oclc.org/worldcat/entity/e39pbjhcd9mrpk6brj3yvcpbyd',
#     'https://id.oclc.org/worldcat/entity/e39pbjhdbtwcqqdyptjxwjfh4q',
#     'volusia county'],
#    'timestamp': '2025-09-30T15:09:00.468Z',
#    'title': 'The Daytona daily news',
#    'type': ['title'],
#    'url': 'https://www.loc.gov/item/sn93063916/'},
#   {'access_restricted': False,
#    'aka': ['http://www.loc.gov/item/2006626021/',
#     'https://hdl.loc.gov/loc.gmd/g3933v.la000083',
#     'http://www.loc.gov/resource/g3933v.la000083/',
#     'http://lccn.loc.gov/2006626021'],
#    'campaigns': [],
#    'contributor': ['rogers, d. d.'],
#    'date': '1883-01-01',
#    'dates': ['1883'],
#    'description': ['"Note - This map was compiled from the U.S. Land Maps, from the Coast Survey Charts, and from Private and Public Surveys made by D. D. Rogers, U.S. Deputy Surveyor in the past 8 years." LC Land ownership maps, 83 Available also through the Library of Congress Web site as a raster image. Includes ten views. Insets: "Town ship 17 South of Range 30 East of Volusia Co. Fla." and "Plan of the town of De Land in T17.S. of R.30.E."'],
#    'digitized': True,
#    'extract_timestamp': '2021-10-29T20:49:28.637Z',
#    'group': ['gmd.mar',
#     'catalog-split-09',
#     'catalog',
#     'general-maps',
#     'main-catalog-split-09',
#     'main-catalog'],
#    'hassegments': False,
#    'id': 'http://www.loc.gov/item/2006626021/',
#    'image_url': ['https://tile.loc.gov/storage-services/service/gmd/gmd393/g3933/g3933v/la000083.gif',
#     'https://tile.loc.gov/storage-services/service/gmd/gmd393/g3933/g3933v/la000083.gif#h=165&w=150',
#     'https://tile.loc.gov/image-services/iiif/service:gmd:gmd393:g3933:g3933v:la000083/full/pct:12.5/0/default.jpg#h=2608&w=2370',
#     'https://tile.loc.gov/image-services/iiif/service:gmd:gmd393:g3933:g3933v:la000083/full/pct:25/0/default.jpg#h=5216&w=4741'],
#    'index': 3,
#    'language': ['english'],
#    'location': ['united states', 'florida', 'volusia county'],
#    'mime_type': ['image/gif', 'image/tiff', 'image/jpeg', 'image/jp2'],
#    'number': ['2006-03-06t12:42:53',
#     'http://www.loc.gov/item/14235428',
#     'http://www.loc.gov/item/2006626021',
#     '2006626021'],
#    'online_format': ['image'],
#    'original_format': ['map'],
#    'partof': ['catalog',
#     'county landownership maps',
#     'cultural landscapes',
#     'american memory',
#     'geography and map division'],
#    'score': 25.53221,
#    'shelf_id': 'G3933.V6 1883 .R6',
#    'site': ['ammem', 'catalog'],
#    'subject': ['florida',
#     'united states',
#     'maps',
#     'volusia county (fla.)',
#     'volusia county'],
#    'timestamp': '2022-12-10T05:33:09.946Z',
#    'title': 'Map of Volusia County and vicinity Florida',
#    'type': ['cartographic'],
#    'url': 'https://www.loc.gov/item/2006626021/'},
#   {'access_restricted': False,
#    'aka': ['http://www.loc.gov/item/2007264076/'],
#    'campaigns': [],
#    'date': '1878',
#    'dates': ['[1878 TO 1911]'],
#    'description': ['Weekly Print began with v. 1, no. 1 (May 15, 1878); ceased with v. 38, no. 6 (June 1911). "A journal devoted to state interests." Published at Jacksonville and DeLand, <Nov. 1905-Aug. 1906>. Issues for <Nov. 1905-Aug. 1906> also have whole numbering; numbering is irregular. Description based on: Vol. 32, no. 44 (Nov. 1, 1905); title from PDF caption (Library of Congress Chronicling America online collection, viewed Dec. 5, 2007). Latest issue consulted: Vol. 33, no. 32 [i.e. 35] (Aug. 29, 1906).'],
#    'digitized': True,
#    'extract_timestamp': '2024-12-30T15:07:01.868Z',
#    'group': ['ndnp/newspapers', 'united-states-newspaper-directory'],
#    'hassegments': False,
#    'id': 'http://www.loc.gov/item/2007264076/',
#    'image_url': [],
#    'index': 4,
#    'language': ['english'],
#    'location': ['de land',
#     'florida',
#     'united states',
#     'duval',
#     'volusia',
#     'jacksonville',
#     'duval county',
#     'volusia county'],
#    'number': ['2024-12-20t12:37:18.550397',
#     'online resource',
#     '2007264076',
#     '182776228'],
#    'original_format': ['newspaper'],
#    'partof': ['the florida agriculturist (jacksonville, fla.) 1878-1911 [online resource]',
#     'directory of u.s. newspapers in american libraries',
#     'serial and government publications division'],
#    'publication_frequency': ['weekly'],
#    'score': 22.997766,
#    'shelf_id': 'https://s3.amazonaws.com/chronam-bib-derivatives/2007264076.xml',
#    'site': ['usnd'],
#    'subject': ['newspapers',
#     'duval county (fla.)',
#     'jacksonville (fla.)',
#     'volusia county (fla.)',
#     'agriculture',
#     'duval',
#     'https://id.oclc.org/worldcat/entity/e39pbjppymwqkdcr7ygf8r8kvc',
#     'duval county',
#     'https://id.oclc.org/worldcat/entity/e39pbjxxdhrxwvth3qhbmbgrbd',
#     'volusia county',
#     'de land',
#     'florida',
#     'volusia',
#     'https://id.oclc.org/worldcat/entity/e39pbjhcd9mrpk6brj3yvcpbyd',
#     'https://id.oclc.org/worldcat/entity/e39pbjgmh839rpx8dpmqwytcqq',
#     'https://id.oclc.org/worldcat/entity/e39qbtfrbghxpwb89fbdfychbm',
#     'jacksonville',
#     'de land (fla.)',
#     'united states'],
#    'timestamp': '2025-03-17T21:53:29.536Z',
#    'title': 'The Florida agriculturist',
#    'type': ['title'],
#    'url': 'https://www.loc.gov/item/2007264076/'},
#   {'access_restricted': False,
#    'aka': ['http://www.loc.gov/item/2022239402/'],
#    'campaigns': [],
#    'date': '1898',
#    'dates': ['[1898 TO 1901]'],
#    'description': ['Weekly Print began in December 1898; ceased with vol. 11, no. [33] (Jan. 26, 1901). The Coast gazette (Ormond, Fla.) began in Mar. 1890 and the Daytona news began in Sept. 1894. The two papers merged July 1895 to become Gazette-news (Daytona, Fla. : 1895). The paper then merged with the Commonwealth (Daytona, Fla.) in Aug. 1898 to become the Gazette-news and commonwealth, but the two papers separated again in Dec. 1898, becoming Gazette-news (Daytona, Fla.) and Commonwealth (Daytona, Fla. : 1898). The name was changed to Daytona gazette-news in Feb. 1902 and continued publication until 1922, when it ceased. From Dec. 1, 1903, to the end of publication, a daily edition of the paper was issued, the Daytona daily news. The daily edition continued to be published after the Daytona gazette-news ceased. January 26, 1901, printed as vol. 11, no. 32, but constitutes vol. 11, no. 33. Mode of access: World Wide Web. Vol. 11, no. 30 (Jan. 5, 1901); title from banner (viewed August 12, 2022). Vol. 11, no. [33] (Jan. 26, 1901) (viewed August 12, 2022). Daytona gazette-news (DLC)  2022239403 (OCoLC)463293508'],
#    'digitized': True,
#    'extract_timestamp': '2024-12-30T15:06:32.966Z',
#    'group': ['ndnp/newspapers', 'united-states-newspaper-directory'],
#    'hassegments': False,
#    'id': 'http://www.loc.gov/item/2022239402/',
#    'image_url': [],
#    'index': 5,
#    'language': ['english'],
#    'location': ['united states', 'florida', 'daytona', 'volusia county'],
#    'number': ['2024-12-20t12:37:18.550397',
#     '2022239402',
#     'online resource',
#     '463293509',
#     '2022239403'],
#    'original_format': ['newspaper'],
#    'partof': ['the gazette-news (daytona, fla.) 1898-1901 [online resource]',
#     'directory of u.s. newspapers in american libraries',
#     'serial and government publications division'],
#    'publication_frequency': ['weekly'],
#    'score': 22.997766,
#    'shelf_id': 'AN2.F6.D39 G39 Internet Access AEU',
#    'site': ['usnd'],
#    'subject': ['daytona (fla.)',
#     'newspapers',
#     'florida',
#     'united states',
#     'daytona',
#     'volusia county (fla.)',
#     'volusia county'],
#    'timestamp': '2025-03-17T22:09:21.061Z',
#    'title': 'The gazette-news',
#    'type': ['title'],
#    'url': 'https://www.loc.gov/item/2022239402/'},
#   {'access_restricted': False,
#    'aka': ['http://www.loc.gov/item/2022239403/'],
#    'campaigns': [],
#    'date': '1901',
#    'dates': ['[1901 TO 1922]'],
#    'description': ['Weekly Print began with vol. 11, no. 34 (February 2, 1901). Ceased in 1922? The Coast gazette (Ormond, Fla.) began in Mar. 1890 and the Daytona news began in Sept. 1894. The two papers merged July 1895 to become Gazette-news (Daytona, Fla. : 1895). The paper then merged with the Commonwealth (Daytona, Fla.) in Aug. 1898 to become the Gazette-news and commonwealth, but the two papers separated again in Dec. 1898, becoming Gazette-news (Daytona, Fla.) and Commonwealth (Daytona, Fla. : 1898). The name was changed to Daytona gazette-news in Feb. 1902 and continued publication until 1922, when it ceased. From Dec. 1, 1903, to the end of publication, a daily edition of the paper was issued, the Daytona daily news. The daily edition continued to be published after the Daytona gazette-news ceased. Mode of access: World Wide Web. Also issued in a daily edition as: Daytona daily news, 1903-1922. Vol. 11, no. 34 (February 2, 1901); title from banner (viewed August 12, 2022). Vol. 26, no. 33 (December 31, 1915) (viewed August 12, 2022).'],
#    'digitized': True,
#    'extract_timestamp': '2024-12-30T15:07:16.047Z',
#    'group': ['ndnp/newspapers', 'united-states-newspaper-directory'],
#    'hassegments': False,
#    'id': 'http://www.loc.gov/item/2022239403/',
#    'image_url': [],
#    'index': 6,
#    'language': ['english'],
#    'location': ['florida',
#     'volusia county',
#     'ormond',
#     'daytona',
#     'united states'],
#    'number': ['463293508',
#     '2024-12-20t12:37:18.550397',
#     '2022239402',
#     '2022239399',
#     'online resource',
#     '2022239403'],
#    'original_format': ['newspaper'],
#    'other_title': ['Issues for Dec. 11, 1909-July 16, 1910 include an additional section with title: Ormond gazette-news',
#     'Gazette-news'],
#    'partof': ['serial and government publications division',
#     'the daytona gazette-news (daytona, fla.) 1901-1922 [online resource]',
#     'directory of u.s. newspapers in american libraries'],
#    'publication_frequency': ['weekly'],
#    'score': 22.997766,
#    'shelf_id': 'AN2.F6.D39 G39 Internet Access AEU',
#    'site': ['usnd'],
#    'subject': ['daytona (fla.)',
#     'newspapers',
#     'florida',
#     'united states',
#     'ormond',
#     'daytona',
#     'volusia county (fla.)',
#     'ormond (fla.)',
#     'volusia county'],
#    'timestamp': '2025-03-17T22:09:21.061Z',
#    'title': 'The Daytona gazette-news',
#    'type': ['title'],
#    'url': 'https://www.loc.gov/item/2022239403/'}],
#  'reproductions': '<p>\n    If an image is displaying, you can download it yourself. (Some images \n    display only as thumbnails outside the Library of Congress because of rights \n    considerations, but you have access to larger size images on site.)\n</p>\n<p>\nAlternatively, you can purchase copies of various types through Library \nof Congress Duplication Services</a>.\n</p>\n<p>\n    <ol>\n        <p>\n            <li>\n                <strong>If a digital image is displaying:</strong>\n                The qualities of the digital image \n                partially depend on whether it was made from the original or an  \n                intermediate such as a copy negative or transparency. If the Reproduction \n                Number field above includes a reproduction number that starts with  \n                LC-DIG..., then there is a digital image that was made directly \n                from the original and is of sufficient resolution for most publication\n                purposes.\n            </li>\n        </p>\n        <li>\n            <strong>If there is information listed in the Reproduction Number field above:</strong>\n            You can use the reproduction number to purchase a copy from Duplication \n            Services.  It will be made from the source listed in the parentheses after  \n            the number. \n            <table width="75%" border="1" align="center" cellpadding="1" bordercolor="#993333">\n                <tr>\n                    <td>\n                        <p>\n                            <strong>\n                                <center>\n                                    Expect\n                                    Delays in Service of Nitrate Negatives\n                                </center>\n                            </strong>\n                        </p>\n\t\t\t\t\t\t\n<p>\t\t\t\t\t\t\nReproductions of all types are available, but Duplication Services anticipates an \n8-10 week turnaround in completing orders, as all negatives must be reproduced at \ntheir off-site, cold storage facility.\n</p>\n<p>\nClues that an FSA/OWI/OEM image may be affected are:<br />\n<strong>Medium</strong> field says "1 negative : nitrate" OR <br />\n<strong>Reproduction Number</strong> field begins with: LC-USF33- \n</p>\n              \n                        <p>\n                            If either is the case, you may wish to consult\n                            with Prints and Photographs Division reference staff\n                            (202-707-6394). In certain instances, duplicate\n                            negatives are available for copying.\n                        </p>\n                    </td>\n                </tr>\n            </table>\n            <p>\n                If only black-and-white (&quot;b&w&quot;) sources are listed and you \n                desire a copy showing color or tint (assuming the original has any),  \n                you can generally purchase a quality copy of the original in color by \n                citing the Call Number listed above and including the catalog record \n                (&quot;About This Item&quot;) with your request.\n            </p>\n        </li>\n        <li>\n            <strong>If there is no information listed in the Reproduction Number field \n                above:</strong>\n            You can generally purchase a quality copy through \n            Duplication Services. Cite the Call Number listed above and include the catalog record (&quot;About This Item&quot;) with \n            your request.\n        </li>\n    </ol>\n</p>\n<p>\n    Price lists, contact information, and order forms are available on the<a href="//lcweb.loc.gov/preserv/pds/">Duplication Services Web site</a>. \n</p>\n',
#  'resource': {'caption': 'digital file from original neg.',
#   'image': 'https://tile.loc.gov/storage-services/service/pnp/fsa/8d24000/8d24700/8d24709_150px.jpg',
#   'segment_count': 1,
#   'url': 'https://www.loc.gov/resource/fsa.8d24709/'},
#  'resources': [{'caption': 'digital file from original neg.',
#    'image': 'https://tile.loc.gov/storage-services/service/pnp/fsa/8d24000/8d24700/8d24709_150px.jpg',
#    'segment_count': 1,
#    'url': 'https://www.loc.gov/resource/fsa.8d24709/'}],
#  'thesaurus_entry': None,
#  'timestamp': 1759432110728,
#  'type': 'legacyzoom',
#  'unrestricted': True,
#  'views': {'brief': 'https://www.loc.gov/resource/fsa.8d24709/?fo=json&st=brief',
#   'current': 'single',
#   'epub': 'https://www.loc.gov/resource/fsa.8d24709/?fo=json&st=pdf',
#   'gallery': 'https://www.loc.gov/resource/fsa.8d24709/?fo=json&st=gallery',
#   'grid': 'https://www.loc.gov/resource/fsa.8d24709/?fo=json&st=grid',
#   'image': 'https://www.loc.gov/resource/fsa.8d24709/?fo=json&st=image',
#   'list': 'https://www.loc.gov/resource/fsa.8d24709/?fo=json&st=list',
#   'pdf': 'https://www.loc.gov/resource/fsa.8d24709/?fo=json&st=pdf',
#   'single': 'https://www.loc.gov/resource/fsa.8d24709/?fo=json',
#   'slideshow': 'https://www.loc.gov/resource/fsa.8d24709/?fo=json&st=slideshow',
#   'text': 'https://www.loc.gov/resource/fsa.8d24709/?fo=json&st=text'}}

# %% [markdown]
# Permalink 2: https://lccn.loc.gov/2017843202

# %%
#request from item 3
r3 = requests.get(uri3, params=parameters)

#display returned data
r3.json()
# Out:
# {'articles_and_essays': None,
#  'cite_this': {'apa': 'Highsmith, C. M., photographer. (2020) <cite>An appropriately decorated "Bookmobile" bus belonging to the Perry County Public Library in Hazard, a coal town of 4,500 or so population in the hills of southeastern Kentucky</cite>. United States Perry County Kentucky Hazard, 2020. -07-19. [Photograph] Retrieved from the Library of Congress, https://www.loc.gov/item/2020722343/.',
#   'chicago': 'Highsmith, Carol M, photographer. <cite>An appropriately decorated "Bookmobile" bus belonging to the Perry County Public Library in Hazard, a coal town of 4,500 or so population in the hills of southeastern Kentucky</cite>. United States Perry County Kentucky Hazard, 2020. -07-19. Photograph. https://www.loc.gov/item/2020722343/.',
#   'mla': 'Highsmith, Carol M, photographer. <cite>An appropriately decorated "Bookmobile" bus belonging to the Perry County Public Library in Hazard, a coal town of 4,500 or so population in the hills of southeastern Kentucky</cite>. -07-19. Photograph. Retrieved from the Library of Congress, &lt;www.loc.gov/item/2020722343/&gt;.'},
#  'item': {'_version_': 1730914868142276608,
#   'access_restricted': False,
#   'aka': ['https://www.loc.gov/pictures/item/2020722343/',
#    'http://www.loc.gov/item/2020722343/',
#    'http://www.loc.gov/pictures/item/2020722343/',
#    'https://www.loc.gov/pictures/collection/highsm/item/2020722343/',
#    'http://www.loc.gov/pictures/collection/highsm/item/2020722343/',
#    'https://hdl.loc.gov/loc.pnp/highsm.64003',
#    'https://hdl.loc.gov/loc.pnp/highsm.64003',
#    'http://www.loc.gov/resource/highsm.64003/',
#    'http://lccn.loc.gov/2020722343'],
#   'call_number': 'LC-DIG-highsm- 64003 (ONLINE) [P&P]',
#   'campaigns': [],
#   'contributor_names': ['Highsmith, Carol M., 1946-, photographer'],
#   'contributors': [{'highsmith, carol m.': 'https://www.loc.gov/search/?fa=contributor:highsmith,+carol+m.&fo=json'}],
#   'control_number': '',
#   'created': '2020-12-01T07:00:24Z',
#   'created_published': ['2020-07-19.'],
#   'created_published_date': '2020-07-19.',
#   'date': '2020-01-01',
#   'dates': [{'2020': 'https://www.loc.gov/search/?dates=2020/2020&fo=json'}],
#   'description': ['1 photograph : digital, tiff file, color.'],
#   'digital_id': ['highsm 64003 https://hdl.loc.gov/loc.pnp/highsm.64003'],
#   'digitized': True,
#   'display_offsite': True,
#   'extract_timestamp': '2021-08-31T05:27:20.532Z',
#   'extract_urls': ['http://www.loc.gov/pictures/collection/highsm/item/2020722343/#highsm',
#    'http://lccn.loc.gov/2020722343#catalog-split-09'],
#   'format': [{'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}],
#   'format_headings': ['Digital photographs--Color--2020.'],
#   'genre': ['Digital photographs--Color--2020'],
#   'group': ['highsm',
#    'catalog-split-09',
#    'catalog',
#    'carol-m-highsmith',
#    'main-catalog-split-09',
#    'main-catalog'],
#   'hassegments': False,
#   'id': 'http://www.loc.gov/item/2020722343/',
#   'image_url': ['https://tile.loc.gov/storage-services/service/pnp/highsm/64000/64003_150px.jpg#h=113&w=150',
#    'https://tile.loc.gov/storage-services/service/pnp/highsm/64000/64003r.jpg#h=480&w=640',
#    'https://tile.loc.gov/storage-services/service/pnp/highsm/64000/64003v.jpg#h=768&w=1024'],
#   'index': 1,
#   'item': {'call_number': 'LC-DIG-highsm- 64003 (ONLINE) [P&P]',
#    'contributors': ['Highsmith, Carol M., 1946- photographer.'],
#    'control_number': '2020722343',
#    'created': '2020-12-01T07:00:24Z',
#    'created_published': '2020-07-19.',
#    'created_published_date': '2020-07-19.',
#    'creators': [{'link': 'https://www.loc.gov/pictures/related/?fi=name&q=Highsmith%2C%20Carol%20M.%2C%201946-&co=highsm',
#      'role': 'photographer',
#      'title': 'Highsmith, Carol M., 1946-'}],
#    'date': '2020-07-19.',
#    'digital_id': ['highsm 64003 https://hdl.loc.gov/loc.pnp/highsm.64003'],
#    'display_offsite': True,
#    'format': ['still image'],
#    'formats': [{'link': 'https://www.loc.gov/pictures/related/?fi=format&q=Digital%20photographs--Color--2020.&co=highsm',
#      'title': 'Digital photographs--Color--2020.'}],
#    'genre': ['Digital photographs--Color--2020'],
#    'id': '2020722343',
#    'language': ['eng'],
#    'link': 'https://www.loc.gov/pictures/item/2020722343/',
#    'marc': 'https://www.loc.gov/pictures/item/2020722343/marc/',
#    'medium': ['1 photograph : digital, tiff file, color.'],
#    'medium_brief': '1 photograph :',
#    'mediums': ['1 photograph : digital, tiff file, color.'],
#    'modified': '2020-12-01T07:00:26Z',
#    'notes': ['Title, date, keywords, and additional description details based on information provided by the photographer.',
#     'The small city was named for Oliver Hazard Perry (and the surrounding county is Perry County). Perry was a prominent naval hero in the early years of the American nation, famous for popularizing another mariner\'s cry, "Don\'t give up the ship."',
#     'Purchase; Carol M. Highsmith Photography, Inc.; 2020; (DLC/PP-2020:047).',
#     "Forms part of Carol M. Highsmith's America Project in the Carol M. Highsmith Archive."],
#    'other_control_numbers': ['21812411'],
#    'part_of': 'Highsmith, Carol M., 1946- Carol M. Highsmith Archive.',
#    'place': [{'latitude': '',
#      'link': 'https://www.loc.gov/pictures/related/?fi=place&q=Kentucky%20--Perry%20County%20--Hazard&co=highsm',
#      'longitude': '',
#      'title': 'Kentucky --Perry County --Hazard'}],
#    'repository': 'Library of Congress Prints and Photographs Division Washington, D.C. 20540 USA https://hdl.loc.gov/loc.pnp/pp.print',
#    'reproduction_number': 'LC-DIG-highsm-64003 (original digital file)',
#    'resource_links': ['https://hdl.loc.gov/loc.pnp/highsm.64003'],
#    'rights_advisory': 'No known restrictions on publication.',
#    'rights_information': 'No known restrictions on publication.',
#    'service_low': 'https://tile.loc.gov/storage-services/service/pnp/highsm/64000/64003_150px.jpg',
#    'service_medium': 'https://tile.loc.gov/storage-services/service/pnp/highsm/64000/64003r.jpg',
#    'sort_date': '2020',
#    'source_collection': ['Highsmith, Carol M., 1946- Carol M. Highsmith Archive.'],
#    'source_created': '2020-11-10T00:00:00Z',
#    'source_modified': '2020-11-24T08:53:19Z',
#    'subject_headings': ['United States--Kentucky --Perry County --Hazard.',
#     'America',
#     'Bookmobiles',
#     'Perry County Public Library',
#     'Oliver Hazard Perry',
#     'Kentucky --Perry County --Hazard'],
#    'subjects': ['United States--Kentucky --Perry County --Hazard',
#     'America',
#     'Bookmobiles',
#     'Perry County Public Library',
#     'Oliver Hazard Perry'],
#    'thumb_gallery': 'https://tile.loc.gov/storage-services/service/pnp/highsm/64000/64003_150px.jpg',
#    'title': 'An appropriately decorated "Bookmobile" bus belonging to the Perry County Public Library in Hazard, a coal town of 4,500 or so population in the hills of southeastern Kentucky'},
#   'language': ['english'],
#   'languages': [{'english': 'https://www.loc.gov/search/?fa=language:english&fo=json'}],
#   'library_of_congress_control_number': '2020722343',
#   'link': 'https://www.loc.gov/pictures/item/2020722343/',
#   'location': ['united states', 'perry county', 'kentucky', 'hazard'],
#   'location_city': ['hazard'],
#   'location_country': ['united states'],
#   'location_county': ['perry county'],
#   'location_state': ['kentucky'],
#   'locations': [{'hazard': 'https://www.loc.gov/search/?fa=location:hazard&fo=json'},
#    {'kentucky': 'https://www.loc.gov/search/?fa=location:kentucky&fo=json'},
#    {'perry county': 'https://www.loc.gov/search/?fa=location:perry+county&fo=json'},
#    {'united states': 'https://www.loc.gov/search/?fa=location:united+states&fo=json'}],
#   'locations_city': [{'hazard': 'https://www.loc.gov/search/?fa=location_city:hazard&fo=json'}],
#   'locations_country': [{'united states': 'https://www.loc.gov/search/?fa=location_country:united+states&fo=json'}],
#   'locations_county': [{'perry county': 'https://www.loc.gov/search/?fa=location_county:perry+county&fo=json'}],
#   'locations_state': [{'kentucky': 'https://www.loc.gov/search/?fa=location_state:kentucky&fo=json'}],
#   'marc': 'https://www.loc.gov/pictures/item/2020722343/marc/',
#   'medium': ['1 photograph : digital, tiff file, color.'],
#   'medium_brief': '1 photograph :',
#   'mime_type': ['image/gif', 'image/jpg', 'image/tif'],
#   'modified': '2020-12-01T07:00:26Z',
#   'notes': ['Title, date, keywords, and additional description details based on information provided by the photographer.',
#    'The small city was named for Oliver Hazard Perry (and the surrounding county is Perry County). Perry was a prominent naval hero in the early years of the American nation, famous for popularizing another mariner\'s cry, "Don\'t give up the ship."',
#    'Purchase; Carol M. Highsmith Photography, Inc.; 2020; (DLC/PP-2020:047).',
#    "Forms part of Carol M. Highsmith's America Project in the Carol M. Highsmith Archive."],
#   'number': ['2020-11-24t08:53:19',
#    'http://www.loc.gov/item/21812411',
#    'online resource',
#    '2020722343'],
#   'number_carrier_type': ['online resource'],
#   'number_former_id': ['http://www.loc.gov/item/21812411'],
#   'number_lccn': ['2020722343'],
#   'number_source_modified': ['2020-11-24t08:53:19'],
#   'online_format': ['image'],
#   'original_format': ['photo, print, drawing'],
#   'other_control_numbers': ['21812411'],
#   'other_formats': [{'label': 'MARCXML Record',
#     'link': 'https://lccn.loc.gov/2020722343/marcxml'},
#    {'label': 'MODS Record', 'link': 'https://lccn.loc.gov/2020722343/mods'},
#    {'label': 'Dublin Core Record',
#     'link': 'https://lccn.loc.gov/2020722343/dc'}],
#   'partof': [{'count': 70224,
#     'title': 'highsmith (carol m.) archive',
#     'url': 'https://www.loc.gov/collections/carol-m-highsmith/?fo=json'},
#    {'count': 934445,
#     'title': 'prints & photographs online catalog (library of congress)',
#     'url': 'https://www.loc.gov/search/?fa=partof:prints+%26+photographs+online+catalog+%28library+of+congress%29&fo=json'},
#    {'count': 1105005,
#     'title': 'prints and photographs division',
#     'url': 'https://www.loc.gov/search/?fa=partof:prints+and+photographs+division&fo=json'},
#    {'count': 1672342,
#     'title': 'catalog',
#     'url': 'https://www.loc.gov/search/?fa=partof:catalog&fo=json'}],
#   'place': [{'latitude': '',
#     'link': 'https://www.loc.gov/pictures/related/?fi=place&q=Kentucky%20--Perry%20County%20--Hazard&co=highsm',
#     'longitude': '',
#     'title': 'Kentucky --Perry County --Hazard'}],
#   'related': {'neighbors': 'https://www.loc.gov/pictures/related/?&co=highsm&pk=2020722343&st=gallery&sb=call_number#focus'},
#   'repository': ['Library of Congress Prints and Photographs Division Washington, D.C. 20540 USA https://hdl.loc.gov/loc.pnp/pp.print'],
#   'reproduction_number': 'LC-DIG-highsm-64003 (original digital file)',
#   'reproductions': ['<p>Some images in this collection are described in groups; others are  described individually. In some cases, all of the images in the  group display online, in other cases they do not. </p>\r\n<p>You can download online images yourself.  Alternatively, you can  purchase copies of various types. </p>\r\n<ol class="margin-bottom-double-li">\r\n\t<li><strong>Determine whether the desired materials can be retrieved  online.</strong>\r\n\t\t<ul class="plain margin-bottom-single-li">\r\n\t\t\t<li>Look in the <strong>Medium</strong> field above to determine whether  the description is for one photograph or more than one.</li>\r\n\t\t\t<li>If the description is for a single item and it is displaying, you can download or purchase a print.  Cite the number that begins  with "LC-DIG..." when purchasing copies through Library of Congress Duplication Services. </li>\r\n\t\t\t<li>If the description is for more than one item and there is  a "Click for more images" icon displaying, select that.  Individual images will display; you can download or purchase prints.  Cite the number that begins with "LC-DIG..." when purchasing  copies through Library of Congress Duplication Services. </li>\r\n\t\t\t<li>If the description is for more than one item and there is no "Click for more images" icon displaying, return to the "About this Item" tab and select the "<em>Check for online items from this group</em>" link.  Then select the "Obtaining Copies" tab for any retrieved items that are of interest. </li>\r\n\t\t</ul>\r\n\t</li>\r\n\t<li><strong>If the images do not display online</strong> -- Select images for reproduction through one of these methods:\r\n\t\t<ul class="plain margin-bottom-single-li">\r\n\t\t\t<li>Visit the Prints &amp; Photographs Reading Room and request to view  the group (general information about service in the reading room is  available at: <a href="https://www.loc.gov/rr/print/info/001_ref.html">https://www.loc.gov/rr/print/info/001_ref.html</a>).</li>\r\n\t\t\t<li>P&amp;P reading room staff can provide up to 15 photocopies of items  per calendar year. (Color images cannot be photocopied.) For assistance,  see our <a href="https://ask.loc.gov/prints-photographs/">Ask a Librarian</a> page. OR</li>\r\n\t\t\t<li>Hire a freelance researcher to do further selection for you  (a list of researchers is available at: <a href="https://www.loc.gov/rr/print/resource/013_pic.html">https://www.loc.gov/rr/print/resource/013_pic.html</a>). </li>\r\n\t\t</ul>\r\n\t</li>\r\n</ol>\r\n<h4>Purchasing Copies</h4>\r\n<p>Library of Congress Duplication Services can make copies of various  types from images in Prints &amp; Photographs Division Collections.   Price lists, contact information, and order forms are available on the <a href="https://www.loc.gov/preserv/pds/">Duplication Services Web site</a>.</p>\r\n<p>Carol M. Highsmith sells prints of her photographs at: <a target="_blank" href="http://photographsamerica.com/">http://photographsamerica.com/ <i class="icon icon-external-link"><span>External</span></i></a> .</p>\r\n'],
#   'resource_links': ['https://hdl.loc.gov/loc.pnp/highsm.64003'],
#   'resources': [{'caption': 'original digital file',
#     'files': 1,
#     'image': 'https://tile.loc.gov/storage-services/service/pnp/highsm/64000/64003_150px.jpg',
#     'url': 'https://www.loc.gov/resource/highsm.64003/'}],
#   'rights': ['<p>The Library of Congress does not&nbsp;own rights to material  in its collections. Therefore, it does not license or charge permission fees  for use of such material and cannot grant or deny permission to publish or  otherwise distribute the material. </p>\n<p>Ultimately, it is the researcher\'s obligation to assess copyright or other use restrictions and  obtain permission from third parties when necessary before publishing or  otherwise distributing materials found in the Library\'s collections. </p>\n<p>For information about reproducing,  publishing, and citing material from this collection, as well as access to the  original items, see: <a href="https://www.loc.gov/rr/print/res/482_high.html">Carol M. Highsmith - Rights and Restrictions Information</a> </p>\n\n'],
#   'rights_advisory': 'No known restrictions on publication.',
#   'rights_information': 'No known restrictions on publication.',
#   'score': 19.262096,
#   'shard': '00',
#   'shelf_id': 'LC-DIG-highsm- 64003 (ONLINE) [P&P]',
#   'site': ['pictures', 'catalog'],
#   'sort_date': '2020',
#   'source_collection': 'Highsmith, Carol M., 1946- Carol M. Highsmith Archive.',
#   'source_created': '2020-11-10T00:00:00Z',
#   'source_modified': '2020-11-24T08:53:19Z',
#   'subject': ['united states',
#    'kentucky',
#    'digital photographs',
#    'color',
#    'bookmobiles',
#    'perry county',
#    'america',
#    'perry county public library',
#    'oliver hazard perry',
#    'hazard'],
#   'subject_headings': ['United States--Kentucky --Perry County --Hazard',
#    'America',
#    'Bookmobiles',
#    'Perry County Public Library',
#    'Oliver Hazard Perry'],
#   'subjects': [{'america': 'https://www.loc.gov/search/?fa=subject:america&fo=json'},
#    {'bookmobiles': 'https://www.loc.gov/search/?fa=subject:bookmobiles&fo=json'},
#    {'color': 'https://www.loc.gov/search/?fa=subject:color&fo=json'},
#    {'digital photographs': 'https://www.loc.gov/search/?fa=subject:digital+photographs&fo=json'},
#    {'hazard': 'https://www.loc.gov/search/?fa=subject:hazard&fo=json'},
#    {'kentucky': 'https://www.loc.gov/search/?fa=subject:kentucky&fo=json'},
#    {'oliver hazard perry': 'https://www.loc.gov/search/?fa=subject:oliver+hazard+perry&fo=json'},
#    {'perry county': 'https://www.loc.gov/search/?fa=subject:perry+county&fo=json'},
#    {'perry county public library': 'https://www.loc.gov/search/?fa=subject:perry+county+public+library&fo=json'},
#    {'united states': 'https://www.loc.gov/search/?fa=subject:united+states&fo=json'}],
#   'thumb_gallery': 'https://tile.loc.gov/storage-services/service/pnp/highsm/64000/64003_150px.jpg',
#   'timestamp': '2022-04-23T15:50:53.296Z',
#   'title': 'An appropriately decorated "Bookmobile" bus belonging to the Perry County Public Library in Hazard, a coal town of 4,500 or so population in the hills of southeastern Kentucky',
#   'type': ['photo, print, drawing'],
#   'unrestricted': True,
#   'url': 'https://www.loc.gov/item/2020722343/'},
#  'more_like_this': [{'access_restricted': False,
#    'aka': ['https://www.loc.gov/pictures/item/2020722346/',
#     'http://www.loc.gov/item/2020722346/',
#     'http://www.loc.gov/pictures/item/2020722346/',
#     'https://www.loc.gov/pictures/collection/highsm/item/2020722346/',
#     'http://www.loc.gov/pictures/collection/highsm/item/2020722346/',
#     'https://hdl.loc.gov/loc.pnp/highsm.64006',
#     'https://hdl.loc.gov/loc.pnp/highsm.64006',
#     'http://www.loc.gov/resource/highsm.64006/',
#     'http://lccn.loc.gov/2020722346'],
#    'campaigns': [],
#    'contributor': ['highsmith, carol m.'],
#    'date': '2020-01-01',
#    'dates': ['2020'],
#    'description': ['1 photograph : digital, tiff file, color.'],
#    'digitized': True,
#    'extract_timestamp': '2021-08-31T04:10:52.824Z',
#    'group': ['highsm',
#     'catalog-split-12',
#     'catalog',
#     'carol-m-highsmith',
#     'main-catalog-split-12',
#     'main-catalog'],
#    'hassegments': False,
#    'id': 'http://www.loc.gov/item/2020722346/',
#    'image_url': ['https://tile.loc.gov/storage-services/service/pnp/highsm/64000/64006_150px.jpg#h=104&w=150',
#     'https://tile.loc.gov/storage-services/service/pnp/highsm/64000/64006r.jpg#h=443&w=640',
#     'https://tile.loc.gov/storage-services/service/pnp/highsm/64000/64006v.jpg#h=708&w=1024'],
#    'index': 1,
#    'language': ['english'],
#    'location': ['united states', 'perry county', 'kentucky', 'hazard'],
#    'mime_type': ['image/gif', 'image/jpg', 'image/tif'],
#    'number': ['2020722346',
#     'online resource',
#     '2020-11-24t08:53:20',
#     'http://www.loc.gov/item/21812414'],
#    'online_format': ['image'],
#    'original_format': ['photo, print, drawing'],
#    'partof': ['catalog',
#     'prints & photographs online catalog (library of congress)',
#     'highsmith (carol m.) archive',
#     'prints and photographs division'],
#    'score': 70.31214,
#    'shelf_id': 'LC-DIG-highsm- 64006 (ONLINE) [P&P]',
#    'site': ['pictures', 'catalog'],
#    'subject': ['united states',
#     'kentucky',
#     'digital photographs',
#     'color',
#     'perry county',
#     'view of hazard',
#     'america',
#     'oliver hazard perry',
#     'hazard'],
#    'timestamp': '2022-04-23T15:50:53.296Z',
#    'title': 'Overview of Hazard, a logging and coal town of 4,500 or so population in the hills of southeastern Kentucky',
#    'url': 'https://www.loc.gov/item/2020722346/'},
#   {'access_restricted': False,
#    'aka': ['https://www.loc.gov/pictures/item/2020722347/',
#     'http://www.loc.gov/item/2020722347/',
#     'http://www.loc.gov/pictures/item/2020722347/',
#     'https://www.loc.gov/pictures/collection/highsm/item/2020722347/',
#     'http://www.loc.gov/pictures/collection/highsm/item/2020722347/',
#     'https://hdl.loc.gov/loc.pnp/highsm.64007',
#     'https://hdl.loc.gov/loc.pnp/highsm.64007',
#     'http://www.loc.gov/resource/highsm.64007/',
#     'http://lccn.loc.gov/2020722347'],
#    'campaigns': [],
#    'contributor': ['highsmith, carol m.'],
#    'date': '2020-01-01',
#    'dates': ['2020'],
#    'description': ['1 photograph : digital, tiff file, color.'],
#    'digitized': True,
#    'extract_timestamp': '2021-08-31T02:10:53.216Z',
#    'group': ['highsm',
#     'catalog-split-13',
#     'catalog',
#     'carol-m-highsmith',
#     'main-catalog-split-13',
#     'main-catalog'],
#    'hassegments': False,
#    'id': 'http://www.loc.gov/item/2020722347/',
#    'image_url': ['https://tile.loc.gov/storage-services/service/pnp/highsm/64000/64007_150px.jpg#h=109&w=150',
#     'https://tile.loc.gov/storage-services/service/pnp/highsm/64000/64007r.jpg#h=466&w=640',
#     'https://tile.loc.gov/storage-services/service/pnp/highsm/64000/64007v.jpg#h=745&w=1024'],
#    'index': 2,
#    'language': ['english'],
#    'location': ['united states', 'perry county', 'kentucky', 'hazard'],
#    'mime_type': ['image/gif', 'image/jpg', 'image/tif'],
#    'number': ['2020-11-24t08:53:21',
#     'http://www.loc.gov/item/21812415',
#     'online resource',
#     '2020722347'],
#    'online_format': ['image'],
#    'original_format': ['photo, print, drawing'],
#    'partof': ['catalog',
#     'prints & photographs online catalog (library of congress)',
#     'highsmith (carol m.) archive',
#     'prints and photographs division'],
#    'score': 70.31214,
#    'shelf_id': 'LC-DIG-highsm- 64007 (ONLINE) [P&P]',
#    'site': ['pictures', 'catalog'],
#    'subject': ['united states',
#     'kentucky',
#     'digital photographs',
#     'color',
#     'hazard murals',
#     'perry county',
#     'view of hazard',
#     'america',
#     'oliver hazard perry',
#     'hazard'],
#    'timestamp': '2022-04-23T15:50:53.296Z',
#    'title': 'A staircase-turned-mural in Hazard, a logging and coal town of 4,500 or so population in the hills of southeastern Kentucky',
#    'url': 'https://www.loc.gov/item/2020722347/'},
#   {'access_restricted': False,
#    'aka': ['https://www.loc.gov/pictures/item/2020722340/',
#     'http://www.loc.gov/item/2020722340/',
#     'http://www.loc.gov/pictures/item/2020722340/',
#     'https://www.loc.gov/pictures/collection/highsm/item/2020722340/',
#     'http://www.loc.gov/pictures/collection/highsm/item/2020722340/',
#     'https://hdl.loc.gov/loc.pnp/highsm.64000',
#     'https://hdl.loc.gov/loc.pnp/highsm.64000',
#     'http://www.loc.gov/resource/highsm.64000/',
#     'http://lccn.loc.gov/2020722340'],
#    'campaigns': [],
#    'contributor': ['highsmith, carol m.'],
#    'date': '2020-01-01',
#    'dates': ['2020'],
#    'description': ['1 photograph : digital, tiff file, color.'],
#    'digitized': True,
#    'extract_timestamp': '2021-08-31T05:22:51.556Z',
#    'group': ['highsm',
#     'catalog-split-06',
#     'catalog',
#     'carol-m-highsmith',
#     'main-catalog-split-06',
#     'main-catalog'],
#    'hassegments': False,
#    'id': 'http://www.loc.gov/item/2020722340/',
#    'image_url': ['https://tile.loc.gov/storage-services/service/pnp/highsm/64000/64000_150px.jpg#h=113&w=150',
#     'https://tile.loc.gov/storage-services/service/pnp/highsm/64000/64000r.jpg#h=480&w=640',
#     'https://tile.loc.gov/storage-services/service/pnp/highsm/64000/64000v.jpg#h=768&w=1024'],
#    'index': 3,
#    'language': ['english'],
#    'location': ['united states', 'perry county', 'kentucky', 'hazard'],
#    'mime_type': ['image/gif', 'image/jpg', 'image/tif'],
#    'number': ['2020722340',
#     '2020-11-24t08:53:18',
#     'online resource',
#     'http://www.loc.gov/item/21812408'],
#    'online_format': ['image'],
#    'original_format': ['photo, print, drawing'],
#    'partof': ['catalog',
#     'prints & photographs online catalog (library of congress)',
#     'highsmith (carol m.) archive',
#     'prints and photographs division'],
#    'score': 70.31214,
#    'shelf_id': 'LC-DIG-highsm- 64000 (ONLINE) [P&P]',
#    'site': ['pictures', 'catalog'],
#    'subject': ['united states',
#     'kentucky',
#     'digital photographs',
#     'color',
#     'perry county',
#     'america',
#     'oliver hazard perry',
#     'mountain curves',
#     'hazard'],
#    'timestamp': '2022-04-23T15:50:53.296Z',
#    'title': 'Curve through a cut in the mountains outside Hazard, a coal town of 4,500 or so population in southeastern Kentucky',
#    'url': 'https://www.loc.gov/item/2020722340/'},
#   {'access_restricted': False,
#    'aka': ['https://www.loc.gov/pictures/item/2020722341/',
#     'http://www.loc.gov/item/2020722341/',
#     'http://www.loc.gov/pictures/item/2020722341/',
#     'https://www.loc.gov/pictures/collection/highsm/item/2020722341/',
#     'http://www.loc.gov/pictures/collection/highsm/item/2020722341/',
#     'https://hdl.loc.gov/loc.pnp/highsm.64001',
#     'https://hdl.loc.gov/loc.pnp/highsm.64001',
#     'http://www.loc.gov/resource/highsm.64001/',
#     'http://lccn.loc.gov/2020722341'],
#    'campaigns': [],
#    'contributor': ['highsmith, carol m.'],
#    'date': '2020-01-01',
#    'dates': ['2020'],
#    'description': ['1 photograph : digital, tiff file, color.'],
#    'digitized': True,
#    'extract_timestamp': '2021-08-31T04:10:52.824Z',
#    'group': ['highsm',
#     'catalog-split-07',
#     'catalog',
#     'carol-m-highsmith',
#     'main-catalog-split-07',
#     'main-catalog'],
#    'hassegments': False,
#    'id': 'http://www.loc.gov/item/2020722341/',
#    'image_url': ['https://tile.loc.gov/storage-services/service/pnp/highsm/64000/64001_150px.jpg#h=113&w=150',
#     'https://tile.loc.gov/storage-services/service/pnp/highsm/64000/64001r.jpg#h=480&w=640',
#     'https://tile.loc.gov/storage-services/service/pnp/highsm/64000/64001v.jpg#h=768&w=1024'],
#    'index': 4,
#    'language': ['english'],
#    'location': ['united states', 'perry county', 'kentucky', 'hazard'],
#    'mime_type': ['image/gif', 'image/jpg', 'image/tif'],
#    'number': ['2020-11-24t08:53:19',
#     '2020722341',
#     'online resource',
#     'http://www.loc.gov/item/21812409'],
#    'online_format': ['image'],
#    'original_format': ['photo, print, drawing'],
#    'partof': ['catalog',
#     'prints & photographs online catalog (library of congress)',
#     'highsmith (carol m.) archive',
#     'prints and photographs division'],
#    'score': 70.31214,
#    'shelf_id': 'LC-DIG-highsm- 64001 (ONLINE) [P&P]',
#    'site': ['pictures', 'catalog'],
#    'subject': ['united states',
#     'kentucky',
#     'digital photographs',
#     'color',
#     'perry county',
#     'america',
#     'oliver hazard perry',
#     'mountain curves',
#     'hazard'],
#    'timestamp': '2022-04-23T15:50:53.296Z',
#    'title': 'Curve through a cut in the mountains outside Hazard, a coal town of 4,500 or so population in southeastern Kentucky',
#    'url': 'https://www.loc.gov/item/2020722341/'},
#   {'access_restricted': False,
#    'aka': ['https://www.loc.gov/pictures/item/2020722342/',
#     'http://www.loc.gov/item/2020722342/',
#     'http://www.loc.gov/pictures/item/2020722342/',
#     'https://www.loc.gov/pictures/collection/highsm/item/2020722342/',
#     'http://www.loc.gov/pictures/collection/highsm/item/2020722342/',
#     'https://hdl.loc.gov/loc.pnp/highsm.64002',
#     'https://hdl.loc.gov/loc.pnp/highsm.64002',
#     'http://www.loc.gov/resource/highsm.64002/',
#     'http://lccn.loc.gov/2020722342'],
#    'campaigns': [],
#    'contributor': ['highsmith, carol m.'],
#    'date': '2020-01-01',
#    'dates': ['2020'],
#    'description': ['1 photograph : digital, tiff file, color.'],
#    'digitized': True,
#    'extract_timestamp': '2021-08-31T02:14:01.018Z',
#    'group': ['highsm',
#     'catalog-split-08',
#     'catalog',
#     'carol-m-highsmith',
#     'main-catalog-split-08',
#     'main-catalog'],
#    'hassegments': False,
#    'id': 'http://www.loc.gov/item/2020722342/',
#    'image_url': ['https://tile.loc.gov/storage-services/service/pnp/highsm/64000/64002_150px.jpg#h=113&w=150',
#     'https://tile.loc.gov/storage-services/service/pnp/highsm/64000/64002r.jpg#h=480&w=640',
#     'https://tile.loc.gov/storage-services/service/pnp/highsm/64000/64002v.jpg#h=768&w=1024'],
#    'index': 5,
#    'language': ['english'],
#    'location': ['united states', 'perry county', 'kentucky', 'hazard'],
#    'mime_type': ['image/gif', 'image/jpg', 'image/tif'],
#    'number': ['2020-11-24t08:53:19',
#     'online resource',
#     '2020722342',
#     'http://www.loc.gov/item/21812410'],
#    'online_format': ['image'],
#    'original_format': ['photo, print, drawing'],
#    'partof': ['catalog',
#     'prints & photographs online catalog (library of congress)',
#     'highsmith (carol m.) archive',
#     'prints and photographs division'],
#    'score': 70.31214,
#    'shelf_id': 'LC-DIG-highsm- 64002 (ONLINE) [P&P]',
#    'site': ['pictures', 'catalog'],
#    'subject': ['united states',
#     'kentucky',
#     'digital photographs',
#     'color',
#     'kudzu',
#     'perry county',
#     'america',
#     'oliver hazard perry',
#     'hazard'],
#    'timestamp': '2022-04-23T15:50:53.296Z',
#    'title': 'Insidious kudzu vines ovewhelm just about everything along a road outside Hazard, a coal town of 4,500 or so population in the hills of southeastern Kentucky',
#    'url': 'https://www.loc.gov/item/2020722342/'},
#   {'access_restricted': False,
#    'aka': ['https://www.loc.gov/pictures/item/2020722345/',
#     'http://www.loc.gov/item/2020722345/',
#     'http://www.loc.gov/pictures/item/2020722345/',
#     'https://www.loc.gov/pictures/collection/highsm/item/2020722345/',
#     'http://www.loc.gov/pictures/collection/highsm/item/2020722345/',
#     'https://hdl.loc.gov/loc.pnp/highsm.64005',
#     'https://hdl.loc.gov/loc.pnp/highsm.64005',
#     'http://www.loc.gov/resource/highsm.64005/',
#     'http://lccn.loc.gov/2020722345'],
#    'campaigns': [],
#    'contributor': ['highsmith, carol m.'],
#    'date': '2020-01-01',
#    'dates': ['2020'],
#    'description': ['1 photograph : digital, tiff file, color.'],
#    'digitized': True,
#    'extract_timestamp': '2021-08-31T00:07:13.102Z',
#    'group': ['highsm',
#     'catalog-split-11',
#     'catalog',
#     'carol-m-highsmith',
#     'main-catalog-split-11',
#     'main-catalog'],
#    'hassegments': False,
#    'id': 'http://www.loc.gov/item/2020722345/',
#    'image_url': ['https://tile.loc.gov/storage-services/service/pnp/highsm/64000/64005_150px.jpg#h=104&w=150',
#     'https://tile.loc.gov/storage-services/service/pnp/highsm/64000/64005r.jpg#h=445&w=640',
#     'https://tile.loc.gov/storage-services/service/pnp/highsm/64000/64005v.jpg#h=712&w=1024'],
#    'index': 6,
#    'language': ['english'],
#    'location': ['united states', 'perry county', 'kentucky', 'hazard'],
#    'mime_type': ['image/gif', 'image/jpg', 'image/tif'],
#    'number': ['2020722345',
#     'online resource',
#     '2020-11-24t08:53:20',
#     'http://www.loc.gov/item/21812413'],
#    'online_format': ['image'],
#    'original_format': ['photo, print, drawing'],
#    'partof': ['catalog',
#     'prints & photographs online catalog (library of congress)',
#     'highsmith (carol m.) archive',
#     'prints and photographs division'],
#    'score': 59.34841,
#    'shelf_id': 'LC-DIG-highsm- 64005 (ONLINE) [P&P]',
#    'site': ['pictures', 'catalog'],
#    'subject': ['united states',
#     'kentucky',
#     'digital photographs',
#     'color',
#     'mimetic architecture',
#     'perry county',
#     'mother goose inn',
#     'america',
#     'hazard'],
#    'timestamp': '2022-04-23T15:50:53.296Z',
#    'title': 'An interesting example of "mimetic architecture," or structures that mimic the look of animals and other familiar large objects',
#    'url': 'https://www.loc.gov/item/2020722345/'}],
#  'notice': {'warning': 'Due to the temporary shutdown of the federal government beginning October 1, 2025, all Library of Congress buildings are closed and all public events are canceled until further notice. <a href="/item/prn-25-a05/">More</a>.\n'},
#  'options': {'access_group': [''],
#   'access_group_raw': '',
#   'all': None,
#   'api_version': '1',
#   'app_context': None,
#   'application_version': '$Revision$',
#   'attribute': None,
#   'attribute!': None,
#   'attribute_map': None,
#   'cache_tags': ['highsm',
#    'catalog-split-09',
#    'catalog',
#    'carol-m-highsmith',
#    'main-catalog-split-09',
#    'main-catalog',
#    'catalog-split-12',
#    'main-catalog-split-12',
#    'catalog-split-13',
#    'main-catalog-split-13',
#    'catalog-split-06',
#    'main-catalog-split-06',
#    'catalog-split-07',
#    'main-catalog-split-07',
#    'catalog-split-08',
#    'main-catalog-split-08',
#    'catalog-split-11',
#    'main-catalog-split-11',
#    'newspaper-titles',
#    'ndnp/newspapers',
#    'united-states-newspaper-directory',
#    'ndnp/kyu',
#    'university-of-kentucky-lexington-ky-awardee',
#    'afc/ofp/2020010',
#    'hope-for-recovery-peer-support-workers-in-kentucky',
#    'afc/2019029',
#    'independent-professional-wrestlers-in-central-appalachia',
#    'afc/ofp/2021010',
#    'rural-free-delivery',
#    'catalog-split-04',
#    'main-catalog-split-04'],
#   'callback': None,
#   'clip': None,
#   'clip_image_width': None,
#   'clip_rotation': None,
#   'content_filter': None,
#   'content_replacement': '',
#   'count': None,
#   'dates': None,
#   'default_count': 1,
#   'delimiter': None,
#   'digital_id': 'highsm.64003',
#   'display_level': None,
#   'distance': None,
#   'downloadOption': None,
#   'duration': 0.7193613052368164,
#   'embed': [],
#   'embed!': [],
#   'error_response_status': None,
#   'excludeTerms': None,
#   'facetLimits': '',
#   'facetPrefix': None,
#   'facet_count': None,
#   'facet_style': None,
#   'field': None,
#   'format': 'json',
#   'host': 'www.loc.gov',
#   'ical': False,
#   'id': None,
#   'iiif': False,
#   'index': None,
#   'inputEncoding': 'UTF-8',
#   'item': None,
#   'items': None,
#   'keys': None,
#   'language': None,
#   'latlong': None,
#   'method': 'GET',
#   'newSearch': None,
#   'new_clip_url': False,
#   'onsite': False,
#   'operator': None,
#   'outputEncoding': 'UTF-8',
#   'page_campaigns': [],
#   'path_info': '/resource/highsm.64003/',
#   'port': '443',
#   'proxypath': None,
#   'query_string': 'fo=json',
#   'redirect_proxy': False,
#   'redirect_to_item': None,
#   'referer': '',
#   'region': '',
#   'release_id': 123456789,
#   'request_host': 'www.loc.gov',
#   'request_params': {'fo': ['json']},
#   'request_url': 'https://www.loc.gov/resource/highsm.64003/?fo=json',
#   'resource': '',
#   'resource_sequence': None,
#   'scheme': 'https',
#   'searchIn': None,
#   'searchTerms': '',
#   'segments': None,
#   'site_id': None,
#   'site_type': None,
#   'solrQuery': '',
#   'sortBy': None,
#   'sortOrder': None,
#   'startPage': None,
#   'style': None,
#   'suggested': None,
#   'target': None,
#   'template': 'resource/base',
#   'timestamp': 1759432111.063154,
#   'tz_aware': None,
#   'unionFacets': '',
#   'webcast_permalink': None},
#  'page': [{'height': 0,
#    'levels': 1,
#    'mimetype': 'image/tiff',
#    'size': 453969892,
#    'url': 'https://tile.loc.gov/storage-services/master/pnp/highsm/64000/64003u.tif',
#    'width': 0},
#   {'height': 0,
#    'levels': 1,
#    'mimetype': 'image/tiff',
#    'size': 907874310,
#    'url': 'https://tile.loc.gov/storage-services/master/pnp/highsm/64000/64003a.tif',
#    'width': 0},
#   {'height': 113,
#    'levels': 1,
#    'mimetype': 'image/jpeg',
#    'size': 79677,
#    'url': 'https://tile.loc.gov/storage-services/service/pnp/highsm/64000/64003_150px.jpg',
#    'width': 150},
#   {'height': 480,
#    'levels': 1,
#    'mimetype': 'image/jpeg',
#    'size': 153155,
#    'url': 'https://tile.loc.gov/storage-services/service/pnp/highsm/64000/64003r.jpg',
#    'width': 640},
#   {'height': 768,
#    'levels': 1,
#    'mimetype': 'image/jpeg',
#    'size': 665752,
#    'url': 'https://tile.loc.gov/storage-services/service/pnp/highsm/64000/64003v.jpg',
#    'width': 1024}],
#  'pagination': {'current': 1, 'next': None, 'previous': None, 'total': 1},
#  'related': {'group_record': None,
#   'lot_link': None,
#   'neighbors': 'https://www.loc.gov/pictures/related/?&co=highsm&pk=2020722343&st=gallery&sb=call_number#focus',
#   'survey_link': None},
#  'related_items': [{'access_restricted': False,
#    'aka': ['http://www.loc.gov/item/sn87060006/'],
#    'batch': ['kyu_jindo_ver01'],
#    'campaigns': [],
#    'date': '192?',
#    'description': ['Weekly Description based on: Vol. 1, no. 7 (July 7, 1921).'],
#    'digitized': True,
#    'extract_timestamp': '2025-09-30T14:37:12.775Z',
#    'group': ['newspaper-titles',
#     'ndnp/newspapers',
#     'united-states-newspaper-directory'],
#    'hassegments': False,
#    'id': 'http://www.loc.gov/item/sn87060006/',
#    'image_url': [],
#    'index': 1,
#    'language': ['english'],
#    'latlong': [37.252046, -83.195258],
#    'location': ['united states',
#     'kentucky',
#     'perry',
#     'perry county',
#     'hazard'],
#    'location_str': '',
#    'lonlat': [-83.195258, 37.252046],
#    'number': ['sn87060006',
#     'http://www.loc.gov/item/sn87060006/1927-06-02/ed-1/',
#     '2025-05-23t21:30:26',
#     '2024-12-20t12:37:18.550397',
#     'online resource',
#     'kentucky newsp proj',
#     'microfilm service copy',
#     'microfilm master',
#     'univ of kentucky libr',
#     '15057405',
#     '1'],
#    'original_format': ['newspaper'],
#    'partof': ['chronicling america',
#     'serial and government publications division',
#     'directory of u.s. newspapers in american libraries',
#     'the hazard leader (hazard, ky.) 192?-19??'],
#    'publication_frequency': ['weekly'],
#    'score': 40.601936,
#    'shelf_id': 'http://lccn.loc.gov/sn87060006',
#    'site': ['chroniclingamerica', 'usnd'],
#    'subject': ['kentucky',
#     'united states',
#     'https://id.oclc.org/worldcat/entity/e39pbjqkbcdcthcjfbyffbmcfq',
#     'newspapers',
#     'https://id.oclc.org/worldcat/entity/e39pbjxrbqvkqtkcdycg4gxrv3',
#     'hazard (ky.)',
#     'perry',
#     'perry county (ky.)',
#     'perry county',
#     'hazard'],
#    'timestamp': '2025-09-30T14:59:28.729Z',
#    'title': 'The Hazard leader',
#    'type': ['title'],
#    'url': 'https://www.loc.gov/item/sn87060006/'},
#   {'access_restricted': False,
#    'aka': ['http://www.loc.gov/item/sn87060006/1927-06-02/ed-1/',
#     'http://www.loc.gov/resource/sn87060006/1927-06-02/ed-1/'],
#    'batch': ['kyu_jindo_ver01'],
#    'campaigns': [],
#    'contributor': ['university of kentucky, lexington, ky'],
#    'date': '1927-06-02',
#    'dates': ['1927-06-02'],
#    'description': ['Hazard, Ky.'],
#    'digitized': True,
#    'extract_timestamp': '2025-07-21T10:39:49.398Z',
#    'group': ['ndnp/kyu', 'university-of-kentucky-lexington-ky-awardee'],
#    'hassegments': True,
#    'id': 'http://www.loc.gov/item/sn87060006/1927-06-02/ed-1/',
#    'image_url': ['https://tile.loc.gov/image-services/iiif/service:ndnp:kyu:batch_kyu_jindo_ver01:data:sn87060006:00516997941:1927060201:0006/full/pct:6.25/0/default.jpg#h=378&w=296',
#     'https://tile.loc.gov/image-services/iiif/service:ndnp:kyu:batch_kyu_jindo_ver01:data:sn87060006:00516997941:1927060201:0006/full/pct:12.5/0/default.jpg#h=756&w=592'],
#    'index': 2,
#    'language': ['english'],
#    'location': ['united states',
#     'kentucky',
#     'perry',
#     'perry county',
#     'hazard'],
#    'mime_type': ['image/jp2', 'application/pdf', 'text/xml', 'image/jpeg'],
#    'number': ['00516997941', 'sn87060006', '1'],
#    'numeric_shelf_id': 192706021,
#    'online_format': ['image', 'pdf', 'online text'],
#    'original_format': ['newspaper'],
#    'partof': ['chronicling america',
#     'serial and government publications division',
#     'the hazard leader (hazard, ky.) 192?-19??'],
#    'publication_frequency': ['weekly'],
#    'score': 31.083763,
#    'shelf_id': 'sn87060006, 1927-06-02, Edition 1',
#    'site': ['chroniclingamerica'],
#    'subject': ['kentucky',
#     'united states',
#     'newspapers',
#     'hazard (ky.)',
#     'perry',
#     'perry county (ky.)',
#     'perry county',
#     'hazard'],
#    'timestamp': '2025-07-22T04:57:15.517Z',
#    'title': 'The Hazard leader (Hazard, Ky.), June 2, 1927',
#    'type': ['issue'],
#    'url': 'https://www.loc.gov/item/sn87060006/1927-06-02/ed-1/'},
#   {'access_restricted': False,
#    'aka': ['http://lccn.loc.gov/2023655222',
#     'http://www.loc.gov/item/2023655222/',
#     'https://hdl.loc.gov/loc.afc/afc2020010.afc2020010_016_sr01',
#     'http://www.loc.gov/resource/afc2020010.afc2020010_016_sr01/',
#     'http://www.loc.gov/resource/afc2020010.afc2020010_016_ms01/'],
#    'campaigns': [],
#    'contributor': ['sharp, ethan',
#     'occupational folklife project',
#     'tremblay, dan'],
#    'date': '2021',
#    'dates': ['2021'],
#    'description': ['Interview with Dan Tremblay about his experience with recovery, the different jobs that he has had, how he became involved in training peer support specialists, aspects of the training that he provides, and challenges that peer support specialists deal with in their work.'],
#    'digitized': True,
#    'extract_timestamp': '2023-11-16T08:40:18.739Z',
#    'group': ['catalog-split-13',
#     'catalog',
#     'afc/ofp/2020010',
#     'main-catalog-split-13',
#     'hope-for-recovery-peer-support-workers-in-kentucky'],
#    'hassegments': False,
#    'id': 'http://www.loc.gov/item/2023655222/',
#    'image_url': ['https://tile.loc.gov/storage-services/service/afc/afc2020010/afc2020010_016/afc2020010_016_ms01.gif',
#     'https://tile.loc.gov/storage-services/service/afc/afc2020010/afc2020010_016/afc2020010_016_ms01.gif#h=150&w=116'],
#    'index': 3,
#    'language': ['english'],
#    'location': ['kentucky', 'interviews', 'hazard'],
#    'mime_type': ['audio/mp3', 'image/gif', 'audio/wav', 'application/pdf'],
#    'number': ['2023-03-17t15:57:51',
#     'online resource',
#     '2023655222',
#     '2023-11-14t07:55:38'],
#    'online_format': ['audio', 'image', 'pdf'],
#    'original_format': ['sound recording'],
#    'partof': ['occupational folklife project',
#     'hope for recovery: peer support workers in kentucky: archie green fellows project, 2020-2021',
#     'american folklife center',
#     'catalog'],
#    'score': 26.523361,
#    'shelf_id': 'http://lccn.loc.gov/2023655222',
#    'site': ['catalog'],
#    'subject': ['kentucky',
#     'digital photographs',
#     'color',
#     'interviews',
#     'oral histories',
#     'substance use disorder',
#     'organizational change',
#     'career changes',
#     'treatment',
#     'peer counseling in rehabilitation',
#     'sound recordings',
#     'recovery movement',
#     'rehabilitation counselors',
#     'tremblay, dan',
#     'behavioral medicine',
#     'personal narratives',
#     'occupational training',
#     'entry-level employees'],
#    'timestamp': '2023-11-16T08:42:30.893Z',
#    'title': 'Dan Tremblay interview conducted by Ethan Sharp, 2021-06-24',
#    'type': ['sound recording-nonmusical'],
#    'url': 'https://www.loc.gov/item/2023655222/'},
#   {'access_restricted': False,
#    'aka': ['http://lccn.loc.gov/2021655332',
#     'http://www.loc.gov/item/2021655332/',
#     'https://hdl.loc.gov/loc.afc/afc2019029.afc2019029_06002_sr01',
#     'http://www.loc.gov/resource/afc2019029.afc2019029_06002_sr01/',
#     'http://www.loc.gov/resource/afc2019029.afc2019029_06002_ph/',
#     'http://www.loc.gov/resource/afc2019029.afc2019029_06002_ms01/',
#     'https://hdl.loc.gov/loc.afc/afc2019029.afc2019029_06002_sr01'],
#    'campaigns': [],
#    'contributor': ['bowers, delainey morgan',
#     'occupational folklife project',
#     'maggard, kyle'],
#    'date': '2020',
#    'dates': ['2020'],
#    'description': ['Kyle Maggard discusses his career as a professional wrestler and promoter in central Appalachia for the last 20 years. He speaks about getting into the sport while in high school, a bar fight between his father and "Macho Man" Randy Savage, working as a referee, starting an independent promotion in 2016, the importance of branding and storylines, the challenges of event planning, how the Appalachian region has influenced his approach to wrestling, effects of the COVID-19 pandemic on his promotion, and the challenge of staying relevant in a rapidly changing industry. Maggard concludes with advice for young upstarts.'],
#    'digitized': True,
#    'extract_timestamp': '2025-01-16T06:53:12.517Z',
#    'group': ['catalog-split-13',
#     'catalog',
#     'afc/2019029',
#     'main-catalog-split-13',
#     'independent-professional-wrestlers-in-central-appalachia'],
#    'hassegments': True,
#    'id': 'http://www.loc.gov/item/2021655332/',
#    'image_url': ['https://tile.loc.gov/image-services/iiif/service:afc:afc2019029:afc2019029_06002:afc2019029_06002_ph:afc2019029_06002_ph01/full/pct:25/0/default.jpg',
#     'https://tile.loc.gov/image-services/iiif/service:afc:afc2019029:afc2019029_06002:afc2019029_06002_ph:afc2019029_06002_ph01/full/pct:25/0/default.jpg#h=364&w=512',
#     'https://tile.loc.gov/image-services/iiif/service:afc:afc2019029:afc2019029_06002:afc2019029_06002_ph:afc2019029_06002_ph01/full/pct:50/0/default.jpg#h=728&w=1024',
#     'https://tile.loc.gov/image-services/iiif/service:afc:afc2019029:afc2019029_06002:afc2019029_06002_ph:afc2019029_06002_ph01/full/pct:100/0/default.jpg#h=1456&w=2048'],
#    'index': 4,
#    'language': ['english'],
#    'location': ['united states', 'appalachian region', 'kentucky', 'hazard'],
#    'mime_type': ['image/jpeg',
#     'image/jp2',
#     'audio/mp3',
#     'image/gif',
#     'audio/wav',
#     'application/pdf',
#     'application/x-audio'],
#    'number': ['2021655332',
#     '2022-03-02t15:24:53',
#     'online resource',
#     '2025-01-14t07:58:33'],
#    'online_format': ['image', 'audio', 'pdf'],
#    'original_format': ['sound recording'],
#    'partof': ['occupational folklife project',
#     'catalog',
#     'american folklife center',
#     'independent professional wrestlers in central appalachia: archie green fellows project, 2019-2020'],
#    'score': 22.293001,
#    'shelf_id': 'http://lccn.loc.gov/2021655332',
#    'site': ['catalog'],
#    'subject': ['interviews',
#     'small business',
#     'oral histories',
#     'storytelling',
#     'maggard, kyle',
#     'anecdotes',
#     'covid-19 pandemic',
#     'management',
#     'appalachian region',
#     'social media in sports',
#     'nicknames',
#     'wrestling promoters',
#     'officiating',
#     'wrestling matches',
#     'sound recordings',
#     'wrestling',
#     'training',
#     'personal narratives',
#     'united states',
#     'digital photographs',
#     'wrestlers',
#     'color',
#     'savage, randy',
#     'job security',
#     'influence',
#     'work environment'],
#    'timestamp': '2025-01-16T06:54:12.215Z',
#    'title': 'Kyle Maggard interview conducted by Delainey Morgan Bowers, 2020-07-24',
#    'type': ['sound recording-nonmusical'],
#    'url': 'https://www.loc.gov/item/2021655332/'},
#   {'access_restricted': False,
#    'aka': ['http://lccn.loc.gov/2023655398',
#     'http://www.loc.gov/item/2023655398/',
#     'https://hdl.loc.gov/loc.afc/afc2021010.afc2021010_018_sr01',
#     'http://www.loc.gov/resource/afc2021010.afc2021010_018_sr01/',
#     'http://www.loc.gov/resource/afc2021010.afc2021010_018_ph/',
#     'http://www.loc.gov/resource/afc2021010.afc2021010_018_ms01/'],
#    'campaigns': [],
#    'contributor': ['occupational folklife project',
#     'taylor-hatfield, teresa',
#     'hilliard, emily'],
#    'date': '2022',
#    'dates': ['2022'],
#    'description': ['Teresa Taylor-Hatfield (b. 1963) is a rural mail carrier working out of the Pikeville, Kentucky Post Office. She has been a rural carrier since 1996. She is the vice president of the Kentucky District I of the National Association of Rural Letter Carriers, and previously served as president. She also trains new rural letter carriers. In this interview, Hatfield talks about her passion for the union.'],
#    'digitized': True,
#    'extract_timestamp': '2025-01-16T06:53:05.946Z',
#    'group': ['catalog-split-11',
#     'catalog',
#     'afc/ofp/2021010',
#     'main-catalog-split-11',
#     'rural-free-delivery'],
#    'hassegments': False,
#    'id': 'http://www.loc.gov/item/2023655398/',
#    'image_url': ['https://tile.loc.gov/image-services/iiif/service:afc:afc2021010:afc2021010_018:afc2021010_018_ph:afc2021010_018_ph01/full/pct:6.25/0/default.jpg',
#     'https://tile.loc.gov/image-services/iiif/service:afc:afc2021010:afc2021010_018:afc2021010_018_ph:afc2021010_018_ph01/full/pct:6.25/0/default.jpg#h=228&w=342',
#     'https://tile.loc.gov/image-services/iiif/service:afc:afc2021010:afc2021010_018:afc2021010_018_ph:afc2021010_018_ph01/full/pct:12.5/0/default.jpg#h=456&w=684',
#     'https://tile.loc.gov/image-services/iiif/service:afc:afc2021010:afc2021010_018:afc2021010_018_ph:afc2021010_018_ph01/full/pct:25/0/default.jpg#h=912&w=1368',
#     'https://tile.loc.gov/image-services/iiif/service:afc:afc2021010:afc2021010_018:afc2021010_018_ph:afc2021010_018_ph01/full/pct:50/0/default.jpg#h=1824&w=2736',
#     'https://tile.loc.gov/image-services/iiif/service:afc:afc2021010:afc2021010_018:afc2021010_018_ph:afc2021010_018_ph01/full/pct:100/0/default.jpg#h=3648&w=5472'],
#    'index': 5,
#    'language': ['english'],
#    'location': ['united states',
#     'appalachian region',
#     'pikeville',
#     'kentucky'],
#    'mime_type': ['image/jpeg',
#     'image/jp2',
#     'audio/mp3',
#     'image/gif',
#     'audio/wav',
#     'application/pdf'],
#    'number': ['2023-11-17t15:01:31',
#     '2023655398',
#     'online resource',
#     '2025-01-14t08:21:48'],
#    'online_format': ['image', 'audio', 'pdf'],
#    'original_format': ['sound recording'],
#    'partof': ['rural free delivery: mail carriers in central appalachia, 2021-2022',
#     'occupational folklife project',
#     'catalog',
#     'american folklife center'],
#    'score': 20.611732,
#    'shelf_id': 'http://lccn.loc.gov/2023655398',
#    'site': ['catalog'],
#    'subject': ['kentucky',
#     'industrial safety',
#     'interviews',
#     'oral histories',
#     'letter carriers',
#     'covid-19 pandemic',
#     'appalachian region',
#     'country life',
#     'part-time employment',
#     'employees',
#     'employee morale',
#     'labor unions',
#     'rural free delivery',
#     'occupational training',
#     'postal service',
#     'contracting out',
#     'customer relations',
#     'sound recordings',
#     'personal narratives',
#     'united states',
#     'digital photographs',
#     "national rural letter carriers' association",
#     'color',
#     'women postal service employees',
#     'job satisfaction',
#     'influence',
#     'work environment',
#     'taylor-hatfield, teresa'],
#    'timestamp': '2025-01-16T06:54:35.673Z',
#    'title': 'Teresa Taylor-Hatfield interview conducted by Emily Hilliard, 2022-03-05',
#    'type': ['sound recording-nonmusical'],
#    'url': 'https://www.loc.gov/item/2023655398/'},
#   {'access_restricted': False,
#    'aka': ['http://lccn.loc.gov/2023655391',
#     'http://www.loc.gov/item/2023655391/',
#     'https://hdl.loc.gov/loc.afc/afc2021010.afc2021010_011_sr01',
#     'http://www.loc.gov/resource/afc2021010.afc2021010_011_sr01/',
#     'http://www.loc.gov/resource/afc2021010.afc2021010_011_ph/',
#     'http://www.loc.gov/resource/afc2021010.afc2021010_011_ms01/'],
#    'campaigns': [],
#    'contributor': ['molen, anna',
#     'occupational folklife project',
#     'hilliard, emily'],
#    'date': '2022',
#    'dates': ['2022'],
#    'description': ["Anna Molen (b. 1954, Pulaski County, Kentucky) has been a rural letter carrier for 32 years and plans to retire next year. She remembers admiring the job of a rural letter carrier when she was growing up in Pulaski County, Kentucky. Molen was hired by the Postal Service as a rural carrier in 1990 and had known the postmaster, her boss, since she was a child. She is currently on her fourth rural route. Her first had nearly 700 boxes and was 98 miles. Her current route, which she has been delivering for 13 years, has 600 boxes and is 76 miles. Molen has her own organizational system for delivering the mail -- organizing her route sequence in several storage tubs. She is the NRLCA president in her district and has been a union member for 26 years. She has also been a trainer of new rural letter carriers for 10-12 years. In this interview, she speaks about how her background in social work related to the job of rural letter carrying, her relationships with her customers, and the new evaluated system to determine rural letter carriers' pay."],
#    'digitized': True,
#    'extract_timestamp': '2025-01-16T06:52:30.591Z',
#    'group': ['catalog-split-04',
#     'catalog',
#     'afc/ofp/2021010',
#     'main-catalog-split-04',
#     'rural-free-delivery'],
#    'hassegments': False,
#    'id': 'http://www.loc.gov/item/2023655391/',
#    'image_url': ['https://tile.loc.gov/image-services/iiif/service:afc:afc2021010:afc2021010_011:afc2021010_011_ph:afc2021010_011_ph01/full/pct:6.25/0/default.jpg',
#     'https://tile.loc.gov/image-services/iiif/service:afc:afc2021010:afc2021010_011:afc2021010_011_ph:afc2021010_011_ph01/full/pct:6.25/0/default.jpg#h=228&w=342',
#     'https://tile.loc.gov/image-services/iiif/service:afc:afc2021010:afc2021010_011:afc2021010_011_ph:afc2021010_011_ph01/full/pct:12.5/0/default.jpg#h=456&w=684',
#     'https://tile.loc.gov/image-services/iiif/service:afc:afc2021010:afc2021010_011:afc2021010_011_ph:afc2021010_011_ph01/full/pct:25/0/default.jpg#h=912&w=1368',
#     'https://tile.loc.gov/image-services/iiif/service:afc:afc2021010:afc2021010_011:afc2021010_011_ph:afc2021010_011_ph01/full/pct:50/0/default.jpg#h=1824&w=2736',
#     'https://tile.loc.gov/image-services/iiif/service:afc:afc2021010:afc2021010_011:afc2021010_011_ph:afc2021010_011_ph01/full/pct:100/0/default.jpg#h=3648&w=5472'],
#    'index': 6,
#    'language': ['english'],
#    'location': ['united states', 'somerset', 'appalachian region', 'kentucky'],
#    'mime_type': ['image/jpeg',
#     'image/jp2',
#     'audio/mp3',
#     'image/gif',
#     'audio/wav',
#     'application/pdf'],
#    'number': ['online resource',
#     '2025-01-14t08:03:20',
#     '2023-11-17t14:59:06',
#     '2023655391'],
#    'online_format': ['image', 'audio', 'pdf'],
#    'original_format': ['sound recording'],
#    'partof': ['rural free delivery: mail carriers in central appalachia, 2021-2022',
#     'occupational folklife project',
#     'catalog',
#     'american folklife center'],
#    'score': 20.611732,
#    'shelf_id': 'http://lccn.loc.gov/2023655391',
#    'site': ['catalog'],
#    'subject': ['kentucky',
#     'interviews',
#     'oral histories',
#     'letter carriers',
#     'molen, anna',
#     'covid-19 pandemic',
#     'appalachian region',
#     'country life',
#     'employees',
#     'labor unions',
#     'rural free delivery',
#     'occupational training',
#     'postal service',
#     'technological innovations',
#     'customer relations',
#     'sound recordings',
#     'personal narratives',
#     'united states',
#     'retirement',
#     "national rural letter carriers' association",
#     'digital photographs',
#     'color',
#     'cold weather conditions',
#     'influence',
#     'work environment'],
#    'timestamp': '2025-01-16T06:54:27.283Z',
#    'title': 'Anna Molen interview conducted by Emily Hilliard, 2022-02-12',
#    'type': ['sound recording-nonmusical'],
#    'url': 'https://www.loc.gov/item/2023655391/'}],
#  'reproductions': '<p>\nSome images in this collection are described in groups; others are \ndescribed individually. In some cases, all of the images in the \ngroup display online, in other cases they do not.\n</p>\n\n<p>\nYou can download online images yourself.  Alternatively, you can \npurchase copies of various types.\n</p>\n\n<ol>\n<p>\t\n<strong><li>Determine whether the desired materials can be retrieved \nonline.</strong>\n</p>\n<ul>\n<p>\t\n<li>Look in the <strong>Medium</strong> field above to determine whether\n the description is for one photograph or more than one.</li>\n </p>\n <p>\n<li>If the description is for a single item and it is displaying, \nyou can download or purchase a print.  Cite the number that begins \nwith &quot;LC-DIG...&quot; when purchasing copies through Library of \nCongress Duplication Services.\n</p>\n<p>\n<li>If the description is for more than one item and there is \na &quot;Click for more images&quot; icon displaying, select that. \nIndividual images will display; you can download or purchase prints. \nCite the number that begins with &quot;LC-DIG...&quot; when purchasing \ncopies through Library of Congress Duplication Services.\n</p>\n<p>\n<li>If the description is for more than one item and there is no\n &quot;Click for more images&quot; icon displaying, return to the\n  &quot;About this Item&quot; tab and select the &quot;<i>Check for \n  online items from this group</i>&quot; link.  Then select the \n  "Obtaining Copies" tab for any retrieved items that are of interest.\n</p>\n</ul>\n</li>\n\n<p>\n<strong><li>If the images do not display online</strong> -- Select images for reproduction through one of these methods:\n</p>\n<ul>\n<p>\t\n<li>Visit the Prints &amp; Photographs Reading Room and request to view \nthe group (general information about service in the reading room is \navailable at: <a href="//www.loc.gov/rr/print/info/001_ref.html">https://www.loc.gov/rr/print/info/001_ref.html</a>).</li>  \n</p>\n<p>\n<li>P&amp;P reading room staff can provide up to 15 photocopies of items \nper calendar year. (Color images cannot be photocopied.) For assistance,\n see our <a href="//www.loc.gov/rr/askalib/ask-print.html">Ask a Librarian</a> page. OR</li>\n</p>\n<p>\n<li>Hire a freelance researcher to do further selection for you \n(a list of researchers is available at: \n<a href="//www.loc.gov/rr/print/resource/013_pic.html">https://www.loc.gov/rr/print/resource/013_pic.html</a>).\n</p>\n</ul>\n</li>\n</ol>\n\n<p>\n<strong>Purchasing Copies</strong>\n</p>\n\n<p>\nLibrary of Congress Duplication Services can make copies of various \ntypes from images in Prints & Photographs Division Collections.  \nPrice lists, contact information, and order forms are available on the \n<a href="//www.loc.gov/duplicationservices/">Duplication Services Web site</a>.\n</p>\n\n<p>\nCarol M. Highsmith sells prints of her photographs at: <a href="http://photographsamerica.com/">http://photographsamerica.com/</a> .\n</p>  \n\n\n\n\n        ',
#  'resource': {'caption': 'original digital file',
#   'image': 'https://tile.loc.gov/storage-services/service/pnp/highsm/64000/64003_150px.jpg',
#   'segment_count': 1,
#   'url': 'https://www.loc.gov/resource/highsm.64003/'},
#  'resources': [{'caption': 'original digital file',
#    'image': 'https://tile.loc.gov/storage-services/service/pnp/highsm/64000/64003_150px.jpg',
#    'segment_count': 1,
#    'url': 'https://www.loc.gov/resource/highsm.64003/'}],
#  'thesaurus_entry': None,
#  'timestamp': 1759432111782,
#  'type': 'legacyzoom',
#  'unrestricted': True,
#  'views': {'brief': 'https://www.loc.gov/resource/highsm.64003/?fo=json&st=brief',
#   'current': 'single',
#   'epub': 'https://www.loc.gov/resource/highsm.64003/?fo=json&st=pdf',
#   'gallery': 'https://www.loc.gov/resource/highsm.64003/?fo=json&st=gallery',
#   'grid': 'https://www.loc.gov/resource/highsm.64003/?fo=json&st=grid',
#   'image': 'https://www.loc.gov/resource/highsm.64003/?fo=json&st=image',
#   'list': 'https://www.loc.gov/resource/highsm.64003/?fo=json&st=list',
#   'pdf': 'https://www.loc.gov/resource/highsm.64003/?fo=json&st=pdf',
#   'single': 'https://www.loc.gov/resource/highsm.64003/?fo=json',
#   'slideshow': 'https://www.loc.gov/resource/highsm.64003/?fo=json&st=slideshow',
#   'text': 'https://www.loc.gov/resource/highsm.64003/?fo=json&st=text'}}

# %% [markdown]
# Permalink 3: https://lccn.loc.gov/2020722343

# %% [markdown]
# Question 3

# %%
#write each item's json data to their own file
#item1 = json.dumps(r1.json())
with open("item1.json", "w") as f:
    f.write(json.dumps(r1.json(), indent = 2))

#item2 = json.dumps(r2.json())
with open("item2.json", "w") as f:
    f.write(json.dumps(r2.json(), indent = 2))

#item3 = json.dumps(r3.json())
with open("item3.json", "w") as f:
    f.write(json.dumps(r3.json(), indent = 2))

# %% [markdown]
# Question 4

# %%
#prompt user to search
print('What would you like to search?')

#user input
search_term = input()

#define url addition
search_endpoint = '/search'

#define parameters
parameters = {'fo':'json', 'q': search_term}

#request from search
r4 = requests.get(url + search_endpoint, params = parameters)

#display returned data
r4.json()
# Out:
# What would you like to search?
# {'breadcrumbs': [{'Library of Congress': 'https://www.loc.gov'},
#   {'Search': 'https://www.loc.gov/search/?fo=json&q=hi'}],
#  'expert_resources': None,
#  'facet_trail': [{'facet': 'searchTerms',
#    'field': 'searchTerms',
#    'superset': 'https://www.loc.gov/search/?fo=json',
#    'value': 'hi'},
#   {'facet': 'Available Online',
#    'field': 'digitized',
#    'superset': 'https://www.loc.gov/search/?all=true&fo=json&q=hi',
#    'value': 'digitized'}],
#  'facet_views': {'calendar': 'https://www.loc.gov/search/?fo=json&fs=calendar&q=hi',
#   'chart': 'https://www.loc.gov/search/?fo=json&fs=chart&q=hi',
#   'current': 'list',
#   'list': 'https://www.loc.gov/search/?fo=json&q=hi'},
#  'facets': [{'filters': [{'count': 3086167,
#      'not': None,
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fo=json&q=hi',
#      'title': 'true'},
#     {'count': 14357,
#      'not': None,
#      'off': None,
#      'on': 'https://www.loc.gov/search/?all=true&fo=json&q=hi',
#      'title': 'false'}],
#    'title': 'Available Online',
#    'type': 'digitized'},
#   {'filters': [{'count': 2753405,
#      'not': 'https://www.loc.gov/search/?fa=original-format!:newspaper&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/newspapers/?dl=item&fo=json&q=hi',
#      'title': 'newspaper'},
#     {'count': 200750,
#      'not': 'https://www.loc.gov/search/?fa=original-format!:legislation&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=original-format:legislation&fo=json&q=hi',
#      'title': 'legislation'},
#     {'count': 80713,
#      'not': 'https://www.loc.gov/search/?fa=original-format!:book&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/books/?fo=json&q=hi',
#      'title': 'book'},
#     {'count': 24391,
#      'not': 'https://www.loc.gov/search/?fa=original-format!:periodical&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=original-format:periodical&fo=json&q=hi',
#      'title': 'periodical'},
#     {'count': 21726,
#      'not': 'https://www.loc.gov/search/?fa=original-format!:manuscript/mixed+material&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/manuscripts/?fo=json&q=hi',
#      'title': 'manuscript/mixed material'},
#     {'count': 4643,
#      'not': 'https://www.loc.gov/search/?fa=original-format!:film,+video&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/film-and-videos/?fo=json&q=hi',
#      'title': 'film, video'},
#     {'count': 2359,
#      'not': 'https://www.loc.gov/search/?fa=original-format!:personal+narrative&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=original-format:personal+narrative&fo=json&q=hi',
#      'title': 'personal narrative'},
#     {'count': 2208,
#      'not': 'https://www.loc.gov/search/?fa=original-format!:photo,+print,+drawing&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/photos/?fo=json&q=hi',
#      'title': 'photo, print, drawing'},
#     {'count': 1877,
#      'not': 'https://www.loc.gov/search/?fa=original-format!:web+page&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=original-format:web+page&fo=json&q=hi',
#      'title': 'web page'},
#     {'count': 279,
#      'not': 'https://www.loc.gov/search/?fa=original-format!:software,+e-resource&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=original-format:software,+e-resource&fo=json&q=hi',
#      'title': 'software, e-resource'},
#     {'count': 218,
#      'not': 'https://www.loc.gov/search/?fa=original-format!:sound+recording&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/audio/?fo=json&q=hi',
#      'title': 'sound recording'},
#     {'count': 39,
#      'not': 'https://www.loc.gov/search/?fa=original-format!:map&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/maps/?fo=json&q=hi',
#      'title': 'map'},
#     {'count': 35,
#      'not': 'https://www.loc.gov/search/?fa=original-format!:3d+object&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=original-format:3d+object&fo=json&q=hi',
#      'title': '3d object'},
#     {'count': 25,
#      'not': 'https://www.loc.gov/search/?fa=original-format!:notated+music&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/notated-music/?fo=json&q=hi',
#      'title': 'notated music'},
#     {'count': 16,
#      'not': 'https://www.loc.gov/search/?fa=original-format!:web+archive&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/web-archives/?fo=json&q=hi',
#      'title': 'web archive'},
#     {'count': 9,
#      'not': 'https://www.loc.gov/search/?fa=original-format!:event&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=original-format:event&fo=json&q=hi',
#      'title': 'event'}],
#    'title': 'Original Format',
#    'type': 'original-format'},
#   {'filters': [{'count': 3076906,
#      'not': 'https://www.loc.gov/search/?fa=online-format!:pdf&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=online-format:pdf&fo=json&q=hi',
#      'title': 'pdf'},
#     {'count': 3048437,
#      'not': 'https://www.loc.gov/search/?fa=online-format!:online+text&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=online-format:online+text&fo=json&q=hi',
#      'title': 'online text'},
#     {'count': 2874288,
#      'not': 'https://www.loc.gov/search/?fa=online-format!:image&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=online-format:image&fo=json&q=hi',
#      'title': 'image'},
#     {'count': 201863,
#      'not': 'https://www.loc.gov/search/?fa=online-format!:web+page&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=online-format:web+page&fo=json&q=hi',
#      'title': 'web page'},
#     {'count': 4649,
#      'not': 'https://www.loc.gov/search/?fa=online-format!:video&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=online-format:video&fo=json&q=hi',
#      'title': 'video'},
#     {'count': 159,
#      'not': 'https://www.loc.gov/search/?fa=online-format!:audio&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=online-format:audio&fo=json&q=hi',
#      'title': 'audio'},
#     {'count': 1,
#      'not': 'https://www.loc.gov/search/?fa=online-format!:compressed+data&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=online-format:compressed+data&fo=json&q=hi',
#      'title': 'compressed data'}],
#    'title': 'Online Format',
#    'type': 'online-format'},
#   {'filters': [{'count': 188149,
#      'not': None,
#      'off': None,
#      'on': 'https://www.loc.gov/search/?dates=2000/2026&fo=json&q=hi',
#      'term': '2000-01-01T00:00:00Z',
#      'title': '2000 to 2026'},
#     {'count': 1585765,
#      'not': None,
#      'off': None,
#      'on': 'https://www.loc.gov/search/?dates=1900/1999&fo=json&q=hi',
#      'term': '1900-01-01T00:00:00Z',
#      'title': '1900 to 1999'},
#     {'count': 1300618,
#      'not': None,
#      'off': None,
#      'on': 'https://www.loc.gov/search/?dates=1800/1899&fo=json&q=hi',
#      'term': '1800-01-01T00:00:00Z',
#      'title': '1800 to 1899'},
#     {'count': 5842,
#      'not': None,
#      'off': None,
#      'on': 'https://www.loc.gov/search/?dates=1700/1799&fo=json&q=hi',
#      'term': '1700-01-01T00:00:00Z',
#      'title': '1700 to 1799'},
#     {'count': 202,
#      'not': None,
#      'off': None,
#      'on': 'https://www.loc.gov/search/?dates=1600/1699&fo=json&q=hi',
#      'term': '1600-01-01T00:00:00Z',
#      'title': '1600 to 1699'},
#     {'count': 334,
#      'not': None,
#      'off': None,
#      'on': 'https://www.loc.gov/search/?dates=1500/1599&fo=json&q=hi',
#      'term': '1500-01-01T00:00:00Z',
#      'title': '1500 to 1599'},
#     {'count': 52,
#      'not': None,
#      'off': None,
#      'on': 'https://www.loc.gov/search/?dates=1400/1499&fo=json&q=hi',
#      'term': '1400-01-01T00:00:00Z',
#      'title': '1400 to 1499'},
#     {'count': 1,
#      'not': None,
#      'off': None,
#      'on': 'https://www.loc.gov/search/?dates=1300/1399&fo=json&q=hi',
#      'term': '1300-01-01T00:00:00Z',
#      'title': '1300 to 1399'},
#     {'count': 2,
#      'not': None,
#      'off': None,
#      'on': 'https://www.loc.gov/search/?dates=1200/1299&fo=json&q=hi',
#      'term': '1200-01-01T00:00:00Z',
#      'title': '1200 to 1299'}],
#    'title': 'Date',
#    'type': 'dates'},
#   {'filters': [{'count': 2775766,
#      'not': 'https://www.loc.gov/search/?fa=location!:united+states&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=location:united+states&fo=json&q=hi',
#      'title': 'united states'},
#     {'count': 188885,
#      'not': 'https://www.loc.gov/search/?fa=location!:washington&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=location:washington&fo=json&q=hi',
#      'title': 'washington'},
#     {'count': 134126,
#      'not': 'https://www.loc.gov/search/?fa=location!:virginia&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=location:virginia&fo=json&q=hi',
#      'title': 'virginia'},
#     {'count': 133505,
#      'not': 'https://www.loc.gov/search/?fa=location!:district+of+columbia&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=location:district+of+columbia&fo=json&q=hi',
#      'title': 'district of columbia'},
#     {'count': 131819,
#      'not': 'https://www.loc.gov/search/?fa=location!:ohio&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=location:ohio&fo=json&q=hi',
#      'title': 'ohio'},
#     {'count': 109608,
#      'not': 'https://www.loc.gov/search/?fa=location!:washington+d.c.&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=location:washington+d.c.&fo=json&q=hi',
#      'title': 'washington d.c.'},
#     {'count': 97265,
#      'not': 'https://www.loc.gov/search/?fa=location!:west+virginia&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=location:west+virginia&fo=json&q=hi',
#      'title': 'west virginia'},
#     {'count': 92919,
#      'not': 'https://www.loc.gov/search/?fa=location!:new+york&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=location:new+york&fo=json&q=hi',
#      'title': 'new york'},
#     {'count': 89212,
#      'not': 'https://www.loc.gov/search/?fa=location!:new+york+city&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=location:new+york+city&fo=json&q=hi',
#      'title': 'new york city'},
#     {'count': 82925,
#      'not': 'https://www.loc.gov/search/?fa=location!:new+york+county&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=location:new+york+county&fo=json&q=hi',
#      'title': 'new york county'}],
#    'index': 'https://www.loc.gov/search/index/location/?fo=json&q=hi&sp=1',
#    'title': 'Location',
#    'type': 'location'},
#   {'filters': [{'count': 2753255,
#      'not': 'https://www.loc.gov/search/?fa=partof!:serial+and+government+publications+division&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=partof:serial+and+government+publications+division&fo=json&q=hi',
#      'title': 'serial and government publications division'},
#     {'count': 2751944,
#      'not': 'https://www.loc.gov/search/?fa=partof!:chronicling+america&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=partof:chronicling+america&fo=json&q=hi',
#      'title': 'chronicling america'},
#     {'count': 200748,
#      'not': 'https://www.loc.gov/search/?fa=partof!:congress.gov&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=partof:congress.gov&fo=json&q=hi',
#      'title': 'congress.gov'},
#     {'count': 161861,
#      'not': 'https://www.loc.gov/search/?fa=partof!:bills&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=partof:bills&fo=json&q=hi',
#      'title': 'bills'},
#     {'count': 104955,
#      'not': 'https://www.loc.gov/search/?fa=partof!:house+bills&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=partof:house+bills&fo=json&q=hi',
#      'title': 'house bills'},
#     {'count': 84423,
#      'not': 'https://www.loc.gov/search/?fa=partof!:catalog&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=partof:catalog&fo=json&q=hi',
#      'title': 'catalog'},
#     {'count': 76301,
#      'not': 'https://www.loc.gov/search/?fa=partof!:general+collections&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=partof:general+collections&fo=json&q=hi',
#      'title': 'general collections'},
#     {'count': 69772,
#      'not': 'https://www.loc.gov/search/?fa=partof!:selected+digitized+books&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=partof:selected+digitized+books&fo=json&q=hi',
#      'title': 'selected digitized books'},
#     {'count': 56906,
#      'not': 'https://www.loc.gov/search/?fa=partof!:senate+bills&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=partof:senate+bills&fo=json&q=hi',
#      'title': 'senate bills'},
#     {'count': 36910,
#      'not': 'https://www.loc.gov/search/?fa=partof!:evening+star+%28washington,+d.c.%29+1854-1972&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=partof:evening+star+%28washington,+d.c.%29+1854-1972&fo=json&q=hi',
#      'title': 'evening star (washington, d.c.) 1854-1972'}],
#    'index': 'https://www.loc.gov/search/index/partof/?fo=json&q=hi&sp=1',
#    'title': 'Part of',
#    'type': 'partof'},
#   {'filters': [{'count': 179579,
#      'not': 'https://www.loc.gov/search/?fa=contributor!:library+of+congress,+washington,+dc&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=contributor:library+of+congress,+washington,+dc&fo=json&q=hi',
#      'title': 'library of congress, washington, dc'},
#     {'count': 129424,
#      'not': 'https://www.loc.gov/search/?fa=contributor!:library+of+virginia%3B+richmond,+va&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=contributor:library+of+virginia%3B+richmond,+va&fo=json&q=hi',
#      'title': 'library of virginia; richmond, va'},
#     {'count': 127282,
#      'not': 'https://www.loc.gov/search/?fa=contributor!:house+of+representatives&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=contributor:house+of+representatives&fo=json&q=hi',
#      'title': 'house of representatives'},
#     {'count': 97152,
#      'not': 'https://www.loc.gov/search/?fa=contributor!:west+virginia+university&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=contributor:west+virginia+university&fo=json&q=hi',
#      'title': 'west virginia university'},
#     {'count': 89464,
#      'not': 'https://www.loc.gov/search/?fa=contributor!:ohio+history+connection,+columbus,+oh&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=contributor:ohio+history+connection,+columbus,+oh&fo=json&q=hi',
#      'title': 'ohio history connection, columbus, oh'},
#     {'count': 72523,
#      'not': 'https://www.loc.gov/search/?fa=contributor!:university+of+north+texas%3B+denton,+tx&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=contributor:university+of+north+texas%3B+denton,+tx&fo=json&q=hi',
#      'title': 'university of north texas; denton, tx'},
#     {'count': 71914,
#      'not': 'https://www.loc.gov/search/?fa=contributor!:minnesota+historical+society%3B+saint+paul,+mn&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=contributor:minnesota+historical+society%3B+saint+paul,+mn&fo=json&q=hi',
#      'title': 'minnesota historical society; saint paul, mn'},
#     {'count': 71197,
#      'not': 'https://www.loc.gov/search/?fa=contributor!:senate&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=contributor:senate&fo=json&q=hi',
#      'title': 'senate'},
#     {'count': 67246,
#      'not': 'https://www.loc.gov/search/?fa=contributor!:university+of+nevada+las+vegas+university+libraries&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=contributor:university+of+nevada+las+vegas+university+libraries&fo=json&q=hi',
#      'title': 'university of nevada las vegas university libraries'},
#     {'count': 64124,
#      'not': 'https://www.loc.gov/search/?fa=contributor!:university+of+illinois+at+urbana-champaign+library,+urbana,+il&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=contributor:university+of+illinois+at+urbana-champaign+library,+urbana,+il&fo=json&q=hi',
#      'title': 'university of illinois at urbana-champaign library, urbana, il'}],
#    'index': 'https://www.loc.gov/search/index/contributor/?fo=json&q=hi&sp=1',
#    'title': 'Contributor',
#    'type': 'contributor'},
#   {'filters': [{'count': 2763372,
#      'not': 'https://www.loc.gov/search/?fa=subject!:united+states&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=subject:united+states&fo=json&q=hi',
#      'title': 'united states'},
#     {'count': 2686385,
#      'not': 'https://www.loc.gov/search/?fa=subject!:newspapers&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=subject:newspapers&fo=json&q=hi',
#      'title': 'newspapers'},
#     {'count': 197867,
#      'not': 'https://www.loc.gov/search/?fa=subject!:congress&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=subject:congress&fo=json&q=hi',
#      'title': 'congress'},
#     {'count': 187516,
#      'not': 'https://www.loc.gov/search/?fa=subject!:washington&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=subject:washington&fo=json&q=hi',
#      'title': 'washington'},
#     {'count': 133532,
#      'not': 'https://www.loc.gov/search/?fa=subject!:district+of+columbia&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=subject:district+of+columbia&fo=json&q=hi',
#      'title': 'district of columbia'},
#     {'count': 132182,
#      'not': 'https://www.loc.gov/search/?fa=subject!:virginia&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=subject:virginia&fo=json&q=hi',
#      'title': 'virginia'},
#     {'count': 131598,
#      'not': 'https://www.loc.gov/search/?fa=subject!:ohio&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=subject:ohio&fo=json&q=hi',
#      'title': 'ohio'},
#     {'count': 109448,
#      'not': 'https://www.loc.gov/search/?fa=subject!:washington+%28d.c.%29&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=subject:washington+%28d.c.%29&fo=json&q=hi',
#      'title': 'washington (d.c.)'},
#     {'count': 97203,
#      'not': 'https://www.loc.gov/search/?fa=subject!:west+virginia&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=subject:west+virginia&fo=json&q=hi',
#      'title': 'west virginia'},
#     {'count': 91071,
#      'not': 'https://www.loc.gov/search/?fa=subject!:new+york&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=subject:new+york&fo=json&q=hi',
#      'title': 'new york'}],
#    'index': 'https://www.loc.gov/search/index/subject/?fo=json&q=hi&sp=1',
#    'title': 'Subject',
#    'type': 'subject'},
#   {'filters': [{'count': 3007015,
#      'not': 'https://www.loc.gov/search/?fa=language!:english&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=language:english&fo=json&q=hi',
#      'title': 'english'},
#     {'count': 62660,
#      'not': 'https://www.loc.gov/search/?fa=language!:spanish&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=language:spanish&fo=json&q=hi',
#      'title': 'spanish'},
#     {'count': 36674,
#      'not': 'https://www.loc.gov/search/?fa=language!:german&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=language:german&fo=json&q=hi',
#      'title': 'german'},
#     {'count': 24829,
#      'not': 'https://www.loc.gov/search/?fa=language!:french&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=language:french&fo=json&q=hi',
#      'title': 'french'},
#     {'count': 13313,
#      'not': 'https://www.loc.gov/search/?fa=language!:polish&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=language:polish&fo=json&q=hi',
#      'title': 'polish'},
#     {'count': 9888,
#      'not': 'https://www.loc.gov/search/?fa=language!:italian&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=language:italian&fo=json&q=hi',
#      'title': 'italian'},
#     {'count': 4538,
#      'not': 'https://www.loc.gov/search/?fa=language!:hawaiian&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=language:hawaiian&fo=json&q=hi',
#      'title': 'hawaiian'},
#     {'count': 3589,
#      'not': 'https://www.loc.gov/search/?fa=language!:danish&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=language:danish&fo=json&q=hi',
#      'title': 'danish'},
#     {'count': 3388,
#      'not': 'https://www.loc.gov/search/?fa=language!:czech&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=language:czech&fo=json&q=hi',
#      'title': 'czech'},
#     {'count': 3300,
#      'not': 'https://www.loc.gov/search/?fa=language!:japanese&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=language:japanese&fo=json&q=hi',
#      'title': 'japanese'}],
#    'index': 'https://www.loc.gov/search/index/language/?fo=json&q=hi&sp=1',
#    'title': 'Language',
#    'type': 'language'},
#   {'filters': [{'count': 3086121,
#      'not': 'https://www.loc.gov/search/?fa=access-restricted!:false&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=access-restricted:false&fo=json&q=hi',
#      'title': 'false'},
#     {'count': 46,
#      'not': 'https://www.loc.gov/search/?fa=access-restricted!:true&fo=json&q=hi',
#      'off': None,
#      'on': 'https://www.loc.gov/search/?fa=access-restricted:true&fo=json&q=hi',
#      'title': 'true'}],
#    'title': 'Access Condition',
#    'type': 'access-restricted'}],
#  'form_facets': {},
#  'notice': {'warning': 'Due to the temporary shutdown of the federal government beginning October 1, 2025, all Library of Congress buildings are closed and all public events are canceled until further notice. <a href="/item/prn-25-a05/">More</a>.\n'},
#  'options': {'access_group': [''],
#   'access_group_raw': '',
#   'all': None,
#   'api_version': '1',
#   'app_context': None,
#   'application_version': '$Revision$',
#   'attribute': None,
#   'attribute!': None,
#   'attribute_map': None,
#   'cache_tags': ['paprika-music',
#    'catalog-split-05',
#    'catalog',
#    'main-catalog-split-05',
#    'catalog-split-11',
#    'main-catalog-split-11',
#    'catalog-split-01',
#    'main-catalog-split-01',
#    'paprika-afc',
#    'cowell',
#    'catalog-split-15',
#    'sidney-robertson-cowell-northern-california-folk-music',
#    'main-catalog-split-15',
#    'main-catalog',
#    'nationaljukebox',
#    'national-jukebox',
#    'catalog-split-08',
#    'main-catalog-split-08',
#    'catalog-split-02',
#    'main-catalog-split-02',
#    'cms',
#    'managed-content',
#    'general-web-archives',
#    'powmia',
#    'cph',
#    'catalog-split-04',
#    'miscellaneous-items-high-demand',
#    'main-catalog-split-04',
#    'catalog-split-12',
#    'main-catalog-split-12',
#    'pp_other',
#    'catalog-split-14',
#    'prints-and-photographs-other',
#    'main-catalog-split-14',
#    'afc1981005',
#    'montana-folklife-survey-1979'],
#   'callback': None,
#   'clip': None,
#   'clip_image_width': None,
#   'clip_rotation': None,
#   'content_filter': None,
#   'content_replacement': '',
#   'count': None,
#   'dates': None,
#   'default_count': 25,
#   'delimiter': None,
#   'digital_id': None,
#   'display_level': None,
#   'distance': None,
#   'downloadOption': None,
#   'duration': 2.340588331222534,
#   'embed': [],
#   'embed!': [],
#   'error_response_status': None,
#   'excludeTerms': None,
#   'facetLimits': '',
#   'facetPrefix': None,
#   'facet_count': None,
#   'facet_style': None,
#   'field': None,
#   'format': 'json',
#   'hits': 3086167,
#   'host': 'www.loc.gov',
#   'ical': False,
#   'id': None,
#   'iiif': False,
#   'index': None,
#   'inputEncoding': 'UTF-8',
#   'item': None,
#   'items': None,
#   'keys': None,
#   'language': None,
#   'latlong': None,
#   'method': 'GET',
#   'newSearch': None,
#   'new_clip_url': False,
#   'onsite': False,
#   'operator': None,
#   'outputEncoding': 'UTF-8',
#   'page_campaigns': [],
#   'path_info': '/search',
#   'port': '443',
#   'proxypath': None,
#   'query': 'hi',
#   'query_string': 'fo=json&q=hi',
#   'redirect_proxy': False,
#   'redirect_to_item': None,
#   'referer': '',
#   'region': '',
#   'release_id': 123456789,
#   'request_host': 'www.loc.gov',
#   'request_params': {'fo': ['json'], 'q': 'hi'},
#   'request_url': 'https://www.loc.gov/search?fo=json&q=hi',
#   'resource': '',
#   'resource_sequence': None,
#   'scheme': 'https',
#   'searchIn': None,
#   'searchTerms': 'hi',
#   'segments': None,
#   'site_id': None,
#   'site_type': None,
#   'solrQuery': '',
#   'sortBy': None,
#   'sortOrder': None,
#   'startPage': None,
#   'style': None,
#   'suggested': None,
#   'target': None,
#   'template': 'search/base',
#   'timestamp': 1759504113.5607119,
#   'type': 'search',
#   'tz_aware': None,
#   'unionFacets': '',
#   'url': 'https://www.loc.gov/search/?fo=json&q=hi',
#   'webcast_permalink': None},
#  'pagination': {'current': 1,
#   'first': None,
#   'from': 1,
#   'last': 'https://www.loc.gov/search/?fo=json&q=hi&sp=4',
#   'next': 'https://www.loc.gov/search/?fo=json&q=hi&sp=2',
#   'of': 3086167,
#   'page_list': [{'number': 1, 'url': None},
#    {'number': 2, 'url': 'https://www.loc.gov/search/?fo=json&q=hi&sp=2'},
#    {'number': 3, 'url': 'https://www.loc.gov/search/?fo=json&q=hi&sp=3'},
#    {'number': '...', 'url': 'https://www.loc.gov/search/?fo=json&q=hi&sp=4'}],
#   'perpage': 25,
#   'perpage_options': [25, 50, 100, 150],
#   'previous': None,
#   'results': '1 - 25',
#   'to': 25,
#   'total': 123447},
#  'results': [{'access_restricted': False,
#    'aka': ['http://lccn.loc.gov/2016749260',
#     'http://www.loc.gov/item/2016749260/',
#     'http://www.loc.gov/resource/music.musm1508-10052828/',
#     'https://hdl.loc.gov/loc.music/musm1508.10052828'],
#    'campaigns': [],
#    'contributor': ['luders, gustav', 'ade, george'],
#    'date': '1904',
#    'dates': ['1904'],
#    'description': ['From: The Sho-Gun. Staff notation.'],
#    'digitized': True,
#    'extract_timestamp': '2025-06-27T09:40:13.091Z',
#    'group': ['paprika-music',
#     'catalog-split-05',
#     'catalog',
#     'main-catalog-split-05'],
#    'hassegments': True,
#    'id': 'http://www.loc.gov/item/2016749260/',
#    'image_url': ['https://tile.loc.gov/image-services/iiif/public:music:musm1508-10052828:musm1508-10052828.0001/full/pct:6.25/0/default.jpg',
#     'https://tile.loc.gov/image-services/iiif/public:music:musm1508-10052828:musm1508-10052828.0001/full/pct:6.25/0/default.jpg#h=366&w=282',
#     'https://tile.loc.gov/image-services/iiif/public:music:musm1508-10052828:musm1508-10052828.0001/full/pct:12.5/0/default.jpg#h=732&w=564',
#     'https://tile.loc.gov/image-services/iiif/public:music:musm1508-10052828:musm1508-10052828.0001/full/pct:25.0/0/default.jpg#h=1465&w=1129',
#     'https://tile.loc.gov/image-services/iiif/public:music:musm1508-10052828:musm1508-10052828.0001/full/pct:50.0/0/default.jpg#h=2931&w=2259',
#     'https://tile.loc.gov/image-services/iiif/public:music:musm1508-10052828:musm1508-10052828.0001/full/pct:100.0/0/default.jpg#h=5862&w=4518'],
#    'index': 1,
#    'item': {'call_number': ['M1508 .Sho-Gun'],
#     'contributors': ['Luders, Gustav, 1865-1913 composer',
#      'Ade, George, 1866-1944 lyricist'],
#     'created_published': ['1904.'],
#     'date': '1904',
#     'format': ['notated music'],
#     'medium': ['1 score'],
#     'notes': ['From: The Sho-Gun.', 'Staff notation.'],
#     'number_former_id': ['https://www.loc.gov/item/2016749260',
#      'https://www.loc.gov/item/musm1508.10052828'],
#     'related_items': [{'title': 'Other songs from show',
#       'url': 'https://hdl.loc.gov/loc.music/musm1508callno.2016749260'}],
#     'subjects': ['Sho-Gun'],
#     'title': 'Hi-ko, hi-ko : Korean dance'},
#    'mime_type': ['image/jpeg', 'application/pdf', 'image/jp2'],
#    'number': ['http://www.loc.gov/item/musm1508.10052828',
#     '2023-12-07t16:43:13',
#     'http://www.loc.gov/item/2016749260',
#     '2016749260',
#     'http://www.loc.gov/resource/musm1508.10052828.0'],
#    'number_former_id': ['http://www.loc.gov/resource/musm1508.10052828.0',
#     'http://www.loc.gov/item/2016749260',
#     'http://www.loc.gov/item/musm1508.10052828'],
#    'number_lccn': ['2016749260'],
#    'number_source_modified': ['2023-12-07t16:43:13'],
#    'online_format': ['image', 'pdf'],
#    'original_format': ['notated music'],
#    'partof': ['catalog',
#     'sheet music of the musical theater',
#     'music division'],
#    'resources': [{'files': 4,
#      'image': 'https://tile.loc.gov/image-services/iiif/public:music:musm1508-10052828:musm1508-10052828.0001/full/pct:6.25/0/default.jpg',
#      'paprika_resource_path': '/sets/music/musm1508-10052828',
#      'pdf': 'https://tile.loc.gov/storage-services/public/music/musm1508-10052828/musm1508-10052828.pdf',
#      'schemaVersion': 'v1',
#      'search': 'https://www.loc.gov/search/?fa=segmentof:music.musm1508-10052828/&fo=json&q=hi&st=gallery',
#      'segments': 4,
#      'url': 'https://www.loc.gov/resource/music.musm1508-10052828/',
#      'version': 4}],
#    'segments': [{'count': 4,
#      'link': 'https://www.loc.gov/search/?fa=segmentof:music.musm1508-10052828/&fo=json&q=hi&st=gallery',
#      'url': 'https://www.loc.gov/resource/music.musm1508-10052828/'}],
#    'shelf_id': 'https://repo.loc.gov/access/public/music/musm1508-10052828/.resource.json',
#    'site': ['catalog'],
#    'subject': ['sho-gun'],
#    'timestamp': '2025-06-27T11:21:47.554Z',
#    'title': 'Hi-ko, hi-ko : Korean dance',
#    'type': ['notated music'],
#    'url': 'https://www.loc.gov/item/2016749260/'},
#   {'access_restricted': False,
#    'aka': ['http://lccn.loc.gov/2023804323',
#     'http://www.loc.gov/item/2023804323/',
#     'http://www.loc.gov/resource/music.mussm2-sm1851-490530/',
#     'https://hdl.loc.gov/loc.music/sm1851.490530'],
#    'campaigns': [],
#    'contributor': ['horn, even'],
#    'date': '1851',
#    'dates': ['1851'],
#    'description': ['In bound volumes: Vocal sheet music registered in the U.S. District courts for copyright purposes, 1820-1860 Record created through migration from the Performing Arts Encyclopedia Database.'],
#    'digitized': True,
#    'extract_timestamp': '2025-06-11T07:23:06.090Z',
#    'group': ['paprika-music',
#     'catalog-split-11',
#     'catalog',
#     'main-catalog-split-11'],
#    'hassegments': True,
#    'id': 'http://www.loc.gov/item/2023804323/',
#    'image_url': ['https://tile.loc.gov/image-services/iiif/public:music:mussm2-sm1851-490530:001/full/pct:6.25/0/default.jpg',
#     'https://tile.loc.gov/image-services/iiif/public:music:mussm2-sm1851-490530:001/full/pct:6.25/0/default.jpg#h=463&w=352',
#     'https://tile.loc.gov/image-services/iiif/public:music:mussm2-sm1851-490530:001/full/pct:12.5/0/default.jpg#h=926&w=704',
#     'https://tile.loc.gov/image-services/iiif/public:music:mussm2-sm1851-490530:001/full/pct:25.0/0/default.jpg#h=1853&w=1408',
#     'https://tile.loc.gov/image-services/iiif/public:music:mussm2-sm1851-490530:001/full/pct:50.0/0/default.jpg#h=3707&w=2817',
#     'https://tile.loc.gov/image-services/iiif/public:music:mussm2-sm1851-490530:001/full/pct:100.0/0/default.jpg#h=7415&w=5634'],
#    'index': 2,
#    'item': {'call_number': ['M1.A12 V'],
#     'contributors': ['Horn, Even', 'Horn, Even lyricist'],
#     'created_published': ['New York : Firth, Pond and Co., 1851.'],
#     'date': '1851',
#     'format': ['notated music'],
#     'language': ['eng'],
#     'medium': ['1 score'],
#     'notes': ['In bound volumes: Vocal sheet music registered in the U.S. District courts for copyright purposes, 1820-1860',
#      'Record created through migration from the Performing Arts Encyclopedia Database.'],
#     'number_former_id': ['https://www.loc.gov/item/2023804323',
#      'https://www.loc.gov/item/sm1851.490530'],
#     'repository': ['c-Music M1.A12 V Vol. 42 Case'],
#     'source_collection': ['Sheet music for copyright deposit, 1820-1860. Vocal'],
#     'subjects': ['Polkas',
#      'Choruses, Secular (Mixed voices, 4 parts) with piano',
#      'Piano music',
#      'African Americans',
#      'Afro-American',
#      'Shakers'],
#     'title': 'Fi hi hi, the black shakers song and polka'},
#    'language': ['english'],
#    'mime_type': ['image/jpeg', 'application/pdf', 'image/jp2'],
#    'number': ['http://www.loc.gov/resource/sm1851.490530.0',
#     '2023804323',
#     'http://www.loc.gov/item/2023804323',
#     'http://www.loc.gov/item/sm1851.490530',
#     '2024-01-11t14:08:22',
#     'sheet'],
#    'number_carrier_type': ['sheet'],
#    'number_former_id': ['http://www.loc.gov/resource/sm1851.490530.0',
#     'http://www.loc.gov/item/2023804323',
#     'http://www.loc.gov/item/sm1851.490530'],
#    'number_lccn': ['2023804323'],
#    'number_source_modified': ['2024-01-11t14:08:22'],
#    'online_format': ['image', 'pdf'],
#    'original_format': ['notated music'],
#    'partof': ['music for the nation: american sheet music, ca. 1820-1860',
#     'music division',
#     'catalog',
#     'the library of congress celebrates the songs of america'],
#    'resources': [{'files': 4,
#      'image': 'https://tile.loc.gov/image-services/iiif/public:music:mussm2-sm1851-490530:001/full/pct:6.25/0/default.jpg',
#      'paprika_resource_path': '/sets/music/mussm2-sm1851-490530',
#      'pdf': 'https://tile.loc.gov/storage-services/public/music/mussm2-sm1851-490530/mussm2-sm1851-490530.pdf',
#      'schemaVersion': 'v1',
#      'search': 'https://www.loc.gov/search/?fa=segmentof:music.mussm2-sm1851-490530/&fo=json&q=hi&st=gallery',
#      'segments': 4,
#      'url': 'https://www.loc.gov/resource/music.mussm2-sm1851-490530/',
#      'version': 4}],
#    'segments': [{'count': 4,
#      'link': 'https://www.loc.gov/search/?fa=segmentof:music.mussm2-sm1851-490530/&fo=json&q=hi&st=gallery',
#      'url': 'https://www.loc.gov/resource/music.mussm2-sm1851-490530/'}],
#    'shelf_id': 'https://repo.loc.gov/access/public/music/mussm2-sm1851-490530/.resource.json',
#    'site': ['catalog'],
#    'subject': ['shakers',
#     'piano music',
#     'polkas',
#     'afro-american',
#     'african americans',
#     'choruses, secular (mixed voices, 4 parts) with piano'],
#    'timestamp': '2025-06-11T11:43:12.882Z',
#    'title': 'Fi hi hi, the black shakers song and polka',
#    'type': ['notated music'],
#    'url': 'https://www.loc.gov/item/2023804323/'},
#   {'access_restricted': False,
#    'aka': ['http://lccn.loc.gov/2023804608',
#     'http://www.loc.gov/item/2023804608/',
#     'http://www.loc.gov/resource/music.mussm2-sm1851-661930/',
#     'https://hdl.loc.gov/loc.music/sm1851.661930'],
#    'campaigns': [],
#    'contributor': ['horn, even'],
#    'date': '1851',
#    'dates': ['1851'],
#    'description': ['In bound volumes: Additional instrumental and vocal sheet music registered in the U.S. District courts for copyright purposes, 1820-1860 Record created through migration from the Performing Arts Encyclopedia Database.'],
#    'digitized': True,
#    'extract_timestamp': '2025-06-11T07:05:21.179Z',
#    'group': ['paprika-music',
#     'catalog-split-01',
#     'catalog',
#     'main-catalog-split-01'],
#    'hassegments': True,
#    'id': 'http://www.loc.gov/item/2023804608/',
#    'image_url': ['https://tile.loc.gov/image-services/iiif/public:music:mussm2-sm1851-661930:001/full/pct:6.25/0/default.jpg',
#     'https://tile.loc.gov/image-services/iiif/public:music:mussm2-sm1851-661930:001/full/pct:6.25/0/default.jpg#h=446&w=349',
#     'https://tile.loc.gov/image-services/iiif/public:music:mussm2-sm1851-661930:001/full/pct:12.5/0/default.jpg#h=892&w=698',
#     'https://tile.loc.gov/image-services/iiif/public:music:mussm2-sm1851-661930:001/full/pct:25.0/0/default.jpg#h=1784&w=1396',
#     'https://tile.loc.gov/image-services/iiif/public:music:mussm2-sm1851-661930:001/full/pct:50.0/0/default.jpg#h=3568&w=2793',
#     'https://tile.loc.gov/image-services/iiif/public:music:mussm2-sm1851-661930:001/full/pct:100.0/0/default.jpg#h=7136&w=5587'],
#    'index': 3,
#    'item': {'call_number': ['M1.A12 Z'],
#     'contributors': ['Horn, Even', 'Horn, Even lyricist'],
#     'created_published': ['New York : Firth, Pond and Co., 1851.'],
#     'date': '1851',
#     'format': ['notated music'],
#     'language': ['eng'],
#     'medium': ['1 score'],
#     'notes': ['In bound volumes: Additional instrumental and vocal sheet music registered in the U.S. District courts for copyright purposes, 1820-1860',
#      'Record created through migration from the Performing Arts Encyclopedia Database.'],
#     'number_former_id': ['https://www.loc.gov/item/2023804608',
#      'https://www.loc.gov/item/sm1851.661930'],
#     'repository': ['c-Music M1.A12 Z Vol. 15 Case'],
#     'source_collection': ['Sheet music for copyright deposit, 1820-1860. Instrumental and vocal'],
#     'subjects': ['Polkas',
#      'Songs with piano',
#      'Choruses, Secular (Mixed voices, 4 parts) with piano',
#      'Minstrel Music',
#      'Shakers'],
#     'title': 'Fi hi hi, the black Shakers song and polka'},
#    'language': ['english'],
#    'mime_type': ['image/jpeg', 'application/pdf', 'image/jp2'],
#    'number': ['2024-01-11t14:10:27',
#     'http://www.loc.gov/resource/sm1851.661930.0',
#     'http://www.loc.gov/item/sm1851.661930',
#     '2023804608',
#     'http://www.loc.gov/item/2023804608',
#     'sheet'],
#    'number_carrier_type': ['sheet'],
#    'number_former_id': ['http://www.loc.gov/resource/sm1851.661930.0',
#     'http://www.loc.gov/item/2023804608',
#     'http://www.loc.gov/item/sm1851.661930'],
#    'number_lccn': ['2023804608'],
#    'number_source_modified': ['2024-01-11t14:10:27'],
#    'online_format': ['image', 'pdf'],
#    'original_format': ['notated music'],
#    'partof': ['music for the nation: american sheet music, ca. 1820-1860',
#     'music division',
#     'catalog',
#     'the library of congress celebrates the songs of america'],
#    'resources': [{'files': 4,
#      'image': 'https://tile.loc.gov/image-services/iiif/public:music:mussm2-sm1851-661930:001/full/pct:6.25/0/default.jpg',
#      'paprika_resource_path': '/sets/music/mussm2-sm1851-661930',
#      'pdf': 'https://tile.loc.gov/storage-services/public/music/mussm2-sm1851-661930/mussm2-sm1851-661930.pdf',
#      'schemaVersion': 'v1',
#      'search': 'https://www.loc.gov/search/?fa=segmentof:music.mussm2-sm1851-661930/&fo=json&q=hi&st=gallery',
#      'segments': 4,
#      'url': 'https://www.loc.gov/resource/music.mussm2-sm1851-661930/',
#      'version': 4}],
#    'segments': [{'count': 4,
#      'link': 'https://www.loc.gov/search/?fa=segmentof:music.mussm2-sm1851-661930/&fo=json&q=hi&st=gallery',
#      'url': 'https://www.loc.gov/resource/music.mussm2-sm1851-661930/'}],
#    'shelf_id': 'https://repo.loc.gov/access/public/music/mussm2-sm1851-661930/.resource.json',
#    'site': ['catalog'],
#    'subject': ['shakers',
#     'songs with piano',
#     'minstrel music',
#     'polkas',
#     'choruses, secular (mixed voices, 4 parts) with piano'],
#    'timestamp': '2025-06-11T11:47:26.092Z',
#    'title': 'Fi hi hi, the black Shakers song and polka',
#    'type': ['notated music'],
#    'url': 'https://www.loc.gov/item/2023804608/'},
#   {'access_restricted': False,
#    'aka': ['http://lccn.loc.gov/2016744913',
#     'http://www.loc.gov/item/2016744913/',
#     'http://www.loc.gov/resource/music.musm1508-10057234/',
#     'https://hdl.loc.gov/loc.music/musm1508.10057234'],
#    'campaigns': [],
#    'contributor': ['gilbert, jean'],
#    'date': '1913',
#    'dates': ['1913'],
#    'description': ['From: Tango-Prinzessin. Staff notation.'],
#    'digitized': True,
#    'extract_timestamp': '2025-06-27T08:49:14.457Z',
#    'group': ['paprika-music',
#     'catalog-split-05',
#     'catalog',
#     'main-catalog-split-05'],
#    'hassegments': True,
#    'id': 'http://www.loc.gov/item/2016744913/',
#    'image_url': ['https://tile.loc.gov/image-services/iiif/public:music:musm1508-10057234:musm1508-10057234.0001/full/pct:6.25/0/default.jpg',
#     'https://tile.loc.gov/image-services/iiif/public:music:musm1508-10057234:musm1508-10057234.0001/full/pct:6.25/0/default.jpg#h=349&w=279',
#     'https://tile.loc.gov/image-services/iiif/public:music:musm1508-10057234:musm1508-10057234.0001/full/pct:12.5/0/default.jpg#h=698&w=559',
#     'https://tile.loc.gov/image-services/iiif/public:music:musm1508-10057234:musm1508-10057234.0001/full/pct:25.0/0/default.jpg#h=1396&w=1118',
#     'https://tile.loc.gov/image-services/iiif/public:music:musm1508-10057234:musm1508-10057234.0001/full/pct:50.0/0/default.jpg#h=2792&w=2236',
#     'https://tile.loc.gov/image-services/iiif/public:music:musm1508-10057234:musm1508-10057234.0001/full/pct:100.0/0/default.jpg#h=5584&w=4472'],
#    'index': 4,
#    'item': {'call_number': ['M1508 .Tango-Prinzessin'],
#     'contributors': ['Gilbert, Jean, 1879-1942 composer'],
#     'created_published': ['1913.'],
#     'date': '1913',
#     'format': ['notated music'],
#     'medium': ['1 score'],
#     'notes': ['From: Tango-Prinzessin.', 'Staff notation.'],
#     'number_former_id': ['https://www.loc.gov/item/2016744913',
#      'https://www.loc.gov/item/musm1508.10057234'],
#     'related_items': [{'title': 'Other songs from show',
#       'url': 'https://hdl.loc.gov/loc.music/musm1508callno.2016744913'}],
#     'subjects': ['Tango-Prinzessin'],
#     'title': 'In Hi-Ha-Hellerau'},
#    'mime_type': ['image/jpeg', 'application/pdf', 'image/jp2'],
#    'number': ['2016744913',
#     'http://www.loc.gov/item/2016744913',
#     'http://www.loc.gov/resource/musm1508.10057234.0',
#     '2023-12-07t16:44:40',
#     'http://www.loc.gov/item/musm1508.10057234'],
#    'number_former_id': ['http://www.loc.gov/resource/musm1508.10057234.0',
#     'http://www.loc.gov/item/2016744913',
#     'http://www.loc.gov/item/musm1508.10057234'],
#    'number_lccn': ['2016744913'],
#    'number_source_modified': ['2023-12-07t16:44:40'],
#    'online_format': ['image', 'pdf'],
#    'original_format': ['notated music'],
#    'partof': ['catalog',
#     'sheet music of the musical theater',
#     'music division'],
#    'resources': [{'files': 6,
#      'image': 'https://tile.loc.gov/image-services/iiif/public:music:musm1508-10057234:musm1508-10057234.0001/full/pct:6.25/0/default.jpg',
#      'paprika_resource_path': '/sets/music/musm1508-10057234',
#      'pdf': 'https://tile.loc.gov/storage-services/public/music/musm1508-10057234/musm1508-10057234.pdf',
#      'schemaVersion': 'v1',
#      'search': 'https://www.loc.gov/search/?fa=segmentof:music.musm1508-10057234/&fo=json&q=hi&st=gallery',
#      'segments': 6,
#      'url': 'https://www.loc.gov/resource/music.musm1508-10057234/',
#      'version': 4}],
#    'segments': [{'count': 6,
#      'link': 'https://www.loc.gov/search/?fa=segmentof:music.musm1508-10057234/&fo=json&q=hi&st=gallery',
#      'url': 'https://www.loc.gov/resource/music.musm1508-10057234/'}],
#    'shelf_id': 'https://repo.loc.gov/access/public/music/musm1508-10057234/.resource.json',
#    'site': ['catalog'],
#    'subject': ['tango-prinzessin'],
#    'timestamp': '2025-06-27T11:35:52.637Z',
#    'title': 'In Hi-Ha-Hellerau',
#    'type': ['notated music'],
#    'url': 'https://www.loc.gov/item/2016744913/'},
#   {'access_restricted': False,
#    'aka': ['https://hdl.loc.gov/loc.afc/afc9999005.10151',
#     'http://www.loc.gov/resource/afc.afc9999005-10151/',
#     'http://www.loc.gov/item/afc9999005.10151/'],
#    'campaigns': [],
#    'contributor': ['morgan, aaron', 'cowell, sidney robertson'],
#    'date': '1939-07-17',
#    'dates': ['1939-07-17'],
#    'digitized': True,
#    'extract_timestamp': '2024-07-10T07:03:35.829Z',
#    'group': ['paprika-afc'],
#    'hassegments': False,
#    'id': 'http://www.loc.gov/item/afc9999005.10151/',
#    'image_url': ['https://tile.loc.gov/image-services/iiif/public:afc:afc9999005-10151:0347/full/pct:50.0/0/default.jpg',
#     'https://tile.loc.gov/image-services/iiif/public:afc:afc9999005-10151:0347/full/pct:50.0/0/default.jpg#h=452&w=742',
#     'https://tile.loc.gov/image-services/iiif/public:afc:afc9999005-10151:0347/full/pct:100.0/0/default.jpg#h=904&w=1485'],
#    'index': 5,
#    'item': {'call_number': ['AFS Number: AFS 03368 A03'],
#     'contributors': ['Cowell, Sidney Robertson (Recordist)',
#      'Morgan, Aaron (Performer)'],
#     'created_published': ['Columbia, California'],
#     'date': '19390717',
#     'digital_id': ['https://hdl.loc.gov/loc.afc/afc9999005.10151'],
#     'format': 'still image',
#     'genre': ['card catalogs'],
#     'language': 'eng',
#     'location': ['United States of America -- California -- Columbia'],
#     'notes': ['This is a digitized catalog card, not an audio recording.',
#      'Instrument: Harmonica (mouth organ)',
#      'Statement of responsibility: Played by Aaron Morgan on harmonica.'],
#     'related_items': [{'title': 'W.P.A. California Folk Music Project Collection (AFC 1940/001)',
#       'url': 'https://lccn.loc.gov/2008700333'}],
#     'repository': 'american folklife center',
#     'rights': 'No known restrictions on use or reproduction.',
#     'source_collection': 'Traditional Music and Spoken Word Card Catalog',
#     'subjects': ['United States of America -- California -- Columbia',
#      'card catalogs'],
#     'title': 'Hi lee, hi lo'},
#    'language': ['english'],
#    'location': ['columbia', 'united states', 'california'],
#    'mime_type': ['image/jpeg', 'image/jp2'],
#    'number': ['http://www.loc.gov/resource/afc9999005.10151.0'],
#    'number_former_id': ['http://www.loc.gov/resource/afc9999005.10151.0'],
#    'online_format': ['image'],
#    'original_format': ['photo, print, drawing'],
#    'partof': ['american folklife center',
#     'w.p.a. california folk music project collection',
#     'traditional music and spoken word card catalog'],
#    'resources': [{'caption': 'Card catalog image',
#      'files': 1,
#      'image': 'https://tile.loc.gov/image-services/iiif/public:afc:afc9999005-10151:0347/full/pct:50.0/0/default.jpg',
#      'paprika_resource_path': '/sets/afc/afc9999005-10151',
#      'url': 'https://www.loc.gov/resource/afc.afc9999005-10151/',
#      'version': 2}],
#    'shelf_id': 'AFS Number: AFS 03368 A03',
#    'subject': ['card catalogs'],
#    'timestamp': '2024-07-10T10:02:35.419Z',
#    'title': 'Hi lee, hi lo',
#    'type': ['still image'],
#    'url': 'https://www.loc.gov/item/afc9999005.10151/'},
#   {'access_restricted': False,
#    'aka': ['http://www.loc.gov/item/2017702066/',
#     'http://lccn.loc.gov/2017702066',
#     'http://www.loc.gov/resource/afc1940001.afc1940001_a3368a3/',
#     'https://hdl.loc.gov/loc.afc/afc1940001.afc1940001_a3368a3'],
#    'campaigns': [],
#    'contributor': ['morgan, aaron', 'cowell, sidney robertson'],
#    'date': '1939-01-01',
#    'dates': ['1939'],
#    'description': ['Dust jacket notes: German waltz. Aaron Morgan, harmonica. Recorded by Sidney Robertson Cowell in Columbia, Tuolumne County, California on July 17, 1939. Forms part of a group of field materials documenting Aaron Morgan performing Anglo-American music on July 17 and 18, 1939, collected by Sidney Robertson Cowell in Columbia, Tuolumne County, California.'],
#    'digitized': True,
#    'extract_timestamp': '2020-09-20T12:29:46.045Z',
#    'group': ['cowell',
#     'catalog-split-15',
#     'catalog',
#     'sidney-robertson-cowell-northern-california-folk-music',
#     'main-catalog-split-15',
#     'main-catalog'],
#    'hassegments': False,
#    'id': 'http://www.loc.gov/item/2017702066/',
#    'image_url': [],
#    'index': 6,
#    'item': {'contributors': ['Morgan, Aaron, 1861-1942, performer.',
#      'Cowell, Sidney Robertson, 1903-1995, collector.'],
#     'created_published': ['1939.'],
#     'date': '1939',
#     'digital_id': ['http://hdl.loc.gov/loc.afc/afc1940001.afc1940001_a3368a3'],
#     'format': ['sound recording-musical'],
#     'genre': ['Field recordings'],
#     'language': ['eng'],
#     'medium': ['on 1 band of 1 sound disc : analog, 78 rpm ; 12 in.'],
#     'notes': ['Dust jacket notes: German waltz.',
#      'Aaron Morgan, harmonica.',
#      'Recorded by Sidney Robertson Cowell in Columbia, Tuolumne County, California on July 17, 1939.',
#      'Forms part of a group of field materials documenting Aaron Morgan performing Anglo-American music on July 17 and 18, 1939, collected by Sidney Robertson Cowell in Columbia, Tuolumne County, California.'],
# ...
#     'created_published_date': '8 December 1921 [date received]',
#     'date': '8 December 1921 [date received]',
#     'digital_id': ['anrc 14638 https://hdl.loc.gov/loc.pnp/anrc.14638'],
#     'display_offsite': True,
#     'format': ['still image'],
#     'formats': [{'link': 'https://www.loc.gov/pictures/related/?fi=format&q=Glass%20negatives.',
#       'title': 'Glass negatives.'}],
#     'genre': ['Glass negatives'],
#     'id': '2017679680',
#     'language': ['eng'],
#     'link': 'https://www.loc.gov/pictures/item/2017679680/',
#     'marc': 'https://www.loc.gov/pictures/item/2017679680/marc/',
#     'medium': ['1 negative : glass ; 5 x 7 in.'],
#     'medium_brief': '1 negative :',
#     'mediums': ['1 negative : glass ; 5 x 7 in.'],
#     'modified': '2017-02-28T03:37:41Z',
#     'notes': ['Title, date and notes from Red Cross caption card.',
#      'Photographer name or source of original from caption card or negative sleeve: John Earl Baker.',
#      'Data: Public Information, December 1921.',
#      'Gift; American National Red Cross 1944 and 1952.',
#      'General information about the American National Red Cross photograph collection is available at http://hdl.loc.gov/loc.pnp/pp.anrc',
#      'Temp note: Batch 29'],
#     'number_former_id': ['https://www.loc.gov/item/2017679680',
#      'https://www.loc.gov/item/anrc2016013581'],
#     'other_control_numbers': ['19519449', 'anrc2016013581'],
#     'part_of': 'American National Red Cross photograph collection (Library of Congress)',
#     'place': [{'latitude': '',
#       'link': 'https://www.loc.gov/pictures/related/?fi=place&q=China--Hi-Hsia',
#       'longitude': '',
#       'title': 'China--Hi-Hsia'}],
#     'raw_collections': ['anrc', 'diof', 'minload', 'pp'],
#     'repository': 'Library of Congress Prints and Photographs Division Washington, D.C. 20540 USA http://hdl.loc.gov/loc.pnp/pp.print',
#     'reproduction_number': 'LC-DIG-anrc-14638 (digital file from original)',
#     'resource_links': ['https://hdl.loc.gov/loc.pnp/anrc.14638'],
#     'rights_advisory': 'No known restrictions on publication. For information, see "American National Red Cross photograph collection," https://www.loc.gov/rr/print/res/717_anrc.html',
#     'rights_information': 'No known restrictions on publication. For information, see "American National Red Cross photograph collection," https://www.loc.gov/rr/print/res/717_anrc.html',
#     'service_low': 'https://tile.loc.gov/storage-services/service/pnp/anrc/14600/14638_150px.jpg',
#     'service_medium': 'https://tile.loc.gov/storage-services/service/pnp/anrc/14600/14638r.jpg',
#     'sort_date': '1921',
#     'source_collection': ['American National Red Cross photograph collection (Library of Congress)'],
#     'source_created': '2016-12-07T00:00:00Z',
#     'source_modified': '2017-02-23T16:26:10Z',
#     'subject_headings': ['American Red Cross.',
#      'China--Hi-Hsia.',
#      'China--Hi-Hsia'],
#     'subjects': ['American Red Cross', 'China--Hi-Hsia'],
#     'thumb_gallery': 'https://tile.loc.gov/storage-services/service/pnp/anrc/14600/14638_150px.jpg',
#     'title': 'At Hi-Hsia (before)'},
#    'language': ['english'],
#    'location': ['hi-hsia', 'hsia', 'hawaii', 'china'],
#    'location_city': ['hi-hsia'],
#    'location_country': ['china'],
#    'mime_type': ['image/gif', 'image/jpg', 'image/tif'],
#    'number': ['2017-02-23t16:26:10',
#     'http://www.loc.gov/item/anrc2016013581',
#     '2017679680',
#     'http://www.loc.gov/item/2017679680',
#     'http://www.loc.gov/item/19519449',
#     'sheet'],
#    'number_carrier_type': ['sheet'],
#    'number_former_id': ['http://www.loc.gov/item/19519449',
#     'http://www.loc.gov/item/anrc2016013581',
#     'http://www.loc.gov/item/2017679680'],
#    'number_lccn': ['2017679680'],
#    'number_source_modified': ['2017-02-23t16:26:10'],
#    'online_format': ['image'],
#    'original_format': ['photo, print, drawing'],
#    'partof': ['catalog',
#     'prints and photographs division',
#     'prints & photographs online catalog (library of congress)'],
#    'related': {'neighbors': 'https://www.loc.gov/pictures/related/?&pk=2017679680&st=gallery&sb=call_number#focus'},
#    'reproductions': '',
#    'resources': [{'caption': 'digital file from original',
#      'files': 1,
#      'image': 'https://tile.loc.gov/storage-services/service/pnp/anrc/14600/14638_150px.jpg',
#      'url': 'https://www.loc.gov/resource/anrc.14638/'}],
#    'shelf_id': 'LC-A6197- RC-10113 [P&P]',
#    'site': ['pictures', 'catalog'],
#    'subject': ['american red cross', 'hi-hsia', 'glass negatives', 'china'],
#    'timestamp': '2023-08-17T16:40:00.727Z',
#    'title': 'At Hi-Hsia (before)',
#    'type': ['still image'],
#    'unrestricted': True,
#    'url': 'https://www.loc.gov/item/2017679680/'},
#   {'access_restricted': False,
#    'aka': ['https://www.loc.gov/pictures/item/2017679681/',
#     'http://www.loc.gov/item/2017679681/',
#     'http://www.loc.gov/pictures/item/2017679681/',
#     'https://hdl.loc.gov/loc.pnp/anrc.14639',
#     'https://hdl.loc.gov/loc.pnp/anrc.14639',
#     'http://www.loc.gov/resource/anrc.14639/',
#     'http://lccn.loc.gov/2017679681'],
#    'campaigns': [],
#    'date': '1921',
#    'dates': ['1921'],
#    'description': ['1 negative : glass ; 5 x 7 in.'],
#    'digitized': True,
#    'extract_timestamp': '2023-07-17T14:47:42.413Z',
#    'group': ['pp_other',
#     'catalog-split-15',
#     'catalog',
#     'prints-and-photographs-other',
#     'main-catalog-split-15'],
#    'hassegments': False,
#    'id': 'http://www.loc.gov/item/2017679681/',
#    'image_url': ['https://tile.loc.gov/storage-services/service/pnp/anrc/14600/14639_150px.jpg#h=109&w=150',
#     'https://tile.loc.gov/storage-services/service/pnp/anrc/14600/14639r.jpg#h=465&w=640',
#     'https://tile.loc.gov/storage-services/service/pnp/anrc/14600/14639v.jpg#h=744&w=1024'],
#    'index': 24,
#    'item': {'call_number': 'LC-A6197- RC-10114 [P&P]',
#     'control_number': '2017679681',
#     'created': '2017-02-28T03:52:00Z',
#     'created_published': '8 December 1921 [date received]',
#     'created_published_date': '8 December 1921 [date received]',
#     'date': '8 December 1921 [date received]',
#     'digital_id': ['anrc 14639 https://hdl.loc.gov/loc.pnp/anrc.14639'],
#     'display_offsite': True,
#     'format': ['still image'],
#     'formats': [{'link': 'https://www.loc.gov/pictures/related/?fi=format&q=Glass%20negatives.',
#       'title': 'Glass negatives.'}],
#     'genre': ['Glass negatives'],
#     'id': '2017679681',
#     'language': ['eng'],
#     'link': 'https://www.loc.gov/pictures/item/2017679681/',
#     'marc': 'https://www.loc.gov/pictures/item/2017679681/marc/',
#     'medium': ['1 negative : glass ; 5 x 7 in.'],
#     'medium_brief': '1 negative :',
#     'mediums': ['1 negative : glass ; 5 x 7 in.'],
#     'modified': '2017-02-28T03:52:00Z',
#     'notes': ['Title, date and notes from Red Cross caption card.',
#      'Photographer name or source of original from caption card or negative sleeve: John Earl Baker.',
#      'Data: Public Information, December 1921.',
#      'Gift; American National Red Cross 1944 and 1952.',
#      'General information about the American National Red Cross photograph collection is available at http://hdl.loc.gov/loc.pnp/pp.anrc',
#      'Temp note: Batch 29'],
#     'number_former_id': ['https://www.loc.gov/item/2017679681',
#      'https://www.loc.gov/item/anrc2016013582'],
#     'other_control_numbers': ['19519450', 'anrc2016013582'],
#     'part_of': 'American National Red Cross photograph collection (Library of Congress)',
#     'place': [{'latitude': '',
#       'link': 'https://www.loc.gov/pictures/related/?fi=place&q=China--Hi-Hsia',
#       'longitude': '',
#       'title': 'China--Hi-Hsia'}],
#     'raw_collections': ['anrc', 'diof', 'minload', 'pp'],
#     'repository': 'Library of Congress Prints and Photographs Division Washington, D.C. 20540 USA http://hdl.loc.gov/loc.pnp/pp.print',
#     'reproduction_number': 'LC-DIG-anrc-14639 (digital file from original)',
#     'resource_links': ['https://hdl.loc.gov/loc.pnp/anrc.14639'],
#     'rights_advisory': 'No known restrictions on publication. For information, see "American National Red Cross photograph collection," https://www.loc.gov/rr/print/res/717_anrc.html',
#     'rights_information': 'No known restrictions on publication. For information, see "American National Red Cross photograph collection," https://www.loc.gov/rr/print/res/717_anrc.html',
#     'service_low': 'https://tile.loc.gov/storage-services/service/pnp/anrc/14600/14639_150px.jpg',
#     'service_medium': 'https://tile.loc.gov/storage-services/service/pnp/anrc/14600/14639r.jpg',
#     'sort_date': '1921',
#     'source_collection': ['American National Red Cross photograph collection (Library of Congress)'],
#     'source_created': '2016-12-07T00:00:00Z',
#     'source_modified': '2017-02-23T16:26:13Z',
#     'subject_headings': ['American Red Cross.',
#      'China--Hi-Hsia.',
#      'China--Hi-Hsia'],
#     'subjects': ['American Red Cross', 'China--Hi-Hsia'],
#     'thumb_gallery': 'https://tile.loc.gov/storage-services/service/pnp/anrc/14600/14639_150px.jpg',
#     'title': 'At Hi-Hsia (after)'},
#    'language': ['english'],
#    'location': ['hi-hsia', 'hsia', 'hawaii', 'china'],
#    'location_city': ['hi-hsia'],
#    'location_country': ['china'],
#    'mime_type': ['image/gif', 'image/jpg', 'image/tif'],
#    'number': ['http://www.loc.gov/item/anrc2016013582',
#     'http://www.loc.gov/item/2017679681',
#     '2017-02-23t16:26:13',
#     'http://www.loc.gov/item/19519450',
#     '2017679681',
#     'sheet'],
#    'number_carrier_type': ['sheet'],
#    'number_former_id': ['http://www.loc.gov/item/19519450',
#     'http://www.loc.gov/item/anrc2016013582',
#     'http://www.loc.gov/item/2017679681'],
#    'number_lccn': ['2017679681'],
#    'number_source_modified': ['2017-02-23t16:26:13'],
#    'online_format': ['image'],
#    'original_format': ['photo, print, drawing'],
#    'partof': ['catalog',
#     'prints and photographs division',
#     'prints & photographs online catalog (library of congress)'],
#    'related': {'neighbors': 'https://www.loc.gov/pictures/related/?&pk=2017679681&st=gallery&sb=call_number#focus'},
#    'reproductions': '',
#    'resources': [{'caption': 'digital file from original',
#      'files': 1,
#      'image': 'https://tile.loc.gov/storage-services/service/pnp/anrc/14600/14639_150px.jpg',
#      'url': 'https://www.loc.gov/resource/anrc.14639/'}],
#    'shelf_id': 'LC-A6197- RC-10114 [P&P]',
#    'site': ['pictures', 'catalog'],
#    'subject': ['american red cross', 'hi-hsia', 'glass negatives', 'china'],
#    'timestamp': '2023-08-17T16:40:00.727Z',
#    'title': 'At Hi-Hsia (after)',
#    'type': ['still image'],
#    'unrestricted': True,
#    'url': 'https://www.loc.gov/item/2017679681/'},
#   {'access_restricted': False,
#    'aka': ['http://www.loc.gov/item/afc1981005_pj15/',
#     'https://hdl.loc.gov/loc.afc/afc1981005.afc1981005_pj15',
#     'http://www.loc.gov/resource/afc1981005.afc1981005_pj15/',
#     'http://www.loc.gov/item/afc1981005.afc1981005_pj15/'],
#    'campaigns': [],
#    'contributor': ['johnson, paula j.'],
#    'date': '1979-07-30',
#    'dates': ['[1979-07-30 TO 1979-08-02]'],
#    'digitized': True,
#    'extract_timestamp': '2022-12-20T15:44:01.919Z',
#    'group': ['afc1981005', 'montana-folklife-survey-1979'],
#    'hassegments': True,
#    'id': 'http://www.loc.gov/item/afc1981005_pj15/',
#    'image_url': ['https://tile.loc.gov/image-services/iiif/service:afc:afc1981005:afc1981005_pj15:afc1981005_pj15_02/full/pct:6.25/0/default.jpg#h=214&w=315',
#     'https://tile.loc.gov/image-services/iiif/service:afc:afc1981005:afc1981005_pj15:afc1981005_pj15_02/full/pct:12.5/0/default.jpg#h=429&w=630',
#     'https://tile.loc.gov/image-services/iiif/service:afc:afc1981005:afc1981005_pj15:afc1981005_pj15_02/full/pct:25/0/default.jpg#h=858&w=1261',
#     'https://tile.loc.gov/image-services/iiif/service:afc:afc1981005:afc1981005_pj15:afc1981005_pj15_02/full/pct:50/0/default.jpg#h=1716&w=2522',
#     'https://tile.loc.gov/image-services/iiif/service:afc:afc1981005:afc1981005_pj15:afc1981005_pj15_02/full/pct:100/0/default.jpg#h=3432&w=5044'],
#    'index': 25,
#    'item': {'call_number': ['Call number: AFC 1981/005: MT9-PJ15'],
#     'contributors': ['Johnson, Paula J., 1954- (Collector)',
#      'Johnson, Paula J., 1954- (Photographer)'],
#     'created_published': ['Havre, Montana, July 30, 1979 - August 2, 1979'],
#     'date': '19790730/19790802',
#     'digital_id': ['https://hdl.loc.gov/loc.afc/afc1981005.afc1981005_pj15'],
#     'format': 'still image',
#     'genre': ['Photographs', 'Ethnography'],
#     'language': 'eng',
#     'location': ['United States -- Montana -- Havre'],
#     'medium': ['35 mm color slide'],
#     'notes': ['Index data: Image numbers, descriptions: scenes of Havre MT and vicinity (July 30 through August 2, 1979): 1-6, Havre, as seen from Highway 2, entering town from west; railroad, tracks and grain exchange are prominent features; 7-9, sculpture depicting farmer with a plow, a railway man with an oilcan and a large driver wheel, and a cowboy with a saddle in front of a bank; 10-13, sunset along railroad tracks on Montana\'s Hi-Line west of Havre; 14-15, landscape near Rocky Boy\'s Indian Reservation (Rocky Boy Indian Reservation); 16-17, stone chimney just north of Havre, the photographer\'s notes state that "the chimney is all that remains of a farm where, as local legend has it, a minister came home to find his wife with another man and after killing both his wife and her lover, he set fire to the place"; 18-19, 4-H building at Hill County fairgrounds, "Old McDonald Had a Farm"; 20, sunset.'],
#     'related_items': [{'title': 'Photo log for AFC 1981/005: MT9-PJ15 (part of AFC 1981/005: Box 6, Folder 88)',
#       'url': 'https://www.loc.gov/resource/afc1981005.afc1981005_06_088/?sp=19'}],
#     'repository': 'American Folklife Center',
#     'rights': 'No known restrictions on use or reproduction.',
#     'source_collection': 'Montana Folklife Survey collection (AFC 1981/005)',
#     'subjects': ['Metal sculpture',
#      'Barns',
#      'Chimneys',
#      'Hi-Line (Mont. : Region)',
#      'Photographs',
#      'Ethnography',
#      'United States -- Montana -- Havre'],
#     'title': 'Hi-Line scenes, including Havre, Montana'},
#    'language': ['english'],
#    'location': ['havre', 'united states', 'montana'],
#    'mime_type': ['image/tiff', 'image/jpeg', 'image/jp2'],
#    'online_format': ['image'],
#    'original_format': ['photo, print, drawing'],
#    'partof': ['montana folklife survey collection',
#     'american folklife center'],
#    'resources': [{'files': 20,
#      'image': 'https://tile.loc.gov/image-services/iiif/service:afc:afc1981005:afc1981005_pj15:afc1981005_pj15_02/full/pct:6.25/0/default.jpg',
#      'representative_index': 1,
#      'search': 'https://www.loc.gov/search/?fa=segmentof:afc1981005.afc1981005_pj15/&fo=json&q=hi&st=gallery',
#      'segments': 20,
#      'url': 'https://www.loc.gov/resource/afc1981005.afc1981005_pj15/'}],
#    'segments': [{'count': 20,
#      'link': 'https://www.loc.gov/search/?fa=segmentof:afc1981005.afc1981005_pj15/&fo=json&q=hi&st=gallery',
#      'url': 'https://www.loc.gov/resource/afc1981005.afc1981005_pj15/'}],
#    'shelf_id': 'Call number: AFC 1981/005: MT9-PJ15',
#    'subject': ['barns',
#     'chimneys',
#     'hi-line (mont. : region)',
#     'metal sculpture',
#     'photographs',
#     'ethnography'],
#    'timestamp': '2022-12-20T16:13:32.025Z',
#    'title': 'Hi-Line scenes, including Havre, Montana',
#    'type': ['still image'],
#    'url': 'https://www.loc.gov/item/afc1981005_pj15/'}],
#  'search': {'dates': None,
#   'facet_limits': '',
#   'field': None,
#   'hits': 3086167,
#   'in': None,
#   'query': 'hi',
#   'recommended': 0,
#   'site': {},
#   'sort_by': None,
#   'type': 'search',
#   'union_facets': '',
#   'url': 'https://www.loc.gov/search/?fo=json&q=hi'},
#  'timestamp': 1759504115901,
#  'views': {'brief': 'https://www.loc.gov/search/?fo=json&q=hi&st=brief',
#   'current': 'list',
#   'gallery': 'https://www.loc.gov/search/?fo=json&q=hi&st=gallery',
#   'grid': 'https://www.loc.gov/search/?fo=json&q=hi&st=grid',
#   'list': 'https://www.loc.gov/search/?fo=json&q=hi',
#   'slideshow': 'https://www.loc.gov/search/?fo=json&q=hi&st=slideshow'}}
